# %% [markdown]
# <a href="https://colab.research.google.com/github/viktoriapatouna/Thesis-work-2025/blob/main/LIRmotifs_Humanproteome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from biopython) (2.0.2)
# Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 32.1 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.85

# %%
pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (0.9.0)

# %%
import os
import csv
import regex
from Bio import SeqIO
from tabulate import tabulate
from collections import defaultdict

# %%
 '''READ THE FASTA FILES AND RETURNS A DICTIONARY
    WHERE KEYS ARE PROTEIN IDs AND VALUES ARE SEQUENCES'''
def read_fasta_file(file_path):
    sequences = {}

    with open(file_path, "r") as file:
        #Use Biopython's SeqIO to parse each FASTA record
        for record in SeqIO.parse(file, "fasta"):  #Choosing a specific FASTA record from the file
            sequences[record.id] = str(record.seq)  #Store ID as keys and sequence as value
    return sequences


'''READS A CSV FILE CONTAINING LIR MOTIF DATA AND RETURNS
  A DICTIONARY WITH UNIQUE MOTIF IDENTIFIERS AND MOTIF INFO AS KEY-VALUE PAIRS'''
def read_csv_file(file_path):
  sequences={}

  with open(file_path , "r" , newline="") as file:
    reader= csv.reader(file)
    headers = next(reader) #Skip the header row
    for row in reader:
      #Choose the Homo sapiens and canonical LIR motifs only
      if row[0].strip() == "Homo sapiens" and row[4].strip() != "Non canonical LIR" :
        uniprot_id = row[1].strip()
        start_position = row[8].strip()
        uniqueID =  f"{uniprot_id}_{start_position}" # Make a unique ID for each LIR motif combining Uniprot ID and start position


        #Extract and reconstruct LIR motif sequence
        if len(row) > 6 :
         motif= row[6].strip() # Remove any spaces and get the LIR motifs only
         if len(row)> 5 :
           motif_row5 = row[5].strip()
           motif_from_row5 = motif_row5[-2:] #Get last 2 amino acids from the sequence before the LIR motif position
           motif = motif_from_row5 + motif


        if row[11].strip()=="NO" or row[11].strip() =="N/A":
         experimentally_verified = "NO"
        else:
         experimentally_verified = "YES"


        #Store only if motif exists
        if motif:
           sequences[uniqueID] = {"motif" : motif , "verified" : experimentally_verified}
        else :
         print(f"Skipping empty motif in row :{row}")

  return sequences



  '''MATCHES HUMAN LIR MOTIFS FROM set1 AGAINST HUMAN PROTEINS FROM set2
  AND RETURNS A DICTIONARY WHERE KEYS ARE MOTIF IDs AND VALUES ARE MATCHE DETAILS'''

def find_protein_matches(set1, set2):
    results = {}

    for uniqueID, motif1 in set1.items():
        motif_seq = motif1["motif"]
        experimentally_verified = motif1["verified"]
        motif_length = len(motif_seq)
        matches = []

        for id2, protein2 in set2.items():
          #Build Regex pattern with <=1 mismatch
          motif_pattern="({}){{e<=1}}".format(motif_seq)
          found_matches = []


          #Search for all matches within the protein sequence
          for match in regex.finditer(motif_pattern, protein2  ,overlapped=True) :
            #search for all matches and returns match objects, .findall() only returns strings
            position= match.start()
            sequence = match.group()
            sequence_length = len(sequence)
            #Store match details(matched position in protein,matched sequence and its length)
            found_matches.append((position,sequence,sequence_length))

          #If any matches found for this protein,add then in found_matches variable
          if found_matches:
            matches.append({
                    "protein_id": id2,
                    "protein_length": len(protein2),  # length of the protein from me set2
                    "matches" :found_matches,
                    "experimentally_verified" : experimentally_verified

                })

        #If this motif matched in any protein, store the results under the motif's unique ID
        if matches:
            results[uniqueID] = matches

    return results

# %%
#Read motif data from CSV file
set1 = read_csv_file("LIRcentral.csv")
#Read human proteins sequence from FASTA file
set2 = read_fasta_file("Humanproteome.fasta")

#Check if either input set is empty and stop the execution
if not set1 or not set2:
   print("Error: One or both sets are empty.")

else:
    #Find where motifs matched proteins sequence
    matches = find_protein_matches(set1, set2)

    #Loop through all motifs that matched
    for uniqueID, match_list in matches.items():
        motif_length = len(set1[uniqueID]["motif"])  # protein length from the set1
        print(f"Protein: {uniqueID} (Length: {motif_length})")

        #Loop through all proteins sequences that had a match with this motif
        for match in match_list:
            print(f"  Found in: {match['protein_id']} (Length: {match['protein_length']})")
            #Loop through individual match positions and sequences
            for position, sequence ,*_ in match["matches"]:
               print(f"  Matches at position {position} : {sequence}")
# Out:
# /usr/local/lib/python3.11/dist-packages/Bio/SeqIO/FastaIO.py:203: BiopythonDeprecationWarning: Previously, the FASTA parser silently ignored comments at the beginning of the FASTA file (before the first sequence).
#
# Nowadays, the FASTA file format is usually understood not to have any such comments, and most software packages do not allow them. Therefore, the use of comments at the beginning of a FASTA file is now deprecated in Biopython.
#
# In a future Biopython release, this deprecation warning will be replaced by a ValueError. To avoid this, there are three options:
#
# (1) Modify your FASTA file to remove such comments at the beginning of the file.
#
# (2) Use SeqIO.parse with the 'fasta-pearson' format instead of 'fasta'. This format is consistent with the FASTA format defined by William Pearson's FASTA aligner software. Thie format allows for comments before the first sequence; lines starting with the ';' character anywhere in the file are also regarded as comment lines and are ignored.
#
# (3) Use the 'fasta-blast' format. This format regards any lines starting with '!', '#', or ';' as comment lines. The 'fasta-blast' format may be safer than the 'fasta-pearson' format, as it explicitly indicates which lines are comments.
#   warnings.warn(
# Protein: A0A3Q9JIX6_160 (Length: 6)
#   Found in: tr|A0A804HIC7|A0A804HIC7_HUMAN (Length: 121)
#   Matches at position 1 : TSSRL
#   Found in: tr|A0A804HJK0|A0A804HJK0_HUMAN (Length: 96)
#   Matches at position 1 : TSSRL
#   Found in: tr|A0A804HK32|A0A804HK32_HUMAN (Length: 90)
#   Matches at position 1 : TSSRL
#   Found in: tr|A0A8I5KNV1|A0A8I5KNV1_HUMAN (Length: 140)
#   Matches at position 46 : TSTSRL
#   Found in: tr|A0A8I5KPX0|A0A8I5KPX0_HUMAN (Length: 256)
#   Matches at position 243 : TSYSVL
#   Found in: tr|A0A8I5KUA5|A0A8I5KUA5_HUMAN (Length: 169)
#   Matches at position 75 : TSTSRL
#   Found in: tr|A0A8V8TMA2|A0A8V8TMA2_HUMAN (Length: 64)
#   Matches at position 8 : TSSRL
#   Found in: tr|A0A8V8TMR8|A0A8V8TMR8_HUMAN (Length: 66)
#   Matches at position 8 : TSSRL
#   Found in: tr|A0A8V8TMR9|A0A8V8TMR9_HUMAN (Length: 136)
#   Matches at position 96 : TYSRL
#   Found in: tr|A0A8V8TN79|A0A8V8TN79_HUMAN (Length: 571)
#   Matches at position 154 : TYSRL
#   Found in: tr|A0A8V8TN90|A0A8V8TN90_HUMAN (Length: 611)
#   Matches at position 154 : TYSRL
#   Found in: tr|A0A8V8TN99|A0A8V8TN99_HUMAN (Length: 663)
#   Matches at position 154 : TYSRL
#   Found in: tr|A0A8V8TP54|A0A8V8TP54_HUMAN (Length: 377)
#   Matches at position 154 : TYSRL
#   Found in: tr|A0A8V8TP64|A0A8V8TP64_HUMAN (Length: 644)
#   Matches at position 154 : TYSRL
#   Found in: tr|A0A8V8TP71|A0A8V8TP71_HUMAN (Length: 194)
#   Matches at position 154 : TYSRL
#   Found in: tr|A0A8V8TPI6|A0A8V8TPI6_HUMAN (Length: 710)
#   Matches at position 154 : TYSRL
#   Found in: tr|A0A8V8TPJ1|A0A8V8TPJ1_HUMAN (Length: 786)
#   Matches at position 154 : TYSRL
#   Found in: tr|A0A994J4J1|A0A994J4J1_HUMAN (Length: 430)
#   Matches at position 178 : TSYSL
#   Found in: tr|A0A994J4S6|A0A994J4S6_HUMAN (Length: 734)
#   Matches at position 470 : TSYSL
#   Found in: tr|A0A994J7C1|A0A994J7C1_HUMAN (Length: 1854)
#   Matches at position 1590 : TSYSL
#   Found in: tr|A0A994J7R0|A0A994J7R0_HUMAN (Length: 1182)
#   Matches at position 918 : TSYSL
#   Found in: tr|A0AAG2TKX0|A0AAG2TKX0_HUMAN (Length: 530)
#   Matches at position 20 : TSSRL
#   Found in: tr|A0AAG2TUE6|A0AAG2TUE6_HUMAN (Length: 898)
#   Matches at position 834 : TSHSRL
#   Found in: tr|A7MBN2|A7MBN2_HUMAN (Length: 1927)
#   Matches at position 1663 : TSYSL
#   Found in: tr|A8K3U6|A8K3U6_HUMAN (Length: 605)
#   Matches at position 419 : TSISRL
#   Found in: tr|B1PRL2|B1PRL2_HUMAN (Length: 498)
#   Matches at position 314 : TSSRL
#   Found in: tr|B2RTQ2|B2RTQ2_HUMAN (Length: 837)
#   Matches at position 255 : TSSRL
#   Found in: tr|B3KSI5|B3KSI5_HUMAN (Length: 115)
#   Matches at position 6 : RSYSRL
#   Matches at position 7 : SYSRL
#   Found in: tr|B3KTL0|B3KTL0_HUMAN (Length: 420)
#   Matches at position 54 : TYSRL
#   Found in: tr|B3KV28|B3KV28_HUMAN (Length: 336)
#   Matches at position 305 : TSYSL
#   Found in: tr|B3KY75|B3KY75_HUMAN (Length: 108)
#   Matches at position 65 : TSGSRL
#   Found in: tr|B4DDS8|B4DDS8_HUMAN (Length: 184)
#   Matches at position 153 : TYSRL
#   Found in: tr|B4DH91|B4DH91_HUMAN (Length: 581)
#   Matches at position 144 : TSSRL
#   Found in: tr|B4DIX6|B4DIX6_HUMAN (Length: 340)
#   Matches at position 154 : TYSRL
#   Found in: tr|B4DJT0|B4DJT0_HUMAN (Length: 450)
#   Matches at position 43 : LSYSRL
#   Matches at position 44 : SYSRL
#   Found in: tr|B4DLF2|B4DLF2_HUMAN (Length: 1011)
#   Matches at position 707 : TSSRL
#   Found in: tr|B4DN83|B4DN83_HUMAN (Length: 486)
#   Matches at position 305 : TSSRL
#   Found in: tr|B4DNF7|B4DNF7_HUMAN (Length: 574)
#   Matches at position 181 : KSYSRL
#   Matches at position 182 : SYSRL
#   Found in: tr|B4DR14|B4DR14_HUMAN (Length: 823)
#   Matches at position 759 : TSHSRL
#   Found in: tr|B4DRC7|B4DRC7_HUMAN (Length: 793)
#   Matches at position 552 : TSYIRL
#   Found in: tr|B4DTR5|B4DTR5_HUMAN (Length: 631)
#   Matches at position 309 : TYSRL
#   Found in: tr|B4DVX5|B4DVX5_HUMAN (Length: 362)
#   Matches at position 181 : TSSRL
#   Found in: tr|B4DY46|B4DY46_HUMAN (Length: 559)
#   Matches at position 421 : TSSRL
#   Found in: tr|B4E1W8|B4E1W8_HUMAN (Length: 1080)
#   Matches at position 1009 : TSYSL
#   Found in: tr|B4E3G4|B4E3G4_HUMAN (Length: 1009)
#   Matches at position 206 : TYSRL
#   Found in: tr|B7Z1E8|B7Z1E8_HUMAN (Length: 619)
#   Matches at position 159 : TSSRL
#   Found in: tr|B7Z2Y8|B7Z2Y8_HUMAN (Length: 151)
#   Matches at position 84 : TSASRL
#   Found in: tr|B7Z6L4|B7Z6L4_HUMAN (Length: 657)
#   Matches at position 140 : TSSRL
#   Found in: tr|B7ZL43|B7ZL43_HUMAN (Length: 336)
#   Matches at position 42 : TSYSL
#   Found in: tr|B7ZMF1|B7ZMF1_HUMAN (Length: 837)
#   Matches at position 255 : TSSRL
#   Found in: tr|B9EGE7|B9EGE7_HUMAN (Length: 957)
#   Matches at position 892 : TSYSL
#   Found in: tr|B9TX49|B9TX49_HUMAN (Length: 359)
#   Matches at position 158 : TYSRL
#   Found in: tr|C9JW56|C9JW56_HUMAN (Length: 291)
#   Matches at position 269 : TSSRL
#   Found in: tr|D3YHM4|D3YHM4_HUMAN (Length: 1840)
#   Matches at position 1574 : TSYSL
#   Found in: tr|D6RBF7|D6RBF7_HUMAN (Length: 102)
#   Matches at position 97 : TSSRL
#   Found in: tr|D6RCD8|D6RCD8_HUMAN (Length: 173)
#   Matches at position 134 : TMYSRL
#   Found in: tr|E7EQI7|E7EQI7_HUMAN (Length: 1011)
#   Matches at position 707 : TSSRL
#   Found in: tr|E9PI50|E9PI50_HUMAN (Length: 104)
#   Matches at position 42 : TSYSL
#   Found in: tr|E9PLY0|E9PLY0_HUMAN (Length: 1062)
#   Matches at position 978 : TSLSRL
#   Found in: tr|F2X5Z6|F2X5Z6_HUMAN (Length: 181)
#   Matches at position 8 : TSVSRL
#   Found in: tr|F2Z3L7|F2Z3L7_HUMAN (Length: 197)
#   Matches at position 63 : TSYSEL
#   Found in: tr|F5GWJ3|F5GWJ3_HUMAN (Length: 336)
#   Matches at position 42 : TSYSL
#   Found in: tr|F5H055|F5H055_HUMAN (Length: 200)
#   Matches at position 137 : TSQSRL
#   Found in: tr|F5H116|F5H116_HUMAN (Length: 203)
#   Matches at position 72 : TSSRL
#   Found in: tr|F5H7V9|F5H7V9_HUMAN (Length: 1838)
#   Matches at position 1574 : TSYSL
#   Found in: tr|F8W130|F8W130_HUMAN (Length: 868)
#   Matches at position 340 : TSYSVL
#   Found in: tr|F8W1U0|F8W1U0_HUMAN (Length: 457)
#   Matches at position 48 : TSYSVL
#   Found in: tr|G1CT06|G1CT06_HUMAN (Length: 619)
#   Matches at position 83 : TSSRL
#   Found in: tr|H0Y4K4|H0Y4K4_HUMAN (Length: 291)
#   Matches at position 154 : TYSRL
#   Found in: tr|H0YBS6|H0YBS6_HUMAN (Length: 182)
#   Matches at position 58 : TSSSRL
#   Found in: tr|H0YC92|H0YC92_HUMAN (Length: 76)
#   Matches at position 61 : TSSRL
#   Found in: tr|H0YGZ3|H0YGZ3_HUMAN (Length: 615)
#   Matches at position 500 : TSYSL
#   Found in: tr|H0YLM8|H0YLM8_HUMAN (Length: 3058)
#   Matches at position 475 : TYSRL
#   Found in: tr|H3BMA8|H3BMA8_HUMAN (Length: 94)
#   Matches at position 24 : TSYSVL
#   Found in: tr|H3BMH7|H3BMH7_HUMAN (Length: 237)
#   Matches at position 222 : TSYRL
#   Found in: tr|H3BQ04|H3BQ04_HUMAN (Length: 143)
#   Matches at position 1 : TSSRL
#   Found in: tr|H3BRP6|H3BRP6_HUMAN (Length: 88)
#   Matches at position 1 : TSSRL
#   Found in: tr|H3BT62|H3BT62_HUMAN (Length: 143)
#   Matches at position 1 : TSSRL
#   Found in: tr|H3BVH8|H3BVH8_HUMAN (Length: 134)
#   Matches at position 1 : TSSRL
#   Found in: tr|H7C4Q3|H7C4Q3_HUMAN (Length: 419)
#   Matches at position 215 : TSYSRA
#   Found in: tr|H7C504|H7C504_HUMAN (Length: 272)
#   Matches at position 95 : DSYSRL
#   Matches at position 96 : SYSRL
#   Found in: tr|H9XFB7|H9XFB7_HUMAN (Length: 267)
#   Matches at position 16 : TSSRL
#   Found in: tr|H9XFB8|H9XFB8_HUMAN (Length: 267)
#   Matches at position 61 : TSSRL
#   Found in: tr|H9XFB9|H9XFB9_HUMAN (Length: 266)
#   Matches at position 96 : TSSRL
#   Found in: tr|I6LJZ6|I6LJZ6_HUMAN (Length: 176)
#   Matches at position 120 : PSYSRL
#   Matches at position 121 : SYSRL
#   Found in: tr|I6LLZ7|I6LLZ7_HUMAN (Length: 159)
#   Matches at position 120 : PSYSRL
#   Matches at position 121 : SYSRL
#   Found in: tr|I6QQS6|I6QQS6_HUMAN (Length: 181)
#   Matches at position 8 : TSVSRL
#   Found in: tr|J3KQ40|J3KQ40_HUMAN (Length: 1155)
#   Matches at position 140 : TSSRL
#   Found in: tr|J3KTI1|J3KTI1_HUMAN (Length: 78)
#   Matches at position 8 : TSSRL
#   Found in: tr|J3QKZ6|J3QKZ6_HUMAN (Length: 51)
#   Matches at position 8 : TSSRL
#   Found in: tr|J3QL48|J3QL48_HUMAN (Length: 77)
#   Matches at position 9 : GSYSRL
#   Matches at position 10 : SYSRL
#   Found in: tr|J3QQN1|J3QQN1_HUMAN (Length: 138)
#   Matches at position 35 : GSYSRL
#   Matches at position 36 : SYSRL
#   Found in: tr|J3QS53|J3QS53_HUMAN (Length: 85)
#   Matches at position 8 : TSSRL
#   Found in: tr|K7ELE9|K7ELE9_HUMAN (Length: 272)
#   Matches at position 23 : TSYSL
#   Found in: tr|K7ELV7|K7ELV7_HUMAN (Length: 78)
#   Matches at position 6 : TSYSVL
#   Found in: tr|K7EP34|K7EP34_HUMAN (Length: 96)
#   Matches at position 8 : TSYSVL
#   Found in: tr|K7EPY8|K7EPY8_HUMAN (Length: 89)
#   Matches at position 7 : TSYSVL
#   Found in: tr|K7ER43|K7ER43_HUMAN (Length: 516)
#   Matches at position 336 : TSSRL
#   Found in: tr|K7ERJ6|K7ERJ6_HUMAN (Length: 1106)
#   Matches at position 1042 : TSHSRL
#   Found in: tr|M0R1K0|M0R1K0_HUMAN (Length: 92)
#   Matches at position 36 : PSYSRL
#   Matches at position 37 : SYSRL
#   Found in: tr|O00184|O00184_HUMAN (Length: 579)
#   Matches at position 455 : TSSRL
#   Found in: tr|O14945|O14945_HUMAN (Length: 200)
#   Matches at position 50 : TSYSL
#   Found in: tr|O14997|O14997_HUMAN (Length: 709)
#   Matches at position 382 : TSSRL
#   Found in: sp|P0C5K7|CT62_HUMAN (Length: 136)
#   Matches at position 4 : TSYRRL
#   Found in: tr|Q05C89|Q05C89_HUMAN (Length: 74)
#   Matches at position 42 : TSYSL
#   Found in: tr|Q05CN7|Q05CN7_HUMAN (Length: 567)
#   Matches at position 218 : TSYRL
#   Found in: tr|Q14395|Q14395_HUMAN (Length: 505)
#   Matches at position 452 : TSSRL
#   Found in: tr|Q16198|Q16198_HUMAN (Length: 76)
#   Matches at position 36 : TSSRL
#   Found in: tr|Q4LE33|Q4LE33_HUMAN (Length: 2233)
#   Matches at position 1969 : TSYSL
#   Found in: tr|Q537H9|Q537H9_HUMAN (Length: 230)
#   Matches at position 144 : TSSRL
#   Found in: tr|Q53EL1|Q53EL1_HUMAN (Length: 1164)
#   Matches at position 860 : TSSRL
#   Found in: tr|Q53GF4|Q53GF4_HUMAN (Length: 593)
#   Matches at position 455 : TSSRL
#   Found in: tr|Q59EH4|Q59EH4_HUMAN (Length: 541)
#   Matches at position 361 : TSSRL
#   Found in: tr|Q59F19|Q59F19_HUMAN (Length: 949)
#   Matches at position 512 : TSSRL
#   Found in: tr|Q59FN3|Q59FN3_HUMAN (Length: 274)
#   Matches at position 72 : TMYSRL
#   Found in: tr|Q59FY8|Q59FY8_HUMAN (Length: 117)
#   Matches at position 63 : TSQSRL
#   Found in: tr|Q5HYL4|Q5HYL4_HUMAN (Length: 636)
#   Matches at position 326 : TSSRL
#   Found in: tr|Q5QPA5|Q5QPA5_HUMAN (Length: 263)
#   Matches at position 24 : TSWSRL
#   Found in: tr|Q68DN7|Q68DN7_HUMAN (Length: 252)
#   Matches at position 96 : TSYSPL
#   Found in: tr|Q6DCA5|Q6DCA5_HUMAN (Length: 887)
#   Matches at position 454 : TSSRL
#   Found in: tr|Q6PAV0|Q6PAV0_HUMAN (Length: 622)
#   Matches at position 457 : TSSRL
#   Found in: tr|Q6PJD6|Q6PJD6_HUMAN (Length: 531)
#   Matches at position 134 : TSSRL
#   Found in: tr|Q6ZP26|Q6ZP26_HUMAN (Length: 440)
#   Matches at position 141 : TYSRL
#   Found in: tr|Q6ZSD7|Q6ZSD7_HUMAN (Length: 1062)
#   Matches at position 978 : TSLSRL
#   Found in: tr|Q70T19|Q70T19_HUMAN (Length: 88)
#   Matches at position 71 : TSSRL
#   Found in: tr|Q7Z4Z5|Q7Z4Z5_HUMAN (Length: 304)
#   Matches at position 132 : TSSRL
#   Found in: tr|Q86YH1|Q86YH1_HUMAN (Length: 501)
#   Matches at position 457 : TSSRL
#   Found in: tr|Q8IU91|Q8IU91_HUMAN (Length: 44)
#   Matches at position 1 : TSYSSL
#   Found in: tr|Q96ER8|Q96ER8_HUMAN (Length: 19)
#   Matches at position 8 : TSSRL
#   Found in: tr|Q96P52|Q96P52_HUMAN (Length: 420)
#   Matches at position 268 : RSYSRL
#   Matches at position 269 : SYSRL
#   Found in: tr|Q9BZD1|Q9BZD1_HUMAN (Length: 476)
#   Matches at position 292 : TSSRL
#   Found in: tr|Q9H2L6|Q9H2L6_HUMAN (Length: 142)
#   Matches at position 74 : TSYSL
#   Found in: sp|Q9H693|CP095_HUMAN (Length: 158)
#   Matches at position 143 : TSYRL
#   Found in: tr|Q9H6M4|Q9H6M4_HUMAN (Length: 674)
#   Matches at position 292 : TSYSL
#   Found in: tr|Q9HA55|Q9HA55_HUMAN (Length: 312)
#   Matches at position 248 : TSHSRL
#   Found in: tr|Q9NXY2|Q9NXY2_HUMAN (Length: 235)
#   Matches at position 114 : TSSRL
#   Found in: tr|Q9UI01|Q9UI01_HUMAN (Length: 742)
#   Matches at position 382 : TSSRL
#   Found in: tr|Q9Y438|Q9Y438_HUMAN (Length: 892)
#   Matches at position 161 : TSYSDL
#   Found in: tr|X6RL26|X6RL26_HUMAN (Length: 189)
#   Matches at position 39 : TSYSRV
# Protein: B9EIS5_1955 (Length: 6)
#   Found in: tr|A0A8I5KQV3|A0A8I5KQV3_HUMAN (Length: 1881)
#   Matches at position 1059 : EFVKV
#   Found in: tr|A0A8I5KRW6|A0A8I5KRW6_HUMAN (Length: 1835)
#   Matches at position 1227 : EFVKV
#   Found in: tr|A0A8I5KYL8|A0A8I5KYL8_HUMAN (Length: 602)
#   Matches at position 592 : EDFVPV
#   Found in: tr|A0A8J8Z0T9|A0A8J8Z0T9_HUMAN (Length: 4890)
#   Matches at position 4174 : EFVKV
#   Found in: tr|A0A8Q3SIQ3|A0A8Q3SIQ3_HUMAN (Length: 509)
#   Matches at position 74 : EDFKV
#   Found in: tr|A0A8Q3SIU7|A0A8Q3SIU7_HUMAN (Length: 1518)
#   Matches at position 1087 : EDFKV
#   Found in: tr|A0A8Q3SIX9|A0A8Q3SIX9_HUMAN (Length: 1659)
#   Matches at position 1092 : EDFKV
#   Found in: tr|A0A8Q3SIZ4|A0A8Q3SIZ4_HUMAN (Length: 1402)
#   Matches at position 1087 : EDFKV
#   Found in: tr|A0A8Q3WKG2|A0A8Q3WKG2_HUMAN (Length: 1086)
#   Matches at position 994 : EDFKKV
#   Found in: tr|A0A8Q3WKP2|A0A8Q3WKP2_HUMAN (Length: 107)
#   Matches at position 91 : EGFVKV
#   Found in: tr|A0A8Q3WMJ4|A0A8Q3WMJ4_HUMAN (Length: 1129)
#   Matches at position 814 : EDFKV
#   Found in: tr|A0A8Q3WMK3|A0A8Q3WMK3_HUMAN (Length: 1591)
#   Matches at position 1087 : EDFKV
#   Found in: tr|A0A8V8TMV8|A0A8V8TMV8_HUMAN (Length: 234)
#   Matches at position 126 : EDFVV
#   Found in: tr|A0AAG2TH09|A0AAG2TH09_HUMAN (Length: 376)
#   Matches at position 269 : EDVKV
#   Found in: tr|A0AAG2TH20|A0AAG2TH20_HUMAN (Length: 416)
#   Matches at position 309 : EDVKV
#   Found in: tr|A0AAG2TK99|A0AAG2TK99_HUMAN (Length: 773)
#   Matches at position 666 : EDVKV
#   Found in: tr|A0AAQ5BH14|A0AAQ5BH14_HUMAN (Length: 2155)
#   Matches at position 1723 : EDCVKV
#   Found in: tr|A0AAQ5BH18|A0AAQ5BH18_HUMAN (Length: 2912)
#   Matches at position 1723 : EDCVKV
#   Found in: tr|A0AAQ5BH23|A0AAQ5BH23_HUMAN (Length: 2435)
#   Matches at position 1723 : EDCVKV
#   Found in: tr|A0AAQ5BH37|A0AAQ5BH37_HUMAN (Length: 2929)
#   Matches at position 1723 : EDCVKV
#   Found in: tr|A0AAQ5BIC8|A0AAQ5BIC8_HUMAN (Length: 35853)
#   Matches at position 2061 : EPFVKV
#   Found in: tr|A0AAU7P1G8|A0AAU7P1G8_HUMAN (Length: 553)
#   Matches at position 133 : ECFVKV
#   Found in: tr|A2RUU9|A2RUU9_HUMAN (Length: 1859)
#   Matches at position 1794 : EEDFVKV
#   Matches at position 1795 : EDFVKV
#   Matches at position 1796 : DFVKV
#   Found in: tr|A3KPE3|A3KPE3_HUMAN (Length: 212)
#   Matches at position 133 : ECFVKV
#   Found in: tr|A4D212|A4D212_HUMAN (Length: 2394)
#   Matches at position 351 : EIFVKV
#   Found in: tr|A4D213|A4D213_HUMAN (Length: 2408)
#   Matches at position 351 : EIFVKV
#   Found in: tr|A4D2N6|A4D2N6_HUMAN (Length: 1350)
#   Matches at position 1247 : EDFVKD
#   Found in: tr|A4D2N7|A4D2N7_HUMAN (Length: 1246)
#   Matches at position 1143 : EDFVKD
#   Found in: tr|A7MD47|A7MD47_HUMAN (Length: 467)
#   Matches at position 411 : EDRVKV
#   Found in: tr|A8K1U5|A8K1U5_HUMAN (Length: 528)
#   Matches at position 181 : EDFKV
#   Found in: tr|A8K6Z0|A8K6Z0_HUMAN (Length: 742)
#   Matches at position 87 : EDFVSV
#   Found in: tr|A8K8T9|A8K8T9_HUMAN (Length: 1395)
#   Matches at position 83 : EFVKV
#   Found in: tr|B3KND5|B3KND5_HUMAN (Length: 1451)
#   Matches at position 546 : EDVKV
#   Found in: tr|B3KRU6|B3KRU6_HUMAN (Length: 222)
#   Matches at position 205 : EDLVKV
#   Found in: tr|B3KS41|B3KS41_HUMAN (Length: 742)
#   Matches at position 87 : EDFVSV
#   Found in: tr|B3KTI0|B3KTI0_HUMAN (Length: 354)
#   Matches at position 171 : EDVKV
#   Found in: tr|B3KVB3|B3KVB3_HUMAN (Length: 384)
#   Matches at position 254 : EDFVLV
#   Found in: tr|B3KVT7|B3KVT7_HUMAN (Length: 519)
#   Matches at position 427 : EDFKKV
#   Found in: tr|B3KWG8|B3KWG8_HUMAN (Length: 1088)
#   Matches at position 996 : EDFKKV
#   Found in: tr|B3KY78|B3KY78_HUMAN (Length: 620)
#   Matches at position 202 : EDFVSV
#   Found in: tr|B4DF71|B4DF71_HUMAN (Length: 392)
#   Matches at position 14 : EDFKV
#   Found in: tr|B4DFD7|B4DFD7_HUMAN (Length: 854)
#   Matches at position 44 : EDDVKV
#   Found in: tr|B4DGQ2|B4DGQ2_HUMAN (Length: 1018)
#   Matches at position 230 : EDVKV
#   Found in: tr|B4DH05|B4DH05_HUMAN (Length: 369)
#   Matches at position 257 : EDFLKV
#   Found in: tr|B4DJ00|B4DJ00_HUMAN (Length: 823)
#   Matches at position 758 : EEDFVKV
#   Matches at position 759 : EDFVKV
#   Matches at position 760 : DFVKV
#   Found in: tr|B4DJV6|B4DJV6_HUMAN (Length: 631)
#   Matches at position 378 : EDFNKV
#   Found in: tr|B4DK81|B4DK81_HUMAN (Length: 412)
#   Matches at position 405 : EDFEKV
#   Found in: tr|B4DL51|B4DL51_HUMAN (Length: 675)
#   Matches at position 372 : EDFVEV
#   Found in: tr|B4DNG7|B4DNG7_HUMAN (Length: 204)
#   Matches at position 52 : EDVKV
#   Found in: tr|B4DRL5|B4DRL5_HUMAN (Length: 732)
#   Matches at position 479 : EDFNKV
#   Found in: tr|B4DWY1|B4DWY1_HUMAN (Length: 640)
#   Matches at position 575 : EEDFVKV
#   Matches at position 576 : EDFVKV
#   Matches at position 577 : DFVKV
#   Found in: tr|B4DX55|B4DX55_HUMAN (Length: 520)
#   Matches at position 52 : EDVKV
#   Found in: tr|B4DZ20|B4DZ20_HUMAN (Length: 452)
#   Matches at position 199 : EDFNKV
#   Found in: tr|B4DZ42|B4DZ42_HUMAN (Length: 860)
#   Matches at position 292 : EDFLKV
#   Found in: tr|B4DZC5|B4DZC5_HUMAN (Length: 428)
#   Matches at position 131 : EDFVSV
#   Found in: tr|B4DZT3|B4DZT3_HUMAN (Length: 376)
#   Matches at position 314 : EDVKV
#   Found in: tr|B4E0X0|B4E0X0_HUMAN (Length: 429)
#   Matches at position 230 : EDVKV
#   Found in: tr|B5MCD9|B5MCD9_HUMAN (Length: 112)
#   Matches at position 22 : EDFVLV
#   Found in: tr|B7Z1S8|B7Z1S8_HUMAN (Length: 537)
#   Matches at position 284 : EDFNKV
#   Found in: tr|B7Z2B2|B7Z2B2_HUMAN (Length: 184)
#   Matches at position 147 : EDSVKV
#   Found in: tr|B7Z6Q1|B7Z6Q1_HUMAN (Length: 664)
#   Matches at position 223 : EDFYKV
#   Found in: tr|B9EIS5|B9EIS5_HUMAN (Length: 2016)
#   Matches at position 1951 : EEDFVKV
#   Matches at position 1952 : EDFVKV
#   Matches at position 1953 : DFVKV
#   Found in: tr|C0JYZ2|C0JYZ2_HUMAN (Length: 33423)
#   Matches at position 2199 : EPFVKV
#   Found in: tr|C6KMR8|C6KMR8_HUMAN (Length: 555)
#   Matches at position 133 : ECFVKV
#   Found in: tr|C9J6H5|C9J6H5_HUMAN (Length: 128)
#   Matches at position 89 : EDFVV
#   Found in: tr|C9J6N5|C9J6N5_HUMAN (Length: 124)
#   Matches at position 109 : EFVKV
#   Found in: tr|C9JGR5|C9JGR5_HUMAN (Length: 66)
#   Matches at position 22 : EDFVLV
#   Found in: tr|C9JPM3|C9JPM3_HUMAN (Length: 147)
#   Matches at position 89 : EDFVV
#   Found in: tr|C9JQ40|C9JQ40_HUMAN (Length: 126)
#   Matches at position 109 : EFVKV
#   Found in: tr|C9JSF2|C9JSF2_HUMAN (Length: 226)
#   Matches at position 17 : EEFVKV
#   Matches at position 18 : EFVKV
#   Found in: tr|C9JW51|C9JW51_HUMAN (Length: 128)
#   Matches at position 109 : EFVKV
#   Found in: tr|E9PAK2|E9PAK2_HUMAN (Length: 221)
#   Matches at position 208 : EDVKV
#   Found in: tr|E9PC61|E9PC61_HUMAN (Length: 303)
#   Matches at position 44 : EDSVKV
#   Found in: tr|E9PQH4|E9PQH4_HUMAN (Length: 199)
#   Matches at position 92 : EDVKV
#   Found in: tr|F2Z2K0|F2Z2K0_HUMAN (Length: 274)
#   Matches at position 240 : EDFVKP
#   Found in: tr|F8VSK4|F8VSK4_HUMAN (Length: 263)
#   Matches at position 181 : EDFKV
#   Found in: tr|F8W9E7|F8W9E7_HUMAN (Length: 703)
#   Matches at position 444 : EDFDKV
#   Found in: tr|F8WC81|F8WC81_HUMAN (Length: 97)
#   Matches at position 35 : GDFVKV
#   Matches at position 36 : DFVKV
#   Found in: tr|F8WE20|F8WE20_HUMAN (Length: 89)
#   Matches at position 35 : GDFVKV
#   Matches at position 36 : DFVKV
#   Found in: tr|G4U4J3|G4U4J3_HUMAN (Length: 631)
#   Matches at position 217 : EDSVKV
#   Found in: tr|H0Y512|H0Y512_HUMAN (Length: 409)
#   Matches at position 252 : EDFVLV
#   Found in: tr|H0Y770|H0Y770_HUMAN (Length: 1575)
#   Matches at position 223 : EDFYKV
#   Found in: tr|H0Y781|H0Y781_HUMAN (Length: 1674)
#   Matches at position 874 : EFVKV
#   Found in: tr|H0Y9M1|H0Y9M1_HUMAN (Length: 247)
#   Matches at position 14 : EDFVSV
#   Found in: tr|H0YCM7|H0YCM7_HUMAN (Length: 441)
#   Matches at position 192 : EDFNKV
#   Found in: tr|H0YEC6|H0YEC6_HUMAN (Length: 1906)
#   Matches at position 1723 : EDCVKV
#   Found in: tr|H0YER3|H0YER3_HUMAN (Length: 87)
#   Matches at position 20 : EDFVKD
#   Found in: tr|H0YLM8|H0YLM8_HUMAN (Length: 3058)
#   Matches at position 2248 : EDVKV
#   Found in: tr|H3BLT5|H3BLT5_HUMAN (Length: 1381)
#   Matches at position 581 : EFVKV
#   Found in: tr|H7BXY1|H7BXY1_HUMAN (Length: 168)
#   Matches at position 76 : EDFKKV
#   Found in: tr|H7C0Y8|H7C0Y8_HUMAN (Length: 197)
#   Matches at position 151 : EFVKV
#   Found in: tr|H7C1W9|H7C1W9_HUMAN (Length: 396)
#   Matches at position 18 : EDFKV
#   Found in: tr|H7C5V9|H7C5V9_HUMAN (Length: 376)
#   Matches at position 269 : EDVKV
#   Found in: tr|I6ZVX6|I6ZVX6_HUMAN (Length: 133)
#   Matches at position 127 : ECFVKV
#   Found in: tr|Q16063|Q16063_HUMAN (Length: 21)
#   Matches at position 6 : EGFVKV
#   Found in: tr|Q53F79|Q53F79_HUMAN (Length: 466)
#   Matches at position 52 : EDSVKV
#   Found in: tr|Q59FB2|Q59FB2_HUMAN (Length: 437)
#   Matches at position 420 : EDLVKV
#   Found in: tr|Q5JVZ5|Q5JVZ5_HUMAN (Length: 718)
#   Matches at position 465 : EDFNKV
#   Found in: tr|Q5JVZ8|Q5JVZ8_HUMAN (Length: 267)
#   Matches at position 255 : EDFNKV
#   Found in: tr|Q5JW01|Q5JW01_HUMAN (Length: 283)
#   Matches at position 34 : EDFNKV
#   Found in: tr|Q68DE6|Q68DE6_HUMAN (Length: 1017)
#   Matches at position 87 : EDCVKV
#   Found in: tr|Q7Z330|Q7Z330_HUMAN (Length: 620)
#   Matches at position 202 : EDFVSV
#   Found in: tr|Q8IUS7|Q8IUS7_HUMAN (Length: 392)
#   Matches at position 288 : EDFVKS
#   Found in: tr|Q8WVE9|Q8WVE9_HUMAN (Length: 241)
#   Matches at position 149 : EDFKKV
#   Found in: tr|Q8WXT4|Q8WXT4_HUMAN (Length: 70)
#   Matches at position 42 : ECFVKV
#   Found in: tr|Q96HV8|Q96HV8_HUMAN (Length: 384)
#   Matches at position 254 : EDFVLV
#   Found in: tr|Q96NV5|Q96NV5_HUMAN (Length: 284)
#   Matches at position 192 : EDFKKV
#   Found in: tr|Q9BTG7|Q9BTG7_HUMAN (Length: 287)
#   Matches at position 157 : EDFVLV
# Protein: O14641_444 (Length: 6)
#   Found in: tr|A0A804HK20|A0A804HK20_HUMAN (Length: 1313)
#   Matches at position 134 : RMLKI
#   Found in: tr|A0A8J9ASM4|A0A8J9ASM4_HUMAN (Length: 59)
#   Matches at position 24 : RMWKI
#   Found in: tr|A0A976XH31|A0A976XH31_HUMAN (Length: 1738)
#   Matches at position 1572 : RMWLKK
#   Found in: tr|B3KP17|B3KP17_HUMAN (Length: 481)
#   Matches at position 315 : RMWLKK
#   Found in: tr|B3KTN8|B3KTN8_HUMAN (Length: 353)
#   Matches at position 90 : DRMWLKI
#   Matches at position 91 : RMWLKI
#   Matches at position 92 : MWLKI
#   Found in: tr|B3KX38|B3KX38_HUMAN (Length: 932)
#   Matches at position 766 : RMWLKK
#   Found in: tr|B3KX53|B3KX53_HUMAN (Length: 634)
#   Matches at position 468 : RMWLKK
#   Found in: tr|B4DLQ0|B4DLQ0_HUMAN (Length: 730)
#   Matches at position 434 : DRMWLKI
#   Matches at position 435 : RMWLKI
#   Matches at position 436 : MWLKI
#   Found in: tr|B4DVA8|B4DVA8_HUMAN (Length: 580)
#   Matches at position 392 : RGWLKI
#   Found in: tr|B4DYC8|B4DYC8_HUMAN (Length: 486)
#   Matches at position 469 : RMILKI
#   Found in: tr|B4E2D6|B4E2D6_HUMAN (Length: 717)
#   Matches at position 421 : DRMWLKI
#   Matches at position 422 : RMWLKI
#   Matches at position 423 : MWLKI
#   Found in: tr|B7Z1E8|B7Z1E8_HUMAN (Length: 619)
#   Matches at position 356 : DRMWLKI
#   Matches at position 357 : RMWLKI
#   Matches at position 358 : MWLKI
#   Found in: tr|B7Z6B5|B7Z6B5_HUMAN (Length: 281)
#   Matches at position 18 : DRMWLKI
#   Matches at position 19 : RMWLKI
#   Matches at position 20 : MWLKI
#   Found in: tr|F8WEA7|F8WEA7_HUMAN (Length: 59)
#   Matches at position 53 : RWLKI
#   Found in: tr|F8WEH2|F8WEH2_HUMAN (Length: 63)
#   Matches at position 24 : RMWKI
#   Found in: tr|I3L0Z8|I3L0Z8_HUMAN (Length: 300)
#   Matches at position 94 : DRMWLKI
#   Matches at position 95 : RMWLKI
#   Matches at position 96 : MWLKI
#   Found in: tr|K7EMN7|K7EMN7_HUMAN (Length: 181)
#   Matches at position 147 : RMWLNI
#   Found in: tr|L8E6Z9|L8E6Z9_HUMAN (Length: 139)
#   Matches at position 82 : RKWLKI
#   Found in: tr|Q13518|Q13518_HUMAN (Length: 457)
#   Matches at position 177 : DRMWLKI
#   Matches at position 178 : RMWLKI
#   Matches at position 179 : MWLKI
#   Found in: tr|Q59G99|Q59G99_HUMAN (Length: 387)
#   Matches at position 167 : DRMWLKI
#   Matches at position 168 : RMWLKI
#   Matches at position 169 : MWLKI
#   Found in: sp|Q6IC83|CV042_HUMAN (Length: 251)
#   Matches at position 84 : RWLKI
#   Found in: tr|Q6PJD6|Q6PJD6_HUMAN (Length: 531)
#   Matches at position 331 : DRMWLKI
#   Matches at position 332 : RMWLKI
#   Matches at position 333 : MWLKI
#   Found in: tr|Q8NA39|Q8NA39_HUMAN (Length: 412)
#   Matches at position 149 : DRMWLKI
#   Matches at position 150 : RMWLKI
#   Matches at position 151 : MWLKI
#   Found in: tr|Q8WVA8|Q8WVA8_HUMAN (Length: 608)
#   Matches at position 321 : DRMWLKI
#   Matches at position 322 : RMWLKI
#   Matches at position 323 : MWLKI
#   Found in: tr|Q9HB74|Q9HB74_HUMAN (Length: 171)
#   Matches at position 154 : RMILKI
#   Found in: tr|Q9UG07|Q9UG07_HUMAN (Length: 548)
#   Matches at position 261 : DRMWLKI
#   Matches at position 262 : RMWLKI
#   Matches at position 263 : MWLKI
# Protein: O15040_1408 (Length: 6)
#   Found in: tr|A0A804HJV5|A0A804HJV5_HUMAN (Length: 1640)
#   Matches at position 1591 : DEEVI
#   Found in: tr|A0A8C8UYX0|A0A8C8UYX0_HUMAN (Length: 1460)
#   Matches at position 214 : DEEVI
#   Found in: tr|A0A8I5KT99|A0A8I5KT99_HUMAN (Length: 1747)
#   Matches at position 1698 : DEEVI
#   Found in: tr|A0A8I5KV92|A0A8I5KV92_HUMAN (Length: 1895)
#   Matches at position 1846 : DEEVI
#   Found in: tr|A0A8I5QJH9|A0A8I5QJH9_HUMAN (Length: 1633)
#   Matches at position 1584 : DEEVI
#   Found in: tr|A0A8J9G7U8|A0A8J9G7U8_HUMAN (Length: 1641)
#   Matches at position 1592 : DEEVI
#   Found in: tr|A0AAA9Y9D9|A0AAA9Y9D9_HUMAN (Length: 1281)
#   Matches at position 117 : DEEVI
#   Found in: tr|A2IB45|A2IB45_HUMAN (Length: 925)
#   Matches at position 363 : DRWEVI
#   Found in: tr|A8K3E7|A8K3E7_HUMAN (Length: 664)
#   Matches at position 78 : DEEVI
#   Found in: tr|A8K6L2|A8K6L2_HUMAN (Length: 639)
#   Matches at position 128 : DEEVI
#   Found in: tr|B1AKL4|B1AKL4_HUMAN (Length: 961)
#   Matches at position 274 : DEVEVI
#   Found in: tr|B3KMB9|B3KMB9_HUMAN (Length: 664)
#   Matches at position 78 : DEEVI
#   Found in: tr|B3KN94|B3KN94_HUMAN (Length: 557)
#   Matches at position 258 : DELEVI
#   Found in: tr|B3KQF8|B3KQF8_HUMAN (Length: 881)
#   Matches at position 116 : DESEVI
#   Found in: tr|B3KS82|B3KS82_HUMAN (Length: 779)
#   Matches at position 143 : DELEVI
#   Found in: tr|B3KSZ8|B3KSZ8_HUMAN (Length: 655)
#   Matches at position 195 : DEDEVI
#   Found in: tr|B4DH17|B4DH17_HUMAN (Length: 1189)
#   Matches at position 1140 : DEEVI
#   Found in: tr|B4DJ49|B4DJ49_HUMAN (Length: 443)
#   Matches at position 164 : DEAEVI
#   Found in: tr|B4DRL6|B4DRL6_HUMAN (Length: 702)
#   Matches at position 505 : DESEVI
#   Found in: tr|B4DSD3|B4DSD3_HUMAN (Length: 594)
#   Matches at position 587 : EDEWEVI
#   Matches at position 588 : DEWEVI
#   Matches at position 589 : EWEVI
#   Found in: tr|B4DT42|B4DT42_HUMAN (Length: 344)
#   Matches at position 128 : DEEVI
#   Found in: tr|B4DZE1|B4DZE1_HUMAN (Length: 1075)
#   Matches at position 1026 : DEEVI
#   Found in: tr|B4E2A2|B4E2A2_HUMAN (Length: 711)
#   Matches at position 513 : DESEVI
#   Found in: tr|B7Z1Q8|B7Z1Q8_HUMAN (Length: 527)
#   Matches at position 35 : DEEVI
#   Found in: tr|B7Z4J3|B7Z4J3_HUMAN (Length: 653)
#   Matches at position 128 : DEEVI
#   Found in: tr|B7Z977|B7Z977_HUMAN (Length: 515)
#   Matches at position 236 : DEAEVI
#   Found in: tr|B7ZKX1|B7ZKX1_HUMAN (Length: 1292)
#   Matches at position 133 : DEEVI
#   Found in: tr|E9PAP0|E9PAP0_HUMAN (Length: 285)
#   Matches at position 279 : DEWEVP
#   Found in: tr|F8VWV2|F8VWV2_HUMAN (Length: 144)
#   Matches at position 45 : DEEVI
#   Found in: tr|F8VXB0|F8VXB0_HUMAN (Length: 235)
#   Matches at position 78 : DEEVI
#   Found in: tr|F8W124|F8W124_HUMAN (Length: 61)
#   Matches at position 35 : DEEVI
#   Found in: tr|G8XWS9|G8XWS9_HUMAN (Length: 2733)
#   Matches at position 1161 : DEEEVI
#   Found in: tr|H0Y863|H0Y863_HUMAN (Length: 132)
#   Matches at position 33 : DEEVI
#   Found in: tr|H0YD18|H0YD18_HUMAN (Length: 73)
#   Matches at position 40 : DSWEVI
#   Found in: tr|H0YDE5|H0YDE5_HUMAN (Length: 1416)
#   Matches at position 809 : DEEVI
#   Found in: tr|H0YLX2|H0YLX2_HUMAN (Length: 1276)
#   Matches at position 117 : DEEVI
#   Found in: tr|H7C142|H7C142_HUMAN (Length: 87)
#   Matches at position 74 : FEWEVI
#   Matches at position 75 : EWEVI
#   Found in: tr|J3QLQ6|J3QLQ6_HUMAN (Length: 189)
#   Matches at position 167 : DEEVI
#   Found in: tr|J3QR28|J3QR28_HUMAN (Length: 271)
#   Matches at position 20 : DEEVI
#   Found in: tr|Q05BU1|Q05BU1_HUMAN (Length: 300)
#   Matches at position 17 : DEKEVI
#   Found in: tr|Q12914|Q12914_HUMAN (Length: 1692)
#   Matches at position 1085 : DEEVI
#   Found in: tr|Q2MKN9|Q2MKN9_HUMAN (Length: 81)
#   Matches at position 8 : DEWEVS
#   Found in: tr|Q2MKP0|Q2MKP0_HUMAN (Length: 81)
#   Matches at position 8 : DEWEVS
#   Found in: tr|Q2MKP1|Q2MKP1_HUMAN (Length: 81)
#   Matches at position 8 : DEWEVS
#   Found in: tr|Q2MKP2|Q2MKP2_HUMAN (Length: 81)
#   Matches at position 8 : DEWEVS
#   Found in: tr|Q2TAY9|Q2TAY9_HUMAN (Length: 124)
#   Matches at position 17 : DEEVI
#   Found in: tr|Q59GJ0|Q59GJ0_HUMAN (Length: 1780)
#   Matches at position 1731 : DEEVI
#   Found in: tr|Q5JRI8|Q5JRI8_HUMAN (Length: 82)
#   Matches at position 34 : DEEVI
#   Found in: tr|Q6AHZ7|Q6AHZ7_HUMAN (Length: 2109)
#   Matches at position 348 : DEEVI
#   Found in: tr|Q6AWA4|Q6AWA4_HUMAN (Length: 2112)
#   Matches at position 348 : DEEVI
#   Found in: tr|Q6PJR2|Q6PJR2_HUMAN (Length: 436)
#   Matches at position 274 : DEVEVI
#   Found in: tr|V9GYG5|V9GYG5_HUMAN (Length: 214)
#   Matches at position 164 : DEAEVI
#   Found in: tr|V9GZ14|V9GZ14_HUMAN (Length: 229)
#   Matches at position 164 : DEAEVI
# Protein: O15111_740 (Length: 6)
#   Found in: tr|A0A804HIC0|A0A804HIC0_HUMAN (Length: 655)
#   Matches at position 228 : LDWSL
#   Found in: tr|A0A804HKB9|A0A804HKB9_HUMAN (Length: 446)
#   Matches at position 228 : LDWSL
#   Found in: tr|A0A804HL21|A0A804HL21_HUMAN (Length: 608)
#   Matches at position 228 : LDWSL
#   Found in: tr|A0A804HLJ8|A0A804HLJ8_HUMAN (Length: 1508)
#   Matches at position 1093 : LDKSWL
#   Found in: tr|A1L159|A1L159_HUMAN (Length: 132)
#   Matches at position 111 : ALDWSWL
#   Matches at position 112 : LDWSWL
#   Matches at position 113 : DWSWL
#   Found in: tr|A6H8W6|A6H8W6_HUMAN (Length: 1803)
#   Matches at position 1676 : LDWSNL
#   Found in: tr|A6PVK7|A6PVK7_HUMAN (Length: 1370)
#   Matches at position 955 : LDKSWL
#   Found in: tr|B3KRB7|B3KRB7_HUMAN (Length: 533)
#   Matches at position 512 : ALDWSWL
#   Matches at position 513 : LDWSWL
#   Matches at position 514 : DWSWL
#   Found in: tr|B4DE53|B4DE53_HUMAN (Length: 849)
#   Matches at position 228 : LDWSL
#   Found in: tr|B4DG75|B4DG75_HUMAN (Length: 237)
#   Matches at position 99 : LDISWL
#   Found in: tr|B4DYX7|B4DYX7_HUMAN (Length: 1257)
#   Matches at position 1130 : LDWSNL
#   Found in: tr|C9J164|C9J164_HUMAN (Length: 594)
#   Matches at position 309 : LDWSL
#   Found in: tr|C9J222|C9J222_HUMAN (Length: 165)
#   Matches at position 99 : LDISWL
#   Found in: tr|C9JF34|C9JF34_HUMAN (Length: 159)
#   Matches at position 99 : LDISWL
#   Found in: tr|D6RBJ8|D6RBJ8_HUMAN (Length: 261)
#   Matches at position 254 : LWSWL
#   Found in: tr|F8WB78|F8WB78_HUMAN (Length: 168)
#   Matches at position 99 : LDISWL
#   Found in: tr|F8WDE4|F8WDE4_HUMAN (Length: 233)
#   Matches at position 99 : LDISWL
#   Found in: tr|F8WEJ1|F8WEJ1_HUMAN (Length: 155)
#   Matches at position 99 : LDISWL
#   Found in: tr|H7C363|H7C363_HUMAN (Length: 185)
#   Matches at position 175 : LDWSSL
#   Found in: tr|I6L959|I6L959_HUMAN (Length: 750)
#   Matches at position 228 : LDWSL
#   Found in: tr|I6L9B7|I6L9B7_HUMAN (Length: 227)
#   Matches at position 112 : ADWSWL
#   Matches at position 113 : DWSWL
#   Found in: tr|Q59HD0|Q59HD0_HUMAN (Length: 701)
#   Matches at position 519 : LDWSL
#   Found in: tr|Q5CZ77|Q5CZ77_HUMAN (Length: 355)
#   Matches at position 227 : LDWSNL
#   Found in: tr|Q6P084|Q6P084_HUMAN (Length: 234)
#   Matches at position 207 : LDSWL
#   Found in: tr|Q6ZU10|Q6ZU10_HUMAN (Length: 1058)
#   Matches at position 643 : LDKSWL
#   Found in: tr|Q96LK1|Q96LK1_HUMAN (Length: 328)
#   Matches at position 317 : LDWSL
# Protein: O15111_651 (Length: 6)
#   Found in: tr|A0A804HJV5|A0A804HJV5_HUMAN (Length: 1640)
#   Matches at position 1412 : EILHLL
#   Found in: tr|A0A804HKK8|A0A804HKK8_HUMAN (Length: 37)
#   Matches at position 27 : EIHLL
#   Found in: tr|A0A8I5KT99|A0A8I5KT99_HUMAN (Length: 1747)
#   Matches at position 1519 : EILHLL
#   Found in: tr|A0A8I5KV92|A0A8I5KV92_HUMAN (Length: 1895)
#   Matches at position 1667 : EILHLL
#   Found in: tr|A0A8I5QJH9|A0A8I5QJH9_HUMAN (Length: 1633)
#   Matches at position 1405 : EILHLL
#   Found in: tr|A0A8J9G7U8|A0A8J9G7U8_HUMAN (Length: 1641)
#   Matches at position 1413 : EILHLL
#   Found in: tr|A0A9L9PXF3|A0A9L9PXF3_HUMAN (Length: 1235)
#   Matches at position 367 : EIRHLL
#   Found in: tr|A0A9L9PY96|A0A9L9PY96_HUMAN (Length: 644)
#   Matches at position 145 : EIRHLL
#   Found in: tr|A0AAQ5BHR1|A0AAQ5BHR1_HUMAN (Length: 558)
#   Matches at position 86 : EIRHLL
#   Found in: tr|A0AAQ5BHX1|A0AAQ5BHX1_HUMAN (Length: 433)
#   Matches at position 142 : EIHLL
#   Found in: tr|A0AAQ5BI40|A0AAQ5BI40_HUMAN (Length: 536)
#   Matches at position 142 : EIHLL
#   Found in: tr|A4D1A3|A4D1A3_HUMAN (Length: 109)
#   Matches at position 95 : EIWHTL
#   Found in: tr|A8K8Y2|A8K8Y2_HUMAN (Length: 249)
#   Matches at position 1 : EIKHLL
#   Found in: tr|B0YIV3|B0YIV3_HUMAN (Length: 765)
#   Matches at position 606 : EIIHLL
#   Found in: tr|B3KP42|B3KP42_HUMAN (Length: 390)
#   Matches at position 144 : EIWLL
#   Found in: tr|B4DEV5|B4DEV5_HUMAN (Length: 737)
#   Matches at position 669 : EIWLL
#   Found in: tr|B4DFT3|B4DFT3_HUMAN (Length: 426)
#   Matches at position 358 : EIWLL
#   Found in: tr|B4DH17|B4DH17_HUMAN (Length: 1189)
#   Matches at position 961 : EILHLL
#   Found in: tr|B4DM19|B4DM19_HUMAN (Length: 488)
#   Matches at position 219 : EISHLL
#   Found in: tr|B4DQ82|B4DQ82_HUMAN (Length: 365)
#   Matches at position 147 : EIAHLL
#   Found in: tr|B4DWT8|B4DWT8_HUMAN (Length: 420)
#   Matches at position 174 : EIWLL
#   Found in: tr|B4DZE1|B4DZE1_HUMAN (Length: 1075)
#   Matches at position 847 : EILHLL
#   Found in: tr|B4DZF1|B4DZF1_HUMAN (Length: 512)
#   Matches at position 219 : EISHLL
#   Found in: tr|B4DZY2|B4DZY2_HUMAN (Length: 405)
#   Matches at position 159 : EIWLL
#   Found in: tr|B4E1N9|B4E1N9_HUMAN (Length: 841)
#   Matches at position 31 : EIWSLL
#   Found in: tr|B7SIX5|B7SIX5_HUMAN (Length: 52)
#   Matches at position 28 : EIRHLL
#   Found in: tr|B7Z218|B7Z218_HUMAN (Length: 669)
#   Matches at position 208 : EITHLL
#   Found in: tr|B7Z347|B7Z347_HUMAN (Length: 746)
#   Matches at position 282 : EITHLL
#   Found in: tr|B7Z3G5|B7Z3G5_HUMAN (Length: 786)
#   Matches at position 282 : EITHLL
#   Found in: tr|B7ZAE5|B7ZAE5_HUMAN (Length: 745)
#   Matches at position 282 : EITHLL
#   Found in: tr|B8ZZI7|B8ZZI7_HUMAN (Length: 1119)
#   Matches at position 495 : EIWYLL
#   Found in: tr|C9JC32|C9JC32_HUMAN (Length: 895)
#   Matches at position 224 : EITHLL
#   Found in: tr|E9PBE2|E9PBE2_HUMAN (Length: 79)
#   Matches at position 28 : EIRHLL
#   Found in: tr|E9PG69|E9PG69_HUMAN (Length: 117)
#   Matches at position 28 : EIRHLL
#   Found in: tr|F5H3M3|F5H3M3_HUMAN (Length: 350)
#   Matches at position 132 : EIAHLL
#   Found in: tr|F5H5A1|F5H5A1_HUMAN (Length: 311)
#   Matches at position 224 : EWHLL
#   Found in: tr|F5H755|F5H755_HUMAN (Length: 235)
#   Matches at position 224 : EWHLL
#   Found in: tr|F5H7B7|F5H7B7_HUMAN (Length: 2366)
#   Matches at position 430 : EILHLL
#   Found in: tr|F6X344|F6X344_HUMAN (Length: 567)
#   Matches at position 316 : EIQHLL
#   Found in: tr|F8WAI8|F8WAI8_HUMAN (Length: 1127)
#   Matches at position 529 : EICHLL
#   Found in: tr|G3V370|G3V370_HUMAN (Length: 154)
#   Matches at position 142 : EIHLL
#   Found in: tr|G3V399|G3V399_HUMAN (Length: 150)
#   Matches at position 44 : EVWHLL
#   Found in: tr|G3V3C8|G3V3C8_HUMAN (Length: 102)
#   Matches at position 44 : EVWHLL
#   Found in: tr|G3V3H9|G3V3H9_HUMAN (Length: 112)
#   Matches at position 44 : EVWHLL
#   Found in: tr|G3V5K0|G3V5K0_HUMAN (Length: 61)
#   Matches at position 44 : EVWHLL
#   Found in: tr|G3V5K5|G3V5K5_HUMAN (Length: 159)
#   Matches at position 142 : EIHLL
#   Found in: tr|H0YBC9|H0YBC9_HUMAN (Length: 497)
#   Matches at position 351 : EIWLL
#   Found in: tr|H0YBG5|H0YBG5_HUMAN (Length: 312)
#   Matches at position 249 : EIKHLL
#   Found in: tr|H0YGN5|H0YGN5_HUMAN (Length: 161)
#   Matches at position 117 : EIHLL
#   Found in: tr|H0YHR1|H0YHR1_HUMAN (Length: 222)
#   Matches at position 40 : EIWGLL
#   Found in: tr|H7C0I5|H7C0I5_HUMAN (Length: 140)
#   Matches at position 96 : EIHLL
#   Found in: tr|H7C162|H7C162_HUMAN (Length: 396)
#   Matches at position 329 : EIRHLL
#   Found in: tr|H7C3T3|H7C3T3_HUMAN (Length: 300)
#   Matches at position 25 : EITHLL
#   Found in: tr|K7EIX2|K7EIX2_HUMAN (Length: 1069)
#   Matches at position 50 : EIHLL
#   Found in: tr|K7EK31|K7EK31_HUMAN (Length: 184)
#   Matches at position 50 : EIHLL
#   Found in: tr|K7EKW7|K7EKW7_HUMAN (Length: 114)
#   Matches at position 50 : EIHLL
#   Found in: tr|K7ELB5|K7ELB5_HUMAN (Length: 309)
#   Matches at position 269 : EIWELL
#   Found in: tr|K7ELR8|K7ELR8_HUMAN (Length: 413)
#   Matches at position 50 : EIHLL
#   Found in: tr|K7ESP5|K7ESP5_HUMAN (Length: 213)
#   Matches at position 50 : EIHLL
#   Found in: tr|L0R6S8|L0R6S8_HUMAN (Length: 65)
#   Matches at position 50 : EIHLL
#   Found in: tr|M0QZ16|M0QZ16_HUMAN (Length: 180)
#   Matches at position 149 : EIWYLL
#   Found in: tr|M0QZM4|M0QZM4_HUMAN (Length: 95)
#   Matches at position 75 : EIWLL
#   Found in: tr|Q1RMZ5|Q1RMZ5_HUMAN (Length: 1127)
#   Matches at position 529 : EICHLL
#   Found in: tr|Q32MQ2|Q32MQ2_HUMAN (Length: 987)
#   Matches at position 363 : EIWYLL
#   Found in: tr|Q53RU2|Q53RU2_HUMAN (Length: 91)
#   Matches at position 28 : EIRHLL
#   Found in: tr|Q59EK8|Q59EK8_HUMAN (Length: 107)
#   Matches at position 34 : EIIHLL
#   Found in: tr|Q59GJ0|Q59GJ0_HUMAN (Length: 1780)
#   Matches at position 1552 : EILHLL
#   Found in: tr|Q6P2C7|Q6P2C7_HUMAN (Length: 386)
#   Matches at position 299 : EWHLL
#   Found in: tr|Q7Z4Q3|Q7Z4Q3_HUMAN (Length: 292)
#   Matches at position 7 : EIHLL
#   Found in: tr|Q8N2Z6|Q8N2Z6_HUMAN (Length: 298)
#   Matches at position 13 : EIHLL
#   Found in: tr|Q9H8B9|Q9H8B9_HUMAN (Length: 774)
#   Matches at position 290 : EIHLL
#   Found in: tr|S4R3D3|S4R3D3_HUMAN (Length: 134)
#   Matches at position 97 : EIWELL
#   Found in: tr|X1WI24|X1WI24_HUMAN (Length: 660)
#   Matches at position 535 : EIWYLL
# Protein: O15111_275 (Length: 6)
#   Found in: tr|A0A7S5EXY2|A0A7S5EXY2_HUMAN (Length: 119)
#   Matches at position 100 : EWLQL
#   Found in: tr|A1A4T0|A1A4T0_HUMAN (Length: 462)
#   Matches at position 192 : ENLQL
#   Found in: tr|A1L378|A1L378_HUMAN (Length: 1002)
#   Matches at position 201 : ENFLQL
#   Found in: tr|A6NHJ8|A6NHJ8_HUMAN (Length: 325)
#   Matches at position 286 : ENLQL
#   Found in: tr|A6NMA8|A6NMA8_HUMAN (Length: 334)
#   Matches at position 247 : ENLQL
#   Found in: tr|A6NND8|A6NND8_HUMAN (Length: 322)
#   Matches at position 262 : ENLQL
#   Found in: tr|A8K5H1|A8K5H1_HUMAN (Length: 650)
#   Matches at position 108 : ENLQL
#   Found in: tr|B0QYK8|B0QYK8_HUMAN (Length: 74)
#   Matches at position 22 : ENLLQL
#   Found in: tr|B2R5V0|B2R5V0_HUMAN (Length: 614)
#   Matches at position 257 : ENWLL
#   Found in: tr|B3KM49|B3KM49_HUMAN (Length: 133)
#   Matches at position 21 : ENLQL
#   Found in: tr|B3KPG1|B3KPG1_HUMAN (Length: 648)
#   Matches at position 108 : ENLQL
#   Found in: tr|B3KRB7|B3KRB7_HUMAN (Length: 533)
#   Matches at position 50 : EKWLQL
#   Found in: tr|B3KT35|B3KT35_HUMAN (Length: 901)
#   Matches at position 674 : ENLQL
#   Found in: tr|B4DF87|B4DF87_HUMAN (Length: 514)
#   Matches at position 157 : ENWLL
#   Found in: tr|B4DJ01|B4DJ01_HUMAN (Length: 546)
#   Matches at position 227 : ENWLQH
#   Found in: tr|B4DK03|B4DK03_HUMAN (Length: 504)
#   Matches at position 42 : ENLQL
#   Found in: tr|B4DMF7|B4DMF7_HUMAN (Length: 520)
#   Matches at position 225 : ENLQL
#   Found in: tr|B4DMR6|B4DMR6_HUMAN (Length: 350)
#   Matches at position 289 : ENWLL
#   Found in: tr|B4DMT0|B4DMT0_HUMAN (Length: 424)
#   Matches at position 363 : ENWLL
#   Found in: tr|B4DNG0|B4DNG0_HUMAN (Length: 345)
#   Matches at position 174 : ENTLQL
#   Found in: tr|B4DPF8|B4DPF8_HUMAN (Length: 394)
#   Matches at position 333 : ENWLL
#   Found in: tr|B4DS81|B4DS81_HUMAN (Length: 351)
#   Matches at position 56 : ENLQL
#   Found in: tr|B4DST9|B4DST9_HUMAN (Length: 129)
#   Matches at position 77 : ENPLQL
#   Found in: tr|B4DU56|B4DU56_HUMAN (Length: 616)
#   Matches at position 76 : ENLQL
#   Found in: tr|B4DZ85|B4DZ85_HUMAN (Length: 448)
#   Matches at position 91 : ENWLL
#   Found in: tr|B4E0D8|B4E0D8_HUMAN (Length: 1134)
#   Matches at position 606 : ENGLQL
#   Found in: tr|B4E0L9|B4E0L9_HUMAN (Length: 574)
#   Matches at position 32 : ENLQL
#   Found in: tr|B4E1P7|B4E1P7_HUMAN (Length: 150)
#   Matches at position 39 : ENLQL
#   Found in: tr|B7Z3Q0|B7Z3Q0_HUMAN (Length: 121)
#   Matches at position 32 : ENTLQL
#   Found in: tr|B9EGB3|B9EGB3_HUMAN (Length: 645)
#   Matches at position 108 : ENLQL
#   Found in: tr|C9IZS8|C9IZS8_HUMAN (Length: 510)
#   Matches at position 32 : ENLQL
#   Found in: tr|C9J6Q2|C9J6Q2_HUMAN (Length: 167)
#   Matches at position 56 : QNWLQL
#   Matches at position 57 : NWLQL
#   Found in: tr|C9JA15|C9JA15_HUMAN (Length: 113)
#   Matches at position 56 : QNWLQL
#   Matches at position 57 : NWLQL
#   Found in: tr|C9JAW0|C9JAW0_HUMAN (Length: 142)
#   Matches at position 56 : QNWLQL
#   Matches at position 57 : NWLQL
#   Found in: tr|C9JBS6|C9JBS6_HUMAN (Length: 142)
#   Matches at position 115 : ENWLQH
#   Found in: tr|C9JKP8|C9JKP8_HUMAN (Length: 181)
#   Matches at position 14 : ENILQL
#   Found in: tr|C9JYQ2|C9JYQ2_HUMAN (Length: 183)
#   Matches at position 97 : ENLQL
#   Found in: tr|D4YW74|D4YW74_HUMAN (Length: 6825)
#   Matches at position 5837 : ENKLQL
#   Found in: tr|E7EPJ1|E7EPJ1_HUMAN (Length: 462)
#   Matches at position 192 : ENLQL
#   Found in: tr|E9PBT5|E9PBT5_HUMAN (Length: 969)
#   Matches at position 904 : ENFLQL
#   Found in: tr|E9PJB6|E9PJB6_HUMAN (Length: 152)
#   Matches at position 39 : ENLQL
#   Found in: tr|E9PM95|E9PM95_HUMAN (Length: 128)
#   Matches at position 22 : ENLLQL
#   Found in: tr|E9PPG4|E9PPG4_HUMAN (Length: 157)
#   Matches at position 81 : ENWLL
#   Found in: tr|E9PSC0|E9PSC0_HUMAN (Length: 126)
#   Matches at position 39 : ENLQL
#   Found in: tr|F5GXA4|F5GXA4_HUMAN (Length: 1002)
#   Matches at position 201 : ENFLQL
#   Found in: tr|F5H2M4|F5H2M4_HUMAN (Length: 574)
#   Matches at position 32 : ENLQL
#   Found in: tr|F8VZ98|F8VZ98_HUMAN (Length: 117)
#   Matches at position 33 : ENILQL
#   Found in: tr|F8W737|F8W737_HUMAN (Length: 124)
#   Matches at position 36 : EKWLQL
#   Found in: tr|F8WBX4|F8WBX4_HUMAN (Length: 423)
#   Matches at position 36 : EKWLQL
#   Found in: tr|F8WD48|F8WD48_HUMAN (Length: 303)
#   Matches at position 36 : EKWLQL
#   Found in: tr|F8WD56|F8WD56_HUMAN (Length: 101)
#   Matches at position 36 : EKWLQL
#   Found in: tr|G3CAT1|G3CAT1_HUMAN (Length: 335)
#   Matches at position 236 : ENWLL
#   Found in: tr|G3CAT2|G3CAT2_HUMAN (Length: 302)
#   Matches at position 236 : ENWLL
#   Found in: tr|G3V1N5|G3V1N5_HUMAN (Length: 753)
#   Matches at position 695 : ENLQL
#   Found in: tr|G3V4T3|G3V4T3_HUMAN (Length: 1127)
#   Matches at position 943 : ENKLQL
#   Found in: tr|G4VTY1|G4VTY1_HUMAN (Length: 283)
#   Matches at position 236 : ENWLL
#   Found in: tr|H3BNN7|H3BNN7_HUMAN (Length: 110)
#   Matches at position 101 : EWLQL
#   Found in: tr|H3BS30|H3BS30_HUMAN (Length: 84)
#   Matches at position 75 : EWLQL
#   Found in: tr|H3BV08|H3BV08_HUMAN (Length: 169)
#   Matches at position 160 : EWLQL
#   Found in: tr|H7C0F7|H7C0F7_HUMAN (Length: 119)
#   Matches at position 54 : ENFLQL
#   Found in: tr|H7C0X3|H7C0X3_HUMAN (Length: 111)
#   Matches at position 37 : ENLQL
#   Found in: tr|H7C436|H7C436_HUMAN (Length: 118)
#   Matches at position 94 : ENLQL
#   Found in: tr|J3QLH1|J3QLH1_HUMAN (Length: 228)
#   Matches at position 211 : ENLQL
#   Found in: tr|J3QLW7|J3QLW7_HUMAN (Length: 110)
#   Matches at position 21 : ENLQL
#   Found in: tr|J3QQI0|J3QQI0_HUMAN (Length: 149)
#   Matches at position 1 : ENLQL
#   Found in: tr|K7EIV0|K7EIV0_HUMAN (Length: 196)
#   Matches at position 187 : EWLQL
#   Found in: tr|K7EKD8|K7EKD8_HUMAN (Length: 238)
#   Matches at position 229 : EWLQL
#   Found in: tr|K7ELJ7|K7ELJ7_HUMAN (Length: 278)
#   Matches at position 269 : EWLQL
#   Found in: tr|K7EMQ1|K7EMQ1_HUMAN (Length: 94)
#   Matches at position 85 : EWLQL
#   Found in: tr|L8E861|L8E861_HUMAN (Length: 69)
#   Matches at position 44 : ENWQL
#   Found in: tr|L8E8W9|L8E8W9_HUMAN (Length: 51)
#   Matches at position 35 : ELWLQL
#   Found in: tr|M0QZS3|M0QZS3_HUMAN (Length: 130)
#   Matches at position 76 : ENLQL
#   Found in: tr|M0R0N1|M0R0N1_HUMAN (Length: 132)
#   Matches at position 32 : ENLQL
#   Found in: tr|M0R186|M0R186_HUMAN (Length: 185)
#   Matches at position 18 : ENLQL
#   Found in: tr|M0R1H8|M0R1H8_HUMAN (Length: 325)
#   Matches at position 179 : ENLQL
#   Found in: tr|O14997|O14997_HUMAN (Length: 709)
#   Matches at position 307 : ENLQL
#   Found in: tr|Q05CD9|Q05CD9_HUMAN (Length: 481)
#   Matches at position 301 : ENWLL
#   Found in: tr|Q05DF5|Q05DF5_HUMAN (Length: 483)
#   Matches at position 301 : ENWLL
#   Found in: tr|Q3KZ26|Q3KZ26_HUMAN (Length: 29)
#   Matches at position 2 : GNWLQL
#   Matches at position 3 : NWLQL
#   Found in: tr|Q496N2|Q496N2_HUMAN (Length: 156)
#   Matches at position 147 : EWLQL
#   Found in: tr|Q5IRA6|Q5IRA6_HUMAN (Length: 53)
#   Matches at position 2 : GNWLQL
#   Matches at position 3 : NWLQL
#   Found in: tr|Q5T376|Q5T376_HUMAN (Length: 525)
#   Matches at position 104 : LNWLQL
#   Matches at position 105 : NWLQL
#   Found in: tr|Q6DCA5|Q6DCA5_HUMAN (Length: 887)
#   Matches at position 379 : ENLQL
#   Found in: tr|Q6PAV0|Q6PAV0_HUMAN (Length: 622)
#   Matches at position 382 : ENLQL
#   Found in: tr|Q6PEW6|Q6PEW6_HUMAN (Length: 307)
#   Matches at position 215 : QNWLQL
#   Matches at position 216 : NWLQL
#   Found in: tr|Q6ZNT6|Q6ZNT6_HUMAN (Length: 150)
#   Matches at position 31 : ENWLML
#   Found in: tr|Q7Z2E5|Q7Z2E5_HUMAN (Length: 383)
#   Matches at position 240 : ENLQL
#   Found in: tr|Q86YH1|Q86YH1_HUMAN (Length: 501)
#   Matches at position 382 : ENLQL
#   Found in: tr|Q8WVL4|Q8WVL4_HUMAN (Length: 100)
#   Matches at position 39 : ENLQL
#   Found in: tr|Q8WVU8|Q8WVU8_HUMAN (Length: 123)
#   Matches at position 78 : ENLQL
#   Found in: tr|Q96E88|Q96E88_HUMAN (Length: 575)
#   Matches at position 257 : ENWLL
#   Found in: tr|Q96SV4|Q96SV4_HUMAN (Length: 213)
#   Matches at position 155 : ENLQL
#   Found in: tr|Q9NW91|Q9NW91_HUMAN (Length: 450)
#   Matches at position 87 : LNWLQL
#   Matches at position 88 : NWLQL
#   Found in: tr|Q9UI01|Q9UI01_HUMAN (Length: 742)
#   Matches at position 307 : ENLQL
#   Found in: tr|S4R407|S4R407_HUMAN (Length: 303)
#   Matches at position 202 : ENSLQL
#   Found in: tr|V9HVY7|V9HVY7_HUMAN (Length: 586)
#   Matches at position 108 : ENLQL
# Protein: O15392_101 (Length: 6)
#   Found in: tr|A0A7S5BZ62|A0A7S5BZ62_HUMAN (Length: 125)
#   Matches at position 14 : GEFLKI
#   Found in: tr|A0A7S5BZA6|A0A7S5BZA6_HUMAN (Length: 120)
#   Matches at position 14 : GESLKL
#   Found in: tr|A0A8I5KQT2|A0A8I5KQT2_HUMAN (Length: 717)
#   Matches at position 47 : GELFLKL
#   Found in: tr|A0A8I5KRH2|A0A8I5KRH2_HUMAN (Length: 795)
#   Matches at position 163 : GELFLKL
#   Found in: tr|A0A8I5QJA0|A0A8I5QJA0_HUMAN (Length: 825)
#   Matches at position 193 : GELFLKL
# ...
#   Found in: tr|O95648|O95648_HUMAN (Length: 150)
#   Matches at position 20 : AGESGL
#   Found in: tr|Q2T9H3|Q2T9H3_HUMAN (Length: 333)
#   Matches at position 189 : AGYVSGL
#   Found in: tr|Q3B797|Q3B797_HUMAN (Length: 251)
#   Matches at position 78 : HAGYSGL
#   Matches at position 79 : AGYSGL
#   Matches at position 80 : GYSGL
#   Found in: tr|Q53GI2|Q53GI2_HUMAN (Length: 313)
#   Matches at position 23 : FAGYSGL
#   Matches at position 24 : AGYSGL
#   Matches at position 25 : GYSGL
#   Found in: tr|Q59FW4|Q59FW4_HUMAN (Length: 774)
#   Matches at position 283 : AGPSGL
#   Found in: tr|Q59G01|Q59G01_HUMAN (Length: 931)
#   Matches at position 137 : AGKSGL
#   Found in: tr|Q59GE1|Q59GE1_HUMAN (Length: 394)
#   Matches at position 74 : AGESGL
#   Found in: tr|Q59GS3|Q59GS3_HUMAN (Length: 345)
#   Matches at position 11 : AGSGL
#   Found in: tr|Q59H94|Q59H94_HUMAN (Length: 1342)
#   Matches at position 685 : AGYGGL
#   Found in: tr|Q60FE6|Q60FE6_HUMAN (Length: 2612)
#   Matches at position 2039 : AGYGGL
#   Found in: tr|Q658X7|Q658X7_HUMAN (Length: 231)
#   Matches at position 125 : AGGSGL
#   Found in: tr|Q659E9|Q659E9_HUMAN (Length: 755)
#   Matches at position 748 : AGSGL
#   Found in: tr|Q6INA3|Q6INA3_HUMAN (Length: 259)
#   Matches at position 16 : AGGSGL
#   Found in: tr|Q6N008|Q6N008_HUMAN (Length: 1569)
#   Matches at position 433 : AGSGL
#   Found in: tr|Q6NXF2|Q6NXF2_HUMAN (Length: 983)
#   Matches at position 410 : AGYGGL
#   Found in: tr|Q6NYC5|Q6NYC5_HUMAN (Length: 1064)
#   Matches at position 634 : AGYSTL
#   Found in: tr|Q6ZMW8|Q6ZMW8_HUMAN (Length: 1103)
#   Matches at position 191 : AGYSL
#   Found in: tr|Q6ZN29|Q6ZN29_HUMAN (Length: 907)
#   Matches at position 395 : AGYSL
#   Found in: tr|Q6ZT96|Q6ZT96_HUMAN (Length: 339)
#   Matches at position 63 : AGESGL
#   Found in: tr|Q6ZW97|Q6ZW97_HUMAN (Length: 243)
#   Matches at position 174 : AGHSGL
#   Found in: tr|Q71RA9|Q71RA9_HUMAN (Length: 272)
#   Matches at position 106 : AGHSGL
#   Found in: tr|Q75LH2|Q75LH2_HUMAN (Length: 383)
#   Matches at position 32 : AGDSGL
#   Found in: tr|Q7KYV2|Q7KYV2_HUMAN (Length: 385)
#   Matches at position 65 : AGESGL
#   Found in: tr|Q86TI6|Q86TI6_HUMAN (Length: 347)
#   Matches at position 22 : AGGSGL
#   Found in: tr|Q8N6C1|Q8N6C1_HUMAN (Length: 387)
#   Matches at position 378 : AGSGL
#   Found in: tr|Q8NI96|Q8NI96_HUMAN (Length: 71)
#   Matches at position 42 : ATYSGL
#   Matches at position 58 : AGYSGQ
#   Found in: tr|Q8TES4|Q8TES4_HUMAN (Length: 1455)
#   Matches at position 882 : AGYGGL
#   Found in: tr|Q8WUU1|Q8WUU1_HUMAN (Length: 373)
#   Matches at position 18 : AGCSGL
#   Found in: tr|Q8WY15|Q8WY15_HUMAN (Length: 698)
#   Matches at position 223 : GGYSGL
#   Matches at position 224 : GYSGL
#   Found in: tr|Q8WZ27|Q8WZ27_HUMAN (Length: 180)
#   Matches at position 128 : AGSGL
#   Found in: tr|Q96C61|Q96C61_HUMAN (Length: 838)
#   Matches at position 265 : AGYGGL
#   Found in: tr|Q9HB28|Q9HB28_HUMAN (Length: 133)
#   Matches at position 75 : AGYGL
#   Found in: tr|Q9NT80|Q9NT80_HUMAN (Length: 269)
#   Matches at position 186 : AGSGL
#   Found in: tr|Q9NUX9|Q9NUX9_HUMAN (Length: 289)
#   Matches at position 94 : AGLSGL
#   Found in: tr|X5DNA9|X5DNA9_HUMAN (Length: 369)
#   Matches at position 49 : AGESGL
#   Found in: tr|X5DQL7|X5DQL7_HUMAN (Length: 124)
#   Matches at position 49 : AGESGL
# Protein: Q9Y6K9_340 (Length: 6)
#   Found in: tr|A0A7P0Z4M6|A0A7P0Z4M6_HUMAN (Length: 1564)
#   Matches at position 703 : RFYSKL
#   Found in: tr|A0A8I5KVS6|A0A8I5KVS6_HUMAN (Length: 461)
#   Matches at position 230 : RELSKL
#   Found in: tr|A0A8I5KW48|A0A8I5KW48_HUMAN (Length: 671)
#   Matches at position 230 : RELSKL
#   Found in: tr|A0A8I5QL30|A0A8I5QL30_HUMAN (Length: 468)
#   Matches at position 230 : RELSKL
#   Found in: tr|A0A8V8TQ09|A0A8V8TQ09_HUMAN (Length: 1110)
#   Matches at position 650 : REYDKL
#   Found in: tr|A0A8V8TQJ6|A0A8V8TQJ6_HUMAN (Length: 799)
#   Matches at position 696 : REYDKL
#   Found in: tr|A0A8V8TQJ8|A0A8V8TQJ8_HUMAN (Length: 1156)
#   Matches at position 696 : REYDKL
#   Found in: tr|A0A994J480|A0A994J480_HUMAN (Length: 101)
#   Matches at position 36 : REYKL
#   Found in: tr|A0AAQ5BGU0|A0AAQ5BGU0_HUMAN (Length: 1107)
#   Matches at position 25 : REYSKT
#   Found in: tr|A0AAQ5BGW2|A0AAQ5BGW2_HUMAN (Length: 1095)
#   Matches at position 25 : REYSKT
#   Found in: tr|A0AAQ5BGY0|A0AAQ5BGY0_HUMAN (Length: 866)
#   Matches at position 25 : REYSKT
#   Found in: tr|A0JP02|A0JP02_HUMAN (Length: 874)
#   Matches at position 477 : REYDKL
#   Found in: tr|A4VCI6|A4VCI6_HUMAN (Length: 517)
#   Matches at position 168 : RYSKL
#   Found in: tr|A6NLG9|A6NLG9_HUMAN (Length: 307)
#   Matches at position 189 : RYSKL
#   Found in: tr|A8K4R4|A8K4R4_HUMAN (Length: 1104)
#   Matches at position 703 : RFYSKL
#   Found in: tr|B0YJ47|B0YJ47_HUMAN (Length: 1016)
#   Matches at position 301 : REYKKL
#   Found in: tr|B1AJZ2|B1AJZ2_HUMAN (Length: 2270)
#   Matches at position 79 : REYSKA
#   Found in: tr|B2RAR0|B2RAR0_HUMAN (Length: 565)
#   Matches at position 221 : REMSKL
#   Found in: tr|B2RB53|B2RB53_HUMAN (Length: 377)
#   Matches at position 239 : REYKL
#   Found in: tr|B3KMF4|B3KMF4_HUMAN (Length: 417)
#   Matches at position 5 : REYNKL
#   Found in: tr|B3KPJ0|B3KPJ0_HUMAN (Length: 576)
#   Matches at position 15 : RFYSKL
#   Found in: tr|B3KPW6|B3KPW6_HUMAN (Length: 1070)
#   Matches at position 20 : REYLKL
#   Found in: tr|B3KSA6|B3KSA6_HUMAN (Length: 504)
#   Matches at position 198 : REYNKL
#   Found in: tr|B3VS25|B3VS25_HUMAN (Length: 65)
#   Matches at position 21 : RELSKL
#   Found in: tr|B4DDN7|B4DDN7_HUMAN (Length: 216)
#   Matches at position 98 : RYSKL
#   Found in: tr|B4DDQ2|B4DDQ2_HUMAN (Length: 334)
#   Matches at position 216 : RYSKL
#   Found in: tr|B4DFP0|B4DFP0_HUMAN (Length: 382)
#   Matches at position 275 : REDSKL
#   Found in: tr|B4DHK5|B4DHK5_HUMAN (Length: 1183)
#   Matches at position 822 : REYDKL
#   Found in: tr|B4DJY1|B4DJY1_HUMAN (Length: 153)
#   Matches at position 126 : REISKL
#   Found in: tr|B4DLI1|B4DLI1_HUMAN (Length: 403)
#   Matches at position 357 : RIYSKL
#   Found in: tr|B4DMB9|B4DMB9_HUMAN (Length: 914)
#   Matches at position 611 : REYDKL
#   Found in: tr|B4DN96|B4DN96_HUMAN (Length: 798)
#   Matches at position 702 : REYKL
#   Found in: tr|B4DP94|B4DP94_HUMAN (Length: 195)
#   Matches at position 40 : RESKL
#   Found in: tr|B4DQ44|B4DQ44_HUMAN (Length: 672)
#   Matches at position 667 : RESKL
#   Found in: tr|B4DRM0|B4DRM0_HUMAN (Length: 619)
#   Matches at position 503 : REKSKL
#   Found in: tr|B4DSH4|B4DSH4_HUMAN (Length: 405)
#   Matches at position 337 : RESKL
#   Found in: tr|B4DYD7|B4DYD7_HUMAN (Length: 644)
#   Matches at position 73 : RYSKL
#   Found in: tr|B4DYK7|B4DYK7_HUMAN (Length: 1347)
#   Matches at position 387 : REYSL
#   Found in: tr|B4E246|B4E246_HUMAN (Length: 572)
#   Matches at position 314 : REYEKL
#   Found in: tr|B7Z2F0|B7Z2F0_HUMAN (Length: 371)
#   Matches at position 19 : RESKL
#   Found in: tr|B7Z376|B7Z376_HUMAN (Length: 586)
#   Matches at position 275 : LEYSKL
#   Matches at position 276 : EYSKL
#   Found in: tr|B7Z9S7|B7Z9S7_HUMAN (Length: 586)
#   Matches at position 275 : LEYSKL
#   Matches at position 276 : EYSKL
#   Found in: tr|B7Z9V5|B7Z9V5_HUMAN (Length: 405)
#   Matches at position 337 : RESKL
#   Found in: tr|B7ZAH2|B7ZAH2_HUMAN (Length: 542)
#   Matches at position 496 : RIYSKL
#   Found in: tr|B7ZAY2|B7ZAY2_HUMAN (Length: 142)
#   Matches at position 1 : REYKL
#   Found in: tr|B7ZB07|B7ZB07_HUMAN (Length: 587)
#   Matches at position 175 : REYNKL
#   Found in: tr|B7ZLS9|B7ZLS9_HUMAN (Length: 976)
#   Matches at position 103 : RVYSKL
#   Found in: tr|D6R9P9|D6R9P9_HUMAN (Length: 87)
#   Matches at position 19 : RESKL
#   Found in: tr|D6RFH3|D6RFH3_HUMAN (Length: 87)
#   Matches at position 19 : RESKL
#   Found in: tr|E5RHU4|E5RHU4_HUMAN (Length: 149)
#   Matches at position 25 : REYGKL
#   Found in: tr|E5RJI6|E5RJI6_HUMAN (Length: 63)
#   Matches at position 25 : REYGKL
#   Found in: tr|E7EV10|E7EV10_HUMAN (Length: 590)
#   Matches at position 171 : REQSKL
#   Found in: tr|E9PCS8|E9PCS8_HUMAN (Length: 392)
#   Matches at position 171 : REQSKL
#   Found in: tr|E9PD09|E9PD09_HUMAN (Length: 410)
#   Matches at position 19 : RESKL
#   Found in: tr|E9PPW5|E9PPW5_HUMAN (Length: 177)
#   Matches at position 106 : RGYSKL
#   Found in: tr|E9PQ91|E9PQ91_HUMAN (Length: 228)
#   Matches at position 99 : RGYSKL
#   Found in: tr|F2Z2E4|F2Z2E4_HUMAN (Length: 90)
#   Matches at position 35 : RYSKL
#   Found in: tr|F5GWU8|F5GWU8_HUMAN (Length: 87)
#   Matches at position 1 : REYKL
#   Found in: tr|F5GX62|F5GX62_HUMAN (Length: 139)
#   Matches at position 1 : REYKL
#   Found in: tr|F5GYB5|F5GYB5_HUMAN (Length: 136)
#   Matches at position 1 : REYKL
#   Found in: tr|F5GYH7|F5GYH7_HUMAN (Length: 53)
#   Matches at position 1 : REYKL
#   Found in: tr|F5H004|F5H004_HUMAN (Length: 127)
#   Matches at position 1 : REYKL
#   Found in: tr|F5H077|F5H077_HUMAN (Length: 84)
#   Matches at position 1 : REYKL
#   Found in: tr|F5H0B7|F5H0B7_HUMAN (Length: 98)
#   Matches at position 1 : REYKL
#   Found in: tr|F5H0S2|F5H0S2_HUMAN (Length: 11)
#   Matches at position 1 : REYKL
#   Found in: tr|F5H491|F5H491_HUMAN (Length: 93)
#   Matches at position 1 : REYKL
#   Found in: tr|F5H4H0|F5H4H0_HUMAN (Length: 48)
#   Matches at position 1 : REYKL
#   Found in: tr|F5H500|F5H500_HUMAN (Length: 101)
#   Matches at position 1 : REYKL
#   Found in: tr|F5H6R7|F5H6R7_HUMAN (Length: 122)
#   Matches at position 1 : REYKL
#   Found in: tr|F8VRE4|F8VRE4_HUMAN (Length: 118)
#   Matches at position 23 : REYSSL
#   Found in: tr|F8W9L6|F8W9L6_HUMAN (Length: 348)
#   Matches at position 23 : REYSSL
#   Found in: tr|F8WBC0|F8WBC0_HUMAN (Length: 32)
#   Matches at position 1 : REYKL
#   Found in: tr|F8WE40|F8WE40_HUMAN (Length: 54)
#   Matches at position 14 : QEYSKL
#   Matches at position 15 : EYSKL
#   Found in: tr|F8WEL2|F8WEL2_HUMAN (Length: 119)
#   Matches at position 35 : RYSKL
#   Found in: tr|G3V2F6|G3V2F6_HUMAN (Length: 76)
#   Matches at position 23 : REYSSL
#   Found in: tr|G3V3C2|G3V3C2_HUMAN (Length: 62)
#   Matches at position 23 : REYSSL
#   Found in: tr|G3V513|G3V513_HUMAN (Length: 120)
#   Matches at position 23 : REYSSL
#   Found in: tr|H0Y3C6|H0Y3C6_HUMAN (Length: 316)
#   Matches at position 156 : REKSKL
#   Found in: tr|H0YF12|H0YF12_HUMAN (Length: 108)
#   Matches at position 75 : RELSKL
#   Found in: tr|H0YGJ6|H0YGJ6_HUMAN (Length: 397)
#   Matches at position 56 : REYDKL
#   Found in: tr|H0YIL9|H0YIL9_HUMAN (Length: 259)
#   Matches at position 219 : RESKL
#   Found in: tr|H3BLS7|H3BLS7_HUMAN (Length: 3210)
#   Matches at position 995 : REYSKA
#   Found in: tr|H3BMH0|H3BMH0_HUMAN (Length: 277)
#   Matches at position 1 : REYLKL
#   Found in: tr|H7BZ71|H7BZ71_HUMAN (Length: 246)
#   Matches at position 218 : REYKL
#   Found in: tr|H7BZ97|H7BZ97_HUMAN (Length: 258)
#   Matches at position 129 : EEYSKL
#   Matches at position 130 : EYSKL
#   Found in: tr|I3L0R3|I3L0R3_HUMAN (Length: 47)
#   Matches at position 36 : REFSKL
#   Found in: tr|I3L1Z5|I3L1Z5_HUMAN (Length: 1071)
#   Matches at position 25 : REYSKT
#   Found in: tr|I3L231|I3L231_HUMAN (Length: 77)
#   Matches at position 36 : REFSKL
#   Found in: tr|I3L2S5|I3L2S5_HUMAN (Length: 71)
#   Matches at position 25 : REYSKT
#   Found in: tr|J3KTD4|J3KTD4_HUMAN (Length: 188)
#   Matches at position 97 : RESKL
#   Found in: tr|L8E7R5|L8E7R5_HUMAN (Length: 69)
#   Matches at position 34 : REYSL
#   Found in: tr|Q2TBD1|Q2TBD1_HUMAN (Length: 716)
#   Matches at position 301 : REYKKL
#   Found in: tr|Q3MHC4|Q3MHC4_HUMAN (Length: 109)
#   Matches at position 103 : RVYSKL
#   Found in: tr|Q496Y1|Q496Y1_HUMAN (Length: 1004)
#   Matches at position 74 : REYSKN
#   Found in: tr|Q53HW0|Q53HW0_HUMAN (Length: 253)
#   Matches at position 25 : REYGKL
#   Found in: tr|Q53RX8|Q53RX8_HUMAN (Length: 233)
#   Matches at position 107 : REQSKL
#   Found in: tr|Q58FF9|Q58FF9_HUMAN (Length: 101)
#   Matches at position 85 : REGSKL
#   Found in: tr|Q5VXJ5|Q5VXJ5_HUMAN (Length: 792)
#   Matches at position 103 : RVYSKL
#   Found in: tr|Q6AI22|Q6AI22_HUMAN (Length: 2810)
#   Matches at position 460 : REYKL
#   Found in: tr|Q6I9S5|Q6I9S5_HUMAN (Length: 217)
#   Matches at position 62 : RESKL
#   Found in: tr|Q6IQ41|Q6IQ41_HUMAN (Length: 1237)
#   Matches at position 703 : RFYSKL
#   Found in: tr|Q8NFP3|Q8NFP3_HUMAN (Length: 622)
#   Matches at position 347 : REYSKQ
#   Found in: tr|Q96LK1|Q96LK1_HUMAN (Length: 328)
#   Matches at position 239 : REYKL
#   Found in: tr|Q9BXV4|Q9BXV4_HUMAN (Length: 153)
#   Matches at position 1 : REYKL
#   Found in: tr|Q9H2G7|Q9H2G7_HUMAN (Length: 795)
#   Matches at position 103 : RVYSKL
#   Found in: tr|V9GY29|V9GY29_HUMAN (Length: 92)
#   Matches at position 19 : REYKL
#   Found in: tr|V9GYC3|V9GYC3_HUMAN (Length: 151)
#   Matches at position 19 : REYKL
# Protein: Q9Y6K9_234 (Length: 6)
#   Found in: tr|A0A804HI81|A0A804HI81_HUMAN (Length: 1309)
#   Matches at position 1165 : VAYHRL
#   Found in: tr|A0A8V8TME4|A0A8V8TME4_HUMAN (Length: 454)
#   Matches at position 379 : VAYQL
#   Found in: tr|A0A8V8TMV9|A0A8V8TMV9_HUMAN (Length: 500)
#   Matches at position 425 : VAYQL
#   Found in: tr|A0A8V8TNA3|A0A8V8TNA3_HUMAN (Length: 484)
#   Matches at position 237 : VATHQL
#   Found in: tr|A0A8V8TNF4|A0A8V8TNF4_HUMAN (Length: 267)
#   Matches at position 20 : VATHQL
#   Found in: tr|A0A8V8TP68|A0A8V8TP68_HUMAN (Length: 478)
#   Matches at position 403 : VAYQL
#   Found in: tr|A0AAA9X9E9|A0AAA9X9E9_HUMAN (Length: 3925)
#   Matches at position 1941 : VAGHQL
#   Found in: tr|B1VKB5|B1VKB5_HUMAN (Length: 399)
#   Matches at position 323 : VAYQL
#   Found in: tr|B2RA39|B2RA39_HUMAN (Length: 569)
#   Matches at position 322 : VATHQL
#   Found in: tr|B3KUK3|B3KUK3_HUMAN (Length: 653)
#   Matches at position 89 : QAYHQL
#   Matches at position 90 : AYHQL
#   Found in: tr|B3KUL4|B3KUL4_HUMAN (Length: 424)
#   Matches at position 151 : VATHQL
#   Found in: tr|B3KWX8|B3KWX8_HUMAN (Length: 1260)
#   Matches at position 1116 : VAYHRL
#   Found in: tr|B4DH92|B4DH92_HUMAN (Length: 777)
#   Matches at position 749 : VALHQL
#   Found in: tr|B4DJA1|B4DJA1_HUMAN (Length: 289)
#   Matches at position 213 : VAYQL
#   Found in: tr|B4DNW2|B4DNW2_HUMAN (Length: 180)
#   Matches at position 69 : VAYHL
#   Found in: tr|B4DYK1|B4DYK1_HUMAN (Length: 732)
#   Matches at position 608 : QAYHQL
#   Matches at position 609 : AYHQL
#   Found in: tr|B7Z1W0|B7Z1W0_HUMAN (Length: 985)
#   Matches at position 295 : VAYVQL
#   Found in: tr|B7Z9I9|B7Z9I9_HUMAN (Length: 290)
#   Matches at position 213 : VAYQL
#   Found in: tr|C9JN51|C9JN51_HUMAN (Length: 250)
#   Matches at position 230 : QVAYHQL
#   Matches at position 231 : VAYHQL
#   Matches at position 232 : AYHQL
#   Found in: tr|D6RII0|D6RII0_HUMAN (Length: 76)
#   Matches at position 55 : VAYQL
#   Found in: tr|E9PDH4|E9PDH4_HUMAN (Length: 1384)
#   Matches at position 805 : VAYHSQL
#   Found in: tr|F8VR14|F8VR14_HUMAN (Length: 289)
#   Matches at position 213 : VAYQL
#   Found in: tr|H0Y9A4|H0Y9A4_HUMAN (Length: 337)
#   Matches at position 193 : VAYHRL
#   Found in: tr|H0YA34|H0YA34_HUMAN (Length: 1260)
#   Matches at position 1116 : VAYHRL
#   Found in: tr|H0YI72|H0YI72_HUMAN (Length: 532)
#   Matches at position 455 : VAYQL
#   Found in: tr|H3BQG3|H3BQG3_HUMAN (Length: 491)
#   Matches at position 56 : VAYHL
#   Found in: tr|I3L0Q3|I3L0Q3_HUMAN (Length: 161)
#   Matches at position 41 : VAHQL
#   Found in: tr|I3NI43|I3NI43_HUMAN (Length: 111)
#   Matches at position 41 : VAHQL
#   Found in: tr|Q05CF5|Q05CF5_HUMAN (Length: 434)
#   Matches at position 322 : VATHQL
#   Found in: tr|Q2TBE4|Q2TBE4_HUMAN (Length: 281)
#   Matches at position 231 : VALHQL
#   Found in: tr|Q3LIB1|Q3LIB1_HUMAN (Length: 905)
#   Matches at position 855 : VALHQL
#   Found in: tr|Q495U1|Q495U1_HUMAN (Length: 342)
#   Matches at position 122 : VAYDQL
#   Found in: tr|Q53GR6|Q53GR6_HUMAN (Length: 1195)
#   Matches at position 1051 : VAYHRL
#   Found in: tr|Q6V0K8|Q6V0K8_HUMAN (Length: 366)
#   Matches at position 289 : VAYQL
#   Found in: tr|Q6ZS22|Q6ZS22_HUMAN (Length: 168)
#   Matches at position 33 : VAVHQL
#   Found in: tr|Q6ZS32|Q6ZS32_HUMAN (Length: 1016)
#   Matches at position 437 : VAYHSQL
#   Found in: tr|Q86YV2|Q86YV2_HUMAN (Length: 201)
#   Matches at position 86 : VAHQL
#   Found in: tr|Q8NF31|Q8NF31_HUMAN (Length: 625)
#   Matches at position 13 : VAYVQL
#   Found in: tr|Q8TEK9|Q8TEK9_HUMAN (Length: 824)
#   Matches at position 212 : VAYVQL
#   Found in: tr|Q9NXA4|Q9NXA4_HUMAN (Length: 1064)
#   Matches at position 1021 : VAYHRL
#   Found in: tr|Q9UF98|Q9UF98_HUMAN (Length: 862)
#   Matches at position 212 : VACHQL

# %%
'''LOAD INPUT DATASET'''

#Read motif data from CSV file
set1 = read_csv_file("LIRcentral.csv")
#Read human proteins sequence from FASTA file
set2 = read_fasta_file("Humanproteome.fasta")

'''VALIDATE INPUT DATA'''

#Check if either input set is empty and stop the execution
if not set1 or not set2:
    print("Error: One or both sets are empty.")
else:
  #Find where motifs matched protein sequence
  matches= find_protein_matches(set1,set2)

  #Table creation to store results from output
  table_info =[]
  #Set to store protein IDs that contain identical matches to motifs
  identical_with_LIRmotifs = set()

  #Loop through each motif from the CSV
  for uniqueID, match_list in matches.items():
      motif_length = len(set1[uniqueID]["motif"]) #Length of the current motif

      #Loop through each protein that matched this motif
      for match in match_list:
        protein_id= match["protein_id"]
        protein_length = match["protein_length"]
        experimentally_verified = match["experimentally_verified"]


        #Loop through each individual match found in this protein
        for position, sequence,sequence_length in match["matches"]:

          #Check if the matched sequence is identical to the motif
          if sequence == set1[uniqueID]["motif"] :
            identical= "YES"
            identical_with_LIRmotifs.add(protein_id) #Store the identical matches
          else:
            identical = "NO"

          #Append all relevant data to the result table
          table_info.append([uniqueID, motif_length,experimentally_verified,protein_id, protein_length, position,sequence,sequence_length, identical])

  headers = ["Motif ID", "Motif Length" , "Experimentally Verified" , "Matched in Protein" , "Protein Length" , "Matched Position" , "Matched Sequence","Matched Sequence Length", "Identical Sequence"]
  #print(tabulate(table_info, headers=headers, tablefmt= "grid"))

  #Write the results to a txt file in tab-separated format
  with open("output.txt", "w") as out:
    #out.write(tabulate(table_info, headers=headers, tablefmt= "grid"))
    for match_lir in table_info:
      #out.write(str(match_lir)+"\n")
      out.write('\t'.join(map(str,match_lir)) + '\n')

# %%
'''RESYLTS ANALYSIS'''


# File paths for input and output files
csv_file = "LIRcentral.csv"
output_file = "output.txt"
information_file = "analysis_results.txt"


#Initialize sets to store unique human LIRmotifs data

Homo_sapiens_unique_name_motifs = set() #Unique motif entries with Uniprot ID and position
Homo_sapiens_motifs = set() #Unique Uniprot IDs with LIR motifs

# Dictionaries to store analysis results
lir_motif_counts = defaultdict(int)  # Total number of matches per LIR motif
lir_motif_proteins = defaultdict(set)  # Proteins matched per LIR motif
lir_motif_all_proteins = set() # All proteins with at least one motif match
lir_motif_deletions = defaultdict(int)  # Counts deletions, motif matches <6 amino acids long
lir_motif_insertions = defaultdict(int)  # Counts insertions, motif matches >6 amino acids long
lir_motif_substitutions = defaultdict(int)  # Counts substitutions , motif matches exactly 6 amino acids long but not identical
lir_motif_identical = defaultdict(int) # Matched sequences identical with the LIRmotifs

# Counter objects
total_matches = 0
deletions = 0
insertions = 0
substitutions = 0
identicalseq = 0


'''READ MOTIF ENTRIES FROM THE ORIGINAL CSV FILE
AND COLLECT HUMAN LIR MOTIF IDENTIFIERS'''

with open(csv_file , "r" , newline="") as file :
  reader = csv.reader(file)
  header= next(reader) # Skip CSV header

  for row in reader:
        if row[0].strip() == "Homo sapiens":
            uniprot_id = row[1].strip()
            start_position = row[8].strip()
            uniqueID = f"{uniprot_id}_{start_position}"
            Homo_sapiens_unique_name_motifs.add(uniqueID)
            Homo_sapiens_motifs.add(uniprot_id)


# Read the matches from output.txt file
with open(output_file, "r") as file:
    for line in file:
        cols = line.strip().split("\t")
        if len(cols) < 9:
            continue  # Skip incomplete rows

        lir_motif = cols[0]  # LIR motif ID
        protein_id = cols[3]  # Protein ID where the motif matched
        match_length = int(cols[7])  # Length of the matched sequence to classify mismatch type

        # Count matches with <= 1 mismatch (each row represents one)
        total_matches += 1

        # Count different motifs and their associated proteins
        lir_motif_counts[lir_motif] += 1
        lir_motif_proteins[lir_motif].add(protein_id)
        lir_motif_all_proteins.add(protein_id)

        # Classify type of match
        if cols[8]=="NO": #Not an identical match
          if match_length < 6:
            lir_motif_deletions[lir_motif] += 1
            deletions += 1
          elif match_length > 6:
            lir_motif_insertions[lir_motif] += 1
            insertions += 1
          else:  # match_length == 6
            lir_motif_substitutions[lir_motif] += 1
            substitutions += 1
        else : #Identical match
          lir_motif_identical[lir_motif] += 1
          identicalseq += 1

# Find the LIR motif with the highest number of matches
most_common_motif = max(lir_motif_counts, key=lir_motif_counts.get, default=None)
most_common_motif_count = lir_motif_counts.get(most_common_motif, 0)
#Count how many different proteins matched this motif
unique_proteins_for_motif = len(lir_motif_proteins.get(most_common_motif, set()))

# Find LIR motifs that appear at least 1 time
frequent_motifs = {
    motif: {
        "count": lir_motif_counts[motif],
        "unique_proteins": len(lir_motif_proteins[motif]),
        "deletions": lir_motif_deletions[motif],
        "insertions": lir_motif_insertions[motif],
        "substitutions": lir_motif_substitutions[motif],
        "identical" : lir_motif_identical[motif]
    }
    for motif in lir_motif_counts if lir_motif_counts[motif] >= 1
}

# Write all summary results to a TXT file
with open(information_file, "w") as file:
    file.write(f"1. Homo sapiens LIR motifs: {len(Homo_sapiens_unique_name_motifs)}\n")
    file.write(f"2. Different human proteins with LIR motifs: {len(Homo_sapiens_motifs)}\n")
    file.write(f"3. Total LIRmotifs-human proteins mismatches: {total_matches}\n")
    file.write(f"4. Identified different LIR motifs: {len(lir_motif_counts)}\n")
    file.write(f"6. Mismatches in different proteins:{len(lir_motif_all_proteins)}\n")
    file.write(f"5. Deletions (<6): {deletions}\n")
    file.write(f"7. Insertions (>6): {insertions}\n")
    file.write(f"8. Substitutions (=6): {substitutions}\n")
    file.write(f"9. Identical : {identicalseq}\n")
    file.write(f"10. Most frequent LIR motif: {most_common_motif} ({most_common_motif_count} times)\n")
    file.write(f"11. Number of different proteins matched: {unique_proteins_for_motif}\n\n")
    file.write("LIR motifs matching x times:\n")
    for motif, details in frequent_motifs.items():
        file.write(f"   - {motif}: {details['count']} times\n")
        file.write(f"     Different proteins matched: {details['unique_proteins']}\n")
        file.write(f"     Deletions: {details['deletions']}, Insertions: {details['insertions']}, Substitutions: {details['substitutions']}, Identical:{details['identical']}\n\n")
