# %% [markdown]
# <a href="https://colab.research.google.com/github/viktoriapatouna/Thesis-work-2025/blob/main/LIRmotifs_small_human_proteins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install biopython
# Out:
# Requirement already satisfied: biopython in /usr/local/lib/python3.11/dist-packages (1.85)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from biopython) (2.0.2)

# %%
pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (0.9.0)

# %%
import os
import csv
import regex
from Bio import SeqIO
from tabulate import tabulate
from collections import defaultdict

# %%
 '''READ THE FASTA FILES AND RETURNS A DICTIONARY
    WHERE KEYS ARE PEPTIDES IDs AND VALUES ARE SEQUENCES'''
def read_fasta_file(file_path):
    sequences = {}

    with open(file_path, "r") as file:
        #Use Biopython's SeqIO to parse each FASTA record
        for record in SeqIO.parse(file, "fasta"):  #Choosing a specific FASTA record from the file
            sequences[record.id] = str(record.seq)  #Store ID as keys and sequence as value
    return sequences


'''READS A CSV FILE CONTAINING LIR MOTIF DATA AND RETURNS
  A DICTIONARY WITH UNIQUE MOTIF IDENTIFIERS AND MOTIF INFO AS KEY-VALUE PAIRS'''
def read_csv_file(file_path):
  sequences={}

  with open(file_path , "r" , newline="") as file:
    reader= csv.reader(file)
    headers = next(reader) #Skip the header row
    for row in reader:
      #Choose the Homo sapiens and canonical LIR motifs only
      if row[0].strip() == "Homo sapiens" and row[4].strip() != "Non canonical LIR" :
        uniprot_id = row[1].strip()
        start_position = row[8].strip()
        uniqueID =  f"{uniprot_id}_{start_position}" # Make a unique ID for each LIR motif combining Uniprot ID and start position


        #Extract and reconstruct LIR motif sequence
        if len(row) > 6 :
         motif= row[6].strip() # Remove any spaces and get the LIR motifs only
         if len(row)> 5 :
           motif_row5 = row[5].strip()
           motif_from_row5 = motif_row5[-2:] #Get last 2 amino acids from the sequence before the LIR motif position
           motif = motif_from_row5 + motif


        if row[11].strip()=="NO" or row[11].strip() =="N/A":
         experimentally_verified = "NO"
        else:
         experimentally_verified = "YES"


        #Store only if motif exists
        if motif:
           sequences[uniqueID] = {"motif" : motif , "verified" : experimentally_verified}
        else :
         print(f"Skipping empty motif in row :{row}")

  return sequences



  '''MATCHES HUMAN LIR MOTIFS FROM set1 AGAINST SMALL HUMAN PEPTIDES FROM set2
  AND RETURNS A DICTIONARY WHERE KEYS ARE MOTIF IDs AND VALUES ARE MATCHE DETAILS'''

def find_protein_matches(set1, set2):
    results = {}

    for uniqueID, motif1 in set1.items():
        motif_seq = motif1["motif"]
        experimentally_verified = motif1["verified"]
        motif_length = len(motif_seq)
        matches = []

        for id2, protein2 in set2.items():
          #Build Regex pattern with <=1 mismatch
          motif_pattern="({}){{e<=1}}".format(motif_seq)
          found_matches = []


          #Search for all matches within the peptide sequence
          for match in regex.finditer(motif_pattern, protein2  ,overlapped=True) :
            #search for all matches and returns match objects, .findall() only returns strings
            position= match.start()
            sequence = match.group()
            sequence_length = len(sequence)
            #Store match details(matched position in protein,matched sequence and its length)
            found_matches.append((position,sequence,sequence_length))

          #If any matches found for peptides,add them in found_matches variable
          if found_matches and 10 <= len(protein2) <= 100:
            matches.append({
                    "protein_id": id2,
                    "protein_length": len(protein2),  # length of the peptide from me set2
                    "matches" :found_matches,
                    "experimentally_verified" : experimentally_verified

                })


        #If this motif matched in any peptide, store the results under the motif's unique ID
        if matches:
            results[uniqueID] = matches

    return results

# %%
#Read motif data from CSV file
set1 = read_csv_file("LIRcentral.csv")
#Read small human peptides sequence from FASTA file
set2 = read_fasta_file("Smallhumanpeptides.fasta")

#Check if either input set is empty and stop the execution
if not set1 or not set2:
   print("Error: One or both sets are empty.")

else:
    #Find where motifs matched peptides sequence
    matches = find_protein_matches(set1, set2)

    #Loop through all motifs that matched
    for uniqueID, match_list in matches.items():
        motif_length = len(set1[uniqueID]["motif"])  # motif length from the set1
        print(f"Protein: {uniqueID} (Length: {motif_length})")

        #Loop through all peptides sequences that had a match with this motif
        for match in match_list:
            print(f"  Found in: {match['protein_id']} (Length: {match['protein_length']})")
            #Loop through individual match positions and sequences
            for position, sequence ,*_ in match["matches"]:
               print(f"  Matches at position {position} : {sequence}")
# Out:
# Protein: A0A3Q9JIX6_160 (Length: 6)
#   Found in: IP_059505|TX=9606 (Length: 54)
#   Matches at position 18 : TSLSRL
#   Found in: IP_060960|TX=9606 (Length: 33)
#   Matches at position 1 : TSSRL
#   Found in: IP_063073|TX=9606 (Length: 32)
#   Matches at position 6 : TSYSRH
#   Found in: IP_072017|TX=9606 (Length: 77)
#   Matches at position 60 : TSSRL
#   Found in: IP_073753|TX=9606 (Length: 40)
#   Matches at position 19 : TSYSRG
#   Found in: IP_073772|TX=9606 (Length: 37)
#   Matches at position 4 : TYSRL
#   Found in: IP_074407|TX=9606 (Length: 46)
#   Matches at position 8 : TSYSLL
#   Found in: IP_078763|TX=9606 (Length: 42)
#   Matches at position 37 : TSSRL
#   Found in: IP_083038|TX=9606 (Length: 42)
#   Matches at position 15 : TSYSVL
#   Found in: II_085042|TX=9606 (Length: 81)
#   Matches at position 17 : TSYRL
#   Found in: IP_085463|TX=9606 (Length: 68)
#   Matches at position 10 : TSSRL
#   Found in: IP_085490|TX=9606 (Length: 55)
#   Matches at position 9 : TSYSIL
#   Found in: IP_086869|TX=9606 (Length: 52)
#   Matches at position 43 : TTYSRL
#   Matches at position 44 : TYSRL
#   Found in: IP_090347|TX=9606 (Length: 68)
#   Matches at position 51 : TSYSGL
#   Found in: IP_091001|TX=9606 (Length: 82)
#   Matches at position 38 : TSSRL
#   Found in: IP_091856|TX=9606 (Length: 38)
#   Matches at position 3 : TSHSRL
#   Found in: IP_093152|TX=9606 (Length: 66)
#   Matches at position 35 : TSSRL
#   Found in: IP_095443|TX=9606 (Length: 55)
#   Matches at position 16 : TSVSRL
#   Found in: IP_097179|TX=9606 (Length: 67)
#   Matches at position 31 : TSYRRL
#   Found in: IP_097487|TX=9606 (Length: 48)
#   Matches at position 22 : TSSRL
#   Found in: II_097826|TX=9606 (Length: 53)
#   Matches at position 23 : TSSSRL
#   Found in: IP_099466|TX=9606 (Length: 44)
#   Matches at position 6 : TSYRL
#   Found in: II_100434|TX=9606 (Length: 73)
#   Matches at position 59 : TSSSRL
#   Found in: IP_100909|TX=9606 (Length: 42)
#   Matches at position 14 : TSSSRL
#   Found in: IP_102548|TX=9606 (Length: 100)
#   Matches at position 38 : LSYSRL
#   Matches at position 39 : SYSRL
#   Found in: IP_105187|TX=9606 (Length: 44)
#   Matches at position 24 : TSASRL
#   Found in: IP_107339|TX=9606 (Length: 49)
#   Matches at position 5 : TSYSQL
#   Found in: IP_110409|TX=9606 (Length: 51)
#   Matches at position 31 : TSYSKL
#   Found in: IP_115187|TX=9606 (Length: 29)
#   Matches at position 23 : TSNSRL
#   Found in: IP_118382|TX=9606 (Length: 47)
#   Matches at position 5 : PSYSRL
#   Matches at position 6 : SYSRL
#   Found in: IP_120313|TX=9606 (Length: 70)
#   Matches at position 46 : TSYSLL
#   Found in: IP_123981|TX=9606 (Length: 43)
#   Matches at position 23 : TSQSRL
#   Found in: IP_125698|TX=9606 (Length: 55)
#   Matches at position 49 : RSYSRL
#   Matches at position 50 : SYSRL
#   Found in: IP_129922|TX=9606 (Length: 49)
#   Matches at position 12 : TSDSRL
#   Found in: IP_130368|TX=9606 (Length: 49)
#   Matches at position 14 : TSSRL
#   Found in: IP_133206|TX=9606 (Length: 62)
#   Matches at position 51 : TSYSSL
#   Found in: IP_134028|TX=9606 (Length: 39)
#   Matches at position 15 : TMYSRL
#   Found in: IP_137667|TX=9606 (Length: 49)
#   Matches at position 35 : PTSYSRL
#   Matches at position 36 : TSYSRL
#   Matches at position 37 : SYSRL
#   Found in: IP_138237|TX=9606 (Length: 57)
#   Matches at position 33 : TSYSLL
#   Found in: IP_138346|TX=9606 (Length: 30)
#   Matches at position 21 : TYSRL
#   Found in: IP_140188|TX=9606 (Length: 50)
#   Matches at position 42 : TSYSL
#   Found in: IP_144406|TX=9606 (Length: 36)
#   Matches at position 3 : TSLSRL
#   Found in: IP_146750|TX=9606 (Length: 29)
#   Matches at position 4 : TLYSRL
#   Found in: IP_148716|TX=9606 (Length: 68)
#   Matches at position 62 : TSSSRL
#   Found in: IP_156839|TX=9606 (Length: 34)
#   Matches at position 6 : TSFSRL
#   Found in: IP_158915|TX=9606 (Length: 85)
#   Matches at position 47 : TSSRL
#   Found in: IP_160892|TX=9606 (Length: 49)
#   Matches at position 36 : TSDSRL
#   Found in: IP_162357|TX=9606 (Length: 32)
#   Matches at position 21 : TSVYSRL
#   Found in: IP_169663|TX=9606 (Length: 70)
#   Matches at position 21 : TSQSRL
#   Found in: IP_169676|TX=9606 (Length: 42)
#   Matches at position 7 : TSCSRL
#   Found in: IP_171265|TX=9606 (Length: 63)
#   Matches at position 16 : TSSSRL
#   Found in: IP_172212|TX=9606 (Length: 60)
#   Matches at position 25 : TSHSRL
# Protein: B9EIS5_1955 (Length: 6)
#   Found in: IP_085184|TX=9606 (Length: 80)
#   Matches at position 9 : EFVKV
#   Found in: IP_108238|TX=9606 (Length: 33)
#   Matches at position 13 : EPFVKV
#   Found in: II_121708|TX=9606 (Length: 59)
#   Matches at position 9 : EDFKV
#   Found in: II_121717|TX=9606 (Length: 40)
#   Matches at position 3 : EDSVKV
#   Found in: IP_166816|TX=9606 (Length: 67)
#   Matches at position 10 : EDFKV
# Protein: O14641_444 (Length: 6)
#   Found in: IP_081329|TX=9606 (Length: 40)
#   Matches at position 11 : RMGLKI
#   Found in: IP_093757|TX=9606 (Length: 42)
#   Matches at position 0 : MWLKI
#   Found in: IP_118444|TX=9606 (Length: 80)
#   Matches at position 3 : RMLKI
#   Found in: IP_124403|TX=9606 (Length: 82)
#   Matches at position 44 : VMWLKI
#   Matches at position 45 : MWLKI
#   Found in: IP_133922|TX=9606 (Length: 30)
#   Matches at position 0 : MWLKI
#   Found in: IP_143749|TX=9606 (Length: 47)
#   Matches at position 40 : RMRLKI
#   Found in: IP_150395|TX=9606 (Length: 42)
#   Matches at position 4 : RDWLKI
#   Found in: IP_159486|TX=9606 (Length: 39)
#   Matches at position 26 : RMLKI
#   Found in: IP_161257|TX=9606 (Length: 45)
#   Matches at position 30 : RVWLKI
#   Found in: IP_163892|TX=9606 (Length: 54)
#   Matches at position 5 : RWLKI
#   Found in: IP_170346|TX=9606 (Length: 48)
#   Matches at position 10 : RMLLKI
# Protein: O15040_1408 (Length: 6)
#   Found in: IP_100259|TX=9606 (Length: 61)
#   Matches at position 43 : DEWEI
#   Found in: IP_103561|TX=9606 (Length: 38)
#   Matches at position 8 : DEPEVI
#   Found in: IP_115788|TX=9606 (Length: 72)
#   Matches at position 44 : DSWEVI
# Protein: O15111_740 (Length: 6)
#   Found in: IP_061491|TX=9606 (Length: 51)
#   Matches at position 25 : LPWSWL
#   Found in: IP_062877|TX=9606 (Length: 36)
#   Matches at position 12 : LAWSWL
#   Found in: IP_072933|TX=9606 (Length: 35)
#   Matches at position 24 : LFWSWL
#   Found in: IP_076490|TX=9606 (Length: 43)
#   Matches at position 22 : LSWSWL
#   Found in: IP_079371|TX=9606 (Length: 33)
#   Matches at position 3 : LWWSWL
#   Found in: IP_087275|TX=9606 (Length: 50)
#   Matches at position 13 : LDWFWL
#   Found in: IP_089599|TX=9606 (Length: 88)
#   Matches at position 35 : LDWSQL
#   Found in: IP_089947|TX=9606 (Length: 39)
#   Matches at position 12 : LDSWL
#   Found in: IP_095040|TX=9606 (Length: 37)
#   Matches at position 10 : LDWSPL
#   Found in: IP_103252|TX=9606 (Length: 33)
#   Matches at position 28 : LWSWL
#   Found in: IP_109031|TX=9606 (Length: 54)
#   Matches at position 13 : TDWSWL
#   Matches at position 14 : DWSWL
#   Found in: IP_114849|TX=9606 (Length: 53)
#   Matches at position 10 : LWSWL
#   Found in: IP_119518|TX=9606 (Length: 52)
#   Matches at position 26 : LDWSL
#   Found in: IP_131917|TX=9606 (Length: 30)
#   Matches at position 15 : LAWSWL
#   Found in: IP_132682|TX=9606 (Length: 85)
#   Matches at position 77 : LDWSWE
#   Found in: IP_134404|TX=9606 (Length: 50)
#   Matches at position 8 : LDWSQL
#   Found in: IP_139097|TX=9606 (Length: 38)
#   Matches at position 27 : LDWSL
#   Found in: IP_140206|TX=9606 (Length: 33)
#   Matches at position 10 : LDWDWL
#   Found in: IP_147453|TX=9606 (Length: 73)
#   Matches at position 68 : LDSWL
#   Found in: IP_148197|TX=9606 (Length: 29)
#   Matches at position 1 : LDWSYL
#   Found in: IP_156310|TX=9606 (Length: 78)
#   Matches at position 23 : LDWWL
#   Found in: IP_164763|TX=9606 (Length: 52)
#   Matches at position 29 : LDWSL
#   Found in: IP_168078|TX=9606 (Length: 96)
#   Matches at position 79 : LDSWL
# Protein: O15111_651 (Length: 6)
#   Found in: IP_058985|TX=9606 (Length: 43)
#   Matches at position 23 : EIDHLL
#   Found in: IP_066875|TX=9606 (Length: 79)
#   Matches at position 59 : EIHLL
#   Found in: IP_076260|TX=9606 (Length: 81)
#   Matches at position 25 : EIPHLL
#   Found in: IP_086711|TX=9606 (Length: 33)
#   Matches at position 18 : EIWKLL
#   Found in: IP_100598|TX=9606 (Length: 47)
#   Matches at position 41 : ELWHLL
#   Found in: IP_107124|TX=9606 (Length: 31)
#   Matches at position 8 : EWHLL
#   Found in: IP_110655|TX=9606 (Length: 42)
#   Matches at position 16 : QIWHLL
#   Matches at position 17 : IWHLL
#   Found in: IP_121949|TX=9606 (Length: 72)
#   Matches at position 62 : EIHLL
#   Found in: IP_123946|TX=9606 (Length: 54)
#   Matches at position 30 : EWHLL
#   Found in: IP_128700|TX=9606 (Length: 55)
#   Matches at position 8 : EIAHLL
#   Found in: IP_133207|TX=9606 (Length: 37)
#   Matches at position 28 : CIWHLL
#   Matches at position 29 : IWHLL
#   Found in: IP_133569|TX=9606 (Length: 40)
#   Matches at position 24 : GIWHLL
#   Matches at position 25 : IWHLL
#   Found in: IP_139883|TX=9606 (Length: 99)
#   Matches at position 56 : EIHLL
#   Found in: IP_143493|TX=9606 (Length: 59)
#   Matches at position 44 : EIWHLS
#   Found in: IP_151158|TX=9606 (Length: 68)
#   Matches at position 14 : AIWHLL
#   Matches at position 15 : IWHLL
#   Found in: IP_152560|TX=9606 (Length: 65)
#   Matches at position 9 : EIWPLL
#   Found in: IP_153991|TX=9606 (Length: 38)
#   Matches at position 21 : LIWHLL
#   Matches at position 22 : IWHLL
#   Found in: IP_157267|TX=9606 (Length: 58)
#   Matches at position 38 : ESWHLL
#   Found in: IP_159197|TX=9606 (Length: 40)
#   Matches at position 11 : EIWLL
#   Found in: IP_159886|TX=9606 (Length: 65)
#   Matches at position 18 : EWHLL
# Protein: O15111_275 (Length: 6)
#   Found in: II_072081|TX=9606 (Length: 54)
#   Matches at position 48 : ENWAQL
#   Found in: IP_081148|TX=9606 (Length: 37)
#   Matches at position 21 : ENWLLL
#   Found in: IP_092818|TX=9606 (Length: 49)
#   Matches at position 6 : ENLQL
#   Found in: IP_103969|TX=9606 (Length: 72)
#   Matches at position 24 : ENWLAL
#   Found in: IP_114754|TX=9606 (Length: 95)
#   Matches at position 23 : EGWLQL
#   Found in: IP_146585|TX=9606 (Length: 44)
#   Matches at position 5 : EMWLQL
#   Found in: IP_154983|TX=9606 (Length: 49)
#   Matches at position 14 : ENRLQL
#   Found in: L8E861|TX=9606 (Length: 69)
#   Matches at position 44 : ENWQL
#   Found in: IP_165071|TX=9606 (Length: 43)
#   Matches at position 26 : ENTLQL
# Protein: O15392_101 (Length: 6)
#   Found in: II_061436|TX=9606 (Length: 100)
#   Matches at position 39 : GEGLKL
#   Found in: IP_063862|TX=9606 (Length: 94)
#   Matches at position 59 : GFLKL
#   Found in: IP_070307|TX=9606 (Length: 32)
#   Matches at position 25 : GEFNKL
#   Found in: IP_072247|TX=9606 (Length: 83)
#   Matches at position 76 : GFLKL
#   Found in: IP_075871|TX=9606 (Length: 55)
#   Matches at position 30 : GFLKL
#   Found in: IP_079337|TX=9606 (Length: 53)
#   Matches at position 10 : GFLKL
#   Found in: IP_081291|TX=9606 (Length: 40)
#   Matches at position 10 : GEFLKI
#   Found in: IP_093133|TX=9606 (Length: 39)
#   Matches at position 14 : GEALKL
#   Found in: II_094081|TX=9606 (Length: 99)
#   Matches at position 87 : GFLKL
#   Found in: IP_101212|TX=9606 (Length: 40)
#   Matches at position 33 : GFLKL
#   Found in: IP_107535|TX=9606 (Length: 54)
#   Matches at position 27 : GLFLKL
#   Found in: IP_109045|TX=9606 (Length: 53)
#   Matches at position 25 : GFLKL
#   Found in: IP_109766|TX=9606 (Length: 55)
#   Matches at position 15 : GEFLL
#   Found in: IP_110808|TX=9606 (Length: 92)
#   Matches at position 55 : WEFLKL
#   Matches at position 56 : EFLKL
#   Found in: IP_115364|TX=9606 (Length: 49)
#   Matches at position 32 : GWFLKL
#   Found in: IP_117644|TX=9606 (Length: 53)
#   Matches at position 7 : GYFLKL
#   Found in: IP_124381|TX=9606 (Length: 34)
#   Matches at position 2 : GEFLL
#   Found in: IP_125300|TX=9606 (Length: 65)
#   Matches at position 27 : VEFLKL
#   Matches at position 28 : EFLKL
#   Found in: IP_133480|TX=9606 (Length: 45)
#   Matches at position 38 : GEQLKL
#   Found in: IP_134174|TX=9606 (Length: 71)
#   Matches at position 42 : GETLKL
#   Found in: IP_137717|TX=9606 (Length: 80)
#   Matches at position 29 : GIFLKL
#   Found in: IP_140386|TX=9606 (Length: 50)
#   Matches at position 34 : GLFLKL
#   Found in: IP_142441|TX=9606 (Length: 46)
#   Matches at position 8 : GFLKL
#   Found in: IP_144882|TX=9606 (Length: 64)
#   Matches at position 56 : MEFLKL
#   Matches at position 57 : EFLKL
#   Found in: IP_147232|TX=9606 (Length: 67)
#   Matches at position 37 : GEFLPL
#   Found in: IP_147235|TX=9606 (Length: 62)
#   Matches at position 32 : GEFLPL
#   Found in: IP_159719|TX=9606 (Length: 37)
#   Matches at position 1 : GEVLKL
#   Found in: IP_161955|TX=9606 (Length: 83)
#   Matches at position 66 : GEALKL
#   Found in: IP_166573|TX=9606 (Length: 67)
#   Matches at position 56 : GFLKL
#   Found in: IP_169343|TX=9606 (Length: 75)
#   Matches at position 39 : GEFLL
# Protein: O15553_525 (Length: 6)
#   Found in: IP_059557|TX=9606 (Length: 95)
#   Matches at position 28 : SESELL
#   Found in: IP_060184|TX=9606 (Length: 89)
#   Matches at position 25 : SETELL
#   Found in: IP_060802|TX=9606 (Length: 37)
#   Matches at position 4 : SYWELL
#   Found in: IP_061333|TX=9606 (Length: 48)
#   Matches at position 21 : SEIELL
#   Found in: IP_062860|TX=9606 (Length: 36)
#   Matches at position 23 : SEELL
#   Found in: IP_069117|TX=9606 (Length: 40)
#   Matches at position 27 : SESELL
#   Found in: IP_077964|TX=9606 (Length: 38)
#   Matches at position 21 : SWELL
#   Found in: IP_084454|TX=9606 (Length: 88)
#   Matches at position 37 : SWELL
#   Found in: IP_096631|TX=9606 (Length: 76)
#   Matches at position 26 : SEELL
#   Found in: IP_097592|TX=9606 (Length: 51)
#   Matches at position 12 : SVWELL
#   Found in: IP_097850|TX=9606 (Length: 87)
#   Matches at position 52 : SEELL
#   Found in: IP_101125|TX=9606 (Length: 62)
#   Matches at position 47 : SEAELL
#   Found in: IP_101622|TX=9606 (Length: 57)
#   Matches at position 21 : SEELL
#   Found in: IP_101628|TX=9606 (Length: 66)
#   Matches at position 30 : SEELL
#   Found in: IP_102377|TX=9606 (Length: 34)
#   Matches at position 7 : SWELL
#   Found in: IP_112435|TX=9606 (Length: 83)
#   Matches at position 21 : SWELL
#   Found in: IP_113576|TX=9606 (Length: 64)
#   Matches at position 31 : SWELL
#   Found in: IP_113961|TX=9606 (Length: 47)
#   Matches at position 13 : SSWELL
#   Matches at position 14 : SWELL
#   Found in: IP_119208|TX=9606 (Length: 48)
#   Matches at position 24 : SECELL
#   Found in: Q4W5N5|TX=9606 (Length: 91)
#   Matches at position 43 : SWELL
#   Found in: IP_125956|TX=9606 (Length: 64)
#   Matches at position 49 : SEWSLL
#   Found in: IP_136471|TX=9606 (Length: 39)
#   Matches at position 9 : SEELL
#   Found in: II_143410|TX=9606 (Length: 41)
#   Matches at position 14 : SELELL
#   Found in: IP_156937|TX=9606 (Length: 41)
#   Matches at position 1 : SEWELS
#   Found in: IP_167364|TX=9606 (Length: 55)
#   Matches at position 19 : SEWLL
#   Found in: IP_169264|TX=9606 (Length: 59)
#   Matches at position 39 : SWELL
# Protein: O60238_36 (Length: 6)
#   Found in: IP_059412|TX=9606 (Length: 48)
#   Matches at position 33 : SSWVL
#   Found in: IP_061258|TX=9606 (Length: 37)
#   Matches at position 31 : SSWVLL
#   Found in: IP_063112|TX=9606 (Length: 97)
#   Matches at position 81 : SSWEL
#   Found in: IP_063811|TX=9606 (Length: 74)
#   Matches at position 1 : SSWVHL
#   Found in: IP_065323|TX=9606 (Length: 68)
#   Matches at position 61 : SSWVL
#   Found in: IP_072654|TX=9606 (Length: 96)
#   Matches at position 50 : SSWEL
#   Found in: L0R4U0|TX=9606 (Length: 82)
#   Matches at position 27 : SSWEL
#   Found in: IP_074345|TX=9606 (Length: 63)
#   Matches at position 7 : SSWVCL
#   Found in: IP_077165|TX=9606 (Length: 83)
#   Matches at position 12 : SSWEL
#   Found in: IP_077691|TX=9606 (Length: 52)
#   Matches at position 40 : SSWEL
#   Found in: IP_085867|TX=9606 (Length: 39)
#   Matches at position 30 : SSWVML
#   Found in: IP_086773|TX=9606 (Length: 55)
#   Matches at position 26 : SSWVL
#   Found in: IP_097277|TX=9606 (Length: 80)
#   Matches at position 39 : SSWVL
#   Found in: IP_098931|TX=9606 (Length: 34)
#   Matches at position 5 : SSWVL
#   Found in: IP_100753|TX=9606 (Length: 42)
#   Matches at position 18 : SSWEL
#   Found in: II_104039|TX=9606 (Length: 91)
#   Matches at position 69 : SSWVTL
#   Found in: IP_108140|TX=9606 (Length: 38)
#   Matches at position 23 : SSWVL
#   Found in: IP_113961|TX=9606 (Length: 47)
#   Matches at position 13 : SSWEL
#   Found in: IP_116864|TX=9606 (Length: 85)
#   Matches at position 22 : ESWVEL
#   Matches at position 23 : SWVEL
#   Found in: IP_121489|TX=9606 (Length: 40)
#   Matches at position 6 : SSWVCL
#   Found in: IP_132612|TX=9606 (Length: 75)
#   Matches at position 67 : SSKVEL
#   Found in: IP_132629|TX=9606 (Length: 44)
#   Matches at position 36 : SSKVEL
#   Found in: IP_135536|TX=9606 (Length: 100)
#   Matches at position 23 : SSWVEP
#   Found in: IP_140813|TX=9606 (Length: 43)
#   Matches at position 19 : SSRVEL
#   Found in: IP_149568|TX=9606 (Length: 94)
#   Matches at position 11 : SSWTEL
#   Found in: IP_151218|TX=9606 (Length: 66)
#   Matches at position 19 : SSVEL
#   Found in: IP_151305|TX=9606 (Length: 32)
#   Matches at position 7 : SSWVML
#   Found in: IP_157912|TX=9606 (Length: 56)
#   Matches at position 28 : SSWTEL
# Protein: O75143_444 (Length: 6)
#   Found in: IP_104205|TX=9606 (Length: 49)
#   Matches at position 24 : DDFVNI
#   Found in: IP_111249|TX=9606 (Length: 57)
#   Matches at position 8 : RDFVMI
#   Matches at position 9 : DFVMI
# Protein: O75164_59 (Length: 6)
#   Found in: IP_077985|TX=9606 (Length: 35)
#   Matches at position 6 : ASYDI
#   Found in: IP_103820|TX=9606 (Length: 64)
#   Matches at position 25 : ASNDDI
# Protein: O75376_346 (Length: 6)
#   Found in: IP_083066|TX=9606 (Length: 64)
#   Matches at position 30 : KQFEI
#   Found in: II_084804|TX=9606 (Length: 94)
#   Matches at position 75 : KQFPLI
#   Found in: IP_088550|TX=9606 (Length: 33)
#   Matches at position 13 : KQFPER
#   Found in: IP_115374|TX=9606 (Length: 69)
#   Matches at position 3 : KQQPEI
#   Found in: IP_127438|TX=9606 (Length: 64)
#   Matches at position 41 : KQFPEL
#   Found in: IP_128798|TX=9606 (Length: 42)
#   Matches at position 8 : KQFSEI
#   Found in: IP_146242|TX=9606 (Length: 67)
#   Matches at position 25 : KQFPEL
#   Found in: IP_153823|TX=9606 (Length: 48)
#   Matches at position 15 : KQFPRI
# Protein: O75385_357 (Length: 6)
#   Found in: IP_082987|TX=9606 (Length: 68)
#   Matches at position 17 : DDRVMV
#   Found in: IP_113420|TX=9606 (Length: 42)
#   Matches at position 28 : LDFVMV
#   Matches at position 29 : DFVMV
#   Found in: IP_173043|TX=9606 (Length: 37)
#   Matches at position 29 : DDFMV
# Protein: O95197-2_771 (Length: 6)
#   Found in: IP_082654|TX=9606 (Length: 37)
#   Matches at position 5 : RSYDSL
#   Found in: IP_094043|TX=9606 (Length: 39)
#   Matches at position 7 : RSYDIA
#   Found in: IP_102080|TX=9606 (Length: 31)
#   Matches at position 19 : RSYDCL
#   Found in: IP_125650|TX=9606 (Length: 30)
#   Matches at position 15 : RSYIL
#   Found in: IP_141740|TX=9606 (Length: 59)
#   Matches at position 20 : RSYFIL
#   Found in: IP_149011|TX=9606 (Length: 64)
#   Matches at position 20 : RSKDIL
#   Found in: IP_153698|TX=9606 (Length: 42)
#   Matches at position 32 : RSYIL
# Protein: O95197-2_536 (Length: 6)
#   Found in: IP_089623|TX=9606 (Length: 44)
#   Matches at position 25 : KNEEL
#   Found in: IP_097224|TX=9606 (Length: 75)
#   Matches at position 40 : KNFVEL
#   Found in: IP_105736|TX=9606 (Length: 39)
#   Matches at position 29 : KNFENL
#   Found in: IP_130022|TX=9606 (Length: 68)
#   Matches at position 8 : KNFEVL
#   Found in: IP_132372|TX=9606 (Length: 69)
#   Matches at position 49 : KNEEL
# Protein: O95197-2_323 (Length: 6)
#   Found in: IP_058968|TX=9606 (Length: 61)
#   Matches at position 18 : LWDLV
#   Found in: IP_061267|TX=9606 (Length: 79)
#   Matches at position 34 : LTWDQV
#   Found in: IP_064126|TX=9606 (Length: 48)
#   Matches at position 28 : LTPDLV
#   Found in: II_065151|TX=9606 (Length: 68)
#   Matches at position 28 : LTWLV
#   Found in: IP_072410|TX=9606 (Length: 55)
#   Matches at position 16 : LTWDVV
#   Found in: IP_080705|TX=9606 (Length: 65)
#   Matches at position 24 : LLWDLV
#   Matches at position 25 : LWDLV
#   Found in: IP_084371|TX=9606 (Length: 32)
#   Matches at position 15 : LTWLV
#   Found in: IP_086772|TX=9606 (Length: 56)
#   Matches at position 6 : LTWDLA
#   Found in: IP_089842|TX=9606 (Length: 60)
#   Matches at position 20 : LTKDLV
#   Found in: IP_097026|TX=9606 (Length: 61)
#   Matches at position 38 : LTNDLV
#   Found in: IP_102425|TX=9606 (Length: 97)
#   Matches at position 63 : LTDLV
#   Found in: IP_103372|TX=9606 (Length: 35)
#   Matches at position 20 : LTWDV
#   Found in: IP_106156|TX=9606 (Length: 99)
#   Matches at position 93 : LTWLV
#   Found in: IP_106967|TX=9606 (Length: 93)
#   Matches at position 35 : LTWSLV
#   Found in: IP_108680|TX=9606 (Length: 59)
#   Matches at position 16 : LTWDLP
#   Found in: IP_112987|TX=9606 (Length: 58)
#   Matches at position 7 : LTWDLP
#   Found in: IP_113623|TX=9606 (Length: 60)
#   Matches at position 49 : LEWDLV
#   Found in: IP_121231|TX=9606 (Length: 47)
#   Matches at position 16 : LTWDLS
#   Found in: IP_123763|TX=9606 (Length: 57)
#   Matches at position 51 : LTWRLV
#   Found in: IP_131681|TX=9606 (Length: 44)
#   Matches at position 16 : LWDLV
#   Found in: IP_139822|TX=9606 (Length: 86)
#   Matches at position 48 : LGWDLV
#   Found in: IP_155137|TX=9606 (Length: 41)
#   Matches at position 13 : LTDLV
#   Found in: IP_161342|TX=9606 (Length: 55)
#   Matches at position 10 : LTYDLV
#   Found in: IP_163582|TX=9606 (Length: 31)
#   Matches at position 23 : RTWDLV
#   Matches at position 24 : TWDLV
# Protein: O95197-2_229 (Length: 6)
#   Found in: IP_074625|TX=9606 (Length: 38)
#   Matches at position 10 : SPFFVI
#   Found in: IP_076960|TX=9606 (Length: 38)
#   Matches at position 20 : SPFLVI
#   Found in: IP_083101|TX=9606 (Length: 98)
#   Matches at position 45 : SGFEVI
#   Found in: IP_084244|TX=9606 (Length: 32)
#   Matches at position 1 : SPFLVI
#   Found in: IP_093515|TX=9606 (Length: 42)
#   Matches at position 5 : SPFRVI
#   Found in: IP_094448|TX=9606 (Length: 34)
#   Matches at position 3 : SPFVI
#   Found in: IP_131660|TX=9606 (Length: 31)
#   Matches at position 15 : SFEVI
#   Found in: IP_133342|TX=9606 (Length: 43)
#   Matches at position 14 : SPFLVI
#   Found in: IP_143602|TX=9606 (Length: 97)
#   Matches at position 69 : SPFVI
#   Found in: IP_147325|TX=9606 (Length: 51)
#   Matches at position 10 : SPFSVI
#   Found in: IP_150630|TX=9606 (Length: 30)
#   Matches at position 2 : SPFVVI
#   Found in: IP_161723|TX=9606 (Length: 37)
#   Matches at position 8 : SPFPVI
#   Found in: IP_165290|TX=9606 (Length: 36)
#   Matches at position 29 : SPFEKI
#   Found in: IP_172520|TX=9606 (Length: 41)
#   Matches at position 23 : SPFVI
# Protein: O95197-2_198 (Length: 6)
#   Found in: IP_066722|TX=9606 (Length: 31)
#   Matches at position 26 : TEYKV
#   Found in: IP_084612|TX=9606 (Length: 35)
#   Matches at position 18 : TYSKV
#   Found in: IP_112459|TX=9606 (Length: 64)
#   Matches at position 16 : TELSKV
#   Found in: IP_126433|TX=9606 (Length: 38)
#   Matches at position 7 : TESKV
#   Found in: IP_157702|TX=9606 (Length: 46)
#   Matches at position 39 : TEYSKC
# Protein: O95197-2_186 (Length: 6)
#   Found in: IP_060763|TX=9606 (Length: 60)
#   Matches at position 44 : DRFLLL
#   Found in: IP_061315|TX=9606 (Length: 41)
#   Matches at position 21 : DRFTFL
#   Found in: IP_067455|TX=9606 (Length: 50)
#   Matches at position 27 : DRCTLL
#   Found in: IP_073536|TX=9606 (Length: 60)
#   Matches at position 52 : TRFTLL
#   Matches at position 53 : RFTLL
#   Found in: IP_088318|TX=9606 (Length: 65)
#   Matches at position 41 : DRTLL
#   Found in: IP_111542|TX=9606 (Length: 40)
#   Matches at position 3 : PRFTLL
#   Matches at position 4 : RFTLL
#   Found in: IP_122562|TX=9606 (Length: 56)
#   Matches at position 30 : DFTLL
#   Found in: IP_135449|TX=9606 (Length: 58)
#   Matches at position 12 : DRFLL
#   Found in: IP_136948|TX=9606 (Length: 67)
#   Matches at position 55 : FRFTLL
#   Matches at position 56 : RFTLL
#   Found in: IP_137254|TX=9606 (Length: 43)
#   Matches at position 36 : DRFALL
#   Found in: IP_140462|TX=9606 (Length: 83)
#   Matches at position 13 : DRFTLT
#   Found in: IP_140777|TX=9606 (Length: 32)
#   Matches at position 1 : DRFTLT
#   Found in: IP_149205|TX=9606 (Length: 72)
#   Matches at position 27 : DRFELL
#   Found in: IP_154463|TX=9606 (Length: 40)
#   Matches at position 27 : PRFTLL
#   Matches at position 28 : RFTLL
#   Found in: IP_155740|TX=9606 (Length: 50)
#   Matches at position 44 : DRTLL
#   Found in: IP_160057|TX=9606 (Length: 64)
#   Matches at position 37 : DFTLL
#   Found in: IP_163621|TX=9606 (Length: 35)
#   Matches at position 10 : DFTLL
#   Found in: IP_168700|TX=9606 (Length: 67)
#   Matches at position 13 : DRTLL
# Protein: O95197_248 (Length: 6)
#   Found in: IP_074625|TX=9606 (Length: 38)
#   Matches at position 10 : SPFFVI
#   Found in: IP_076960|TX=9606 (Length: 38)
#   Matches at position 20 : SPFLVI
#   Found in: IP_083101|TX=9606 (Length: 98)
#   Matches at position 45 : SGFEVI
#   Found in: IP_084244|TX=9606 (Length: 32)
#   Matches at position 1 : SPFLVI
#   Found in: IP_093515|TX=9606 (Length: 42)
#   Matches at position 5 : SPFRVI
#   Found in: IP_094448|TX=9606 (Length: 34)
#   Matches at position 3 : SPFVI
#   Found in: IP_131660|TX=9606 (Length: 31)
#   Matches at position 15 : SFEVI
#   Found in: IP_133342|TX=9606 (Length: 43)
#   Matches at position 14 : SPFLVI
#   Found in: IP_143602|TX=9606 (Length: 97)
#   Matches at position 69 : SPFVI
#   Found in: IP_147325|TX=9606 (Length: 51)
#   Matches at position 10 : SPFSVI
#   Found in: IP_150630|TX=9606 (Length: 30)
#   Matches at position 2 : SPFVVI
#   Found in: IP_161723|TX=9606 (Length: 37)
#   Matches at position 8 : SPFPVI
#   Found in: IP_165290|TX=9606 (Length: 36)
#   Matches at position 29 : SPFEKI
#   Found in: IP_172520|TX=9606 (Length: 41)
#   Matches at position 23 : SPFVI
# Protein: O95210_203 (Length: 6)
#   Found in: IP_122120|TX=9606 (Length: 40)
#   Matches at position 16 : EEEMV
# Protein: O95782_879 (Length: 6)
#   Found in: IP_066879|TX=9606 (Length: 33)
#   Matches at position 8 : QRWKQP
#   Found in: IP_092174|TX=9606 (Length: 43)
#   Matches at position 30 : QRRKQL
#   Found in: IP_092185|TX=9606 (Length: 42)
#   Matches at position 29 : QRRKQL
#   Found in: IP_095682|TX=9606 (Length: 100)
#   Matches at position 12 : QRWRQL
#   Found in: IP_095689|TX=9606 (Length: 60)
#   Matches at position 12 : QRWRQL
#   Found in: IP_098175|TX=9606 (Length: 32)
#   Matches at position 5 : QRKQL
#   Found in: IP_103828|TX=9606 (Length: 38)
#   Matches at position 12 : QWKQL
#   Found in: IP_109167|TX=9606 (Length: 37)
#   Matches at position 11 : QAWKQL
#   Found in: IP_112796|TX=9606 (Length: 63)
#   Matches at position 27 : QWKQL
#   Found in: IP_131155|TX=9606 (Length: 77)
#   Matches at position 3 : QRWLQL
#   Found in: IP_136844|TX=9606 (Length: 55)
#   Matches at position 44 : QRWKML
#   Found in: IP_142863|TX=9606 (Length: 37)
#   Matches at position 27 : QWKQL
#   Found in: IP_146642|TX=9606 (Length: 48)
#   Matches at position 42 : QRWKTL
#   Found in: IP_156778|TX=9606 (Length: 50)
#   Matches at position 45 : QRWKL
#   Found in: IP_159585|TX=9606 (Length: 51)
#   Matches at position 41 : QRWKL
#   Found in: IP_169621|TX=9606 (Length: 52)
#   Matches at position 28 : QRKQL
# Protein: P01137_257 (Length: 6)
#   Found in: IP_058214|TX=9606 (Length: 40)
#   Matches at position 7 : RPLLL
#   Found in: IP_059773|TX=9606 (Length: 37)
#   Matches at position 6 : RPFSLL
#   Found in: IP_060347|TX=9606 (Length: 29)
#   Matches at position 14 : YPFLLL
#   Matches at position 15 : PFLLL
#   Found in: IP_060763|TX=9606 (Length: 60)
#   Matches at position 45 : RFLLL
#   Found in: IP_060850|TX=9606 (Length: 56)
#   Matches at position 27 : RKFLLL
#   Found in: IP_063192|TX=9606 (Length: 29)
#   Matches at position 18 : TPFLLL
#   Matches at position 19 : PFLLL
#   Found in: IP_064327|TX=9606 (Length: 32)
#   Matches at position 2 : RPFLLS
#   Found in: IP_065203|TX=9606 (Length: 45)
#   Matches at position 39 : RPVLLL
#   Found in: IP_065563|TX=9606 (Length: 42)
#   Matches at position 21 : RPFLLP
#   Found in: IP_067603|TX=9606 (Length: 47)
#   Matches at position 27 : RKFLLL
#   Found in: IP_068443|TX=9606 (Length: 31)
#   Matches at position 8 : RFLLL
#   Found in: IP_068686|TX=9606 (Length: 38)
#   Matches at position 15 : RPSLLL
#   Found in: IP_069282|TX=9606 (Length: 31)
#   Matches at position 8 : RPGLLL
#   Found in: IP_069545|TX=9606 (Length: 42)
#   Matches at position 24 : QPFLLL
#   Matches at position 25 : PFLLL
#   Found in: IP_069954|TX=9606 (Length: 76)
#   Matches at position 25 : CPFLLL
#   Matches at position 26 : PFLLL
#   Found in: IP_070725|TX=9606 (Length: 36)
#   Matches at position 2 : QPFLLL
#   Matches at position 3 : PFLLL
#   Found in: IP_071060|TX=9606 (Length: 96)
#   Matches at position 68 : RPLLL
#   Found in: IP_071099|TX=9606 (Length: 47)
#   Matches at position 7 : RTFLLL
#   Found in: IP_071410|TX=9606 (Length: 32)
#   Matches at position 10 : RPFLPL
#   Found in: IP_071476|TX=9606 (Length: 29)
#   Matches at position 2 : RPCLLL
#   Found in: IP_072116|TX=9606 (Length: 84)
#   Matches at position 16 : RPSLLL
#   Found in: IP_072129|TX=9606 (Length: 73)
#   Matches at position 16 : RPSLLL
#   Found in: IP_072131|TX=9606 (Length: 74)
#   Matches at position 16 : RPSLLL
#   Found in: IP_072136|TX=9606 (Length: 83)
#   Matches at position 16 : RPSLLL
#   Found in: IP_072275|TX=9606 (Length: 39)
#   Matches at position 26 : RPAFLLL
#   Found in: IP_072442|TX=9606 (Length: 38)
#   Matches at position 33 : RPLLL
#   Found in: IP_072642|TX=9606 (Length: 52)
#   Matches at position 8 : RSFLLL
#   Found in: IP_073478|TX=9606 (Length: 77)
#   Matches at position 40 : RAFLLL
#   Found in: IP_074825|TX=9606 (Length: 60)
#   Matches at position 33 : RPLLL
#   Found in: IP_075269|TX=9606 (Length: 48)
#   Matches at position 29 : RPSLLL
#   Found in: IP_075511|TX=9606 (Length: 29)
#   Matches at position 19 : RFLLL
#   Found in: IP_075530|TX=9606 (Length: 99)
#   Matches at position 4 : RPQLLL
#   Found in: IP_075550|TX=9606 (Length: 91)
#   Matches at position 4 : RPQLLL
#   Found in: IP_075761|TX=9606 (Length: 79)
#   Matches at position 12 : RPLLL
#   Found in: IP_077879|TX=9606 (Length: 47)
#   Matches at position 3 : HPFLLL
#   Matches at position 4 : PFLLL
#   Found in: IP_078202|TX=9606 (Length: 31)
#   Matches at position 24 : RNFLLL
#   Found in: IP_078376|TX=9606 (Length: 65)
#   Matches at position 53 : RFLLL
#   Found in: IP_078394|TX=9606 (Length: 53)
#   Matches at position 23 : RFLLL
#   Found in: IP_079491|TX=9606 (Length: 53)
#   Matches at position 9 : RPLLL
#   Found in: IP_080120|TX=9606 (Length: 81)
#   Matches at position 29 : RPFLPL
#   Found in: IP_082142|TX=9606 (Length: 67)
#   Matches at position 28 : RIFLLL
#   Found in: IP_082346|TX=9606 (Length: 67)
#   Matches at position 28 : RIFLLL
#   Found in: IP_082664|TX=9606 (Length: 99)
#   Matches at position 88 : RPLLL
#   Found in: IP_082681|TX=9606 (Length: 34)
#   Matches at position 26 : RDFLLL
#   Found in: IP_083504|TX=9606 (Length: 90)
#   Matches at position 16 : RPALLL
#   Found in: IP_084584|TX=9606 (Length: 70)
#   Matches at position 63 : LPFLLL
#   Matches at position 64 : PFLLL
#   Found in: IP_085651|TX=9606 (Length: 61)
#   Matches at position 36 : RPLLL
#   Found in: IP_089536|TX=9606 (Length: 38)
#   Matches at position 23 : RPSLLL
#   Found in: IP_089592|TX=9606 (Length: 99)
#   Matches at position 63 : QPFLLL
#   Matches at position 64 : PFLLL
#   Found in: IP_090080|TX=9606 (Length: 53)
#   Matches at position 7 : RDFLLL
#   Found in: II_092917|TX=9606 (Length: 35)
#   Matches at position 24 : LPFLLL
#   Matches at position 25 : PFLLL
#   Found in: IP_093306|TX=9606 (Length: 47)
#   Matches at position 30 : RPFLHL
#   Found in: IP_093340|TX=9606 (Length: 35)
#   Matches at position 5 : RSFLLL
#   Found in: IP_094411|TX=9606 (Length: 39)
#   Matches at position 8 : VRPFLLL
#   Matches at position 9 : RPFLLL
#   Matches at position 10 : PFLLL
#   Found in: IP_095728|TX=9606 (Length: 81)
#   Matches at position 19 : RPLLL
#   Found in: II_099485|TX=9606 (Length: 69)
#   Matches at position 15 : RFLLL
#   Found in: IP_099832|TX=9606 (Length: 44)
#   Matches at position 14 : RPLLLL
#   Found in: IP_099931|TX=9606 (Length: 43)
#   Matches at position 7 : RPFLLG
#   Found in: IP_100039|TX=9606 (Length: 51)
#   Matches at position 12 : RVFLLL
#   Found in: IP_100699|TX=9606 (Length: 41)
#   Matches at position 5 : RPAFLLL
#   Found in: II_100720|TX=9606 (Length: 90)
#   Matches at position 55 : RPLLL
#   Found in: IP_103630|TX=9606 (Length: 60)
#   Matches at position 2 : RGPFLLL
#   Matches at position 3 : GPFLLL
#   Matches at position 4 : PFLLL
#   Found in: IP_104914|TX=9606 (Length: 44)
#   Matches at position 11 : IPFLLL
#   Matches at position 12 : PFLLL
#   Found in: IP_106255|TX=9606 (Length: 38)
#   Matches at position 19 : RPVLLL
#   Found in: IP_106437|TX=9606 (Length: 60)
#   Matches at position 22 : VPFLLL
#   Matches at position 23 : PFLLL
#   Found in: IP_107578|TX=9606 (Length: 39)
#   Matches at position 13 : RFLLL
#   Found in: IP_107875|TX=9606 (Length: 38)
#   Matches at position 4 : RFLLL
#   Found in: IP_108050|TX=9606 (Length: 71)
#   Matches at position 35 : ERPFLLL
#   Matches at position 36 : RPFLLL
#   Matches at position 37 : PFLLL
#   Found in: IP_108559|TX=9606 (Length: 32)
#   Matches at position 15 : RFLLL
#   Found in: IP_108749|TX=9606 (Length: 53)
#   Matches at position 42 : RPFFLL
#   Found in: IP_109107|TX=9606 (Length: 48)
#   Matches at position 17 : RPSFLLL
#   Found in: IP_110421|TX=9606 (Length: 54)
#   Matches at position 41 : RFFLLL
#   Found in: IP_111449|TX=9606 (Length: 43)
#   Matches at position 8 : RFFLLL
#   Found in: IP_112398|TX=9606 (Length: 42)
#   Matches at position 21 : RPFLVL
#   Found in: IP_114420|TX=9606 (Length: 62)
#   Matches at position 18 : RPSLLL
#   Found in: IP_114514|TX=9606 (Length: 35)
#   Matches at position 23 : RFLLL
#   Found in: IP_114664|TX=9606 (Length: 58)
#   Matches at position 15 : RLPFLLL
#   Matches at position 16 : LPFLLL
#   Matches at position 17 : PFLLL
#   Found in: II_115951|TX=9606 (Length: 63)
#   Matches at position 11 : RRFLLL
#   Matches at position 12 : RFLLL
#   Found in: IP_116744|TX=9606 (Length: 31)
#   Matches at position 17 : RPLLLL
#   Found in: IP_117067|TX=9606 (Length: 43)
#   Matches at position 12 : RPLLL
#   Found in: IP_117430|TX=9606 (Length: 42)
#   Matches at position 9 : RPSLLL
#   Found in: IP_117552|TX=9606 (Length: 57)
#   Matches at position 27 : RVFLLL
#   Found in: IP_118441|TX=9606 (Length: 29)
#   Matches at position 18 : APFLLL
#   Matches at position 19 : PFLLL
#   Found in: IP_118709|TX=9606 (Length: 37)
#   Matches at position 9 : HPFLLL
#   Matches at position 10 : PFLLL
#   Found in: IP_118711|TX=9606 (Length: 32)
#   Matches at position 9 : HPFLLL
#   Matches at position 10 : PFLLL
#   Found in: IP_119225|TX=9606 (Length: 67)
#   Matches at position 49 : YPFLLL
#   Matches at position 50 : PFLLL
#   Found in: IP_120407|TX=9606 (Length: 31)
#   Matches at position 21 : RIFLLL
#   Found in: IP_120806|TX=9606 (Length: 90)
#   Matches at position 62 : RPFLHL
#   Found in: IP_121196|TX=9606 (Length: 76)
#   Matches at position 61 : RPLLL
#   Found in: IP_122681|TX=9606 (Length: 50)
#   Matches at position 34 : RPFLPL
#   Found in: IP_122699|TX=9606 (Length: 48)
#   Matches at position 34 : RPFLPL
#   Found in: IP_122982|TX=9606 (Length: 75)
#   Matches at position 3 : RSFLLL
#   Found in: IP_123293|TX=9606 (Length: 35)
#   Matches at position 6 : RPLLL
#   Found in: IP_124787|TX=9606 (Length: 67)
#   Matches at position 28 : RIFLLL
#   Found in: IP_125053|TX=9606 (Length: 51)
#   Matches at position 7 : PPFLLL
#   Matches at position 8 : PFLLL
#   Found in: IP_125253|TX=9606 (Length: 53)
#   Matches at position 25 : RPFLRL
#   Found in: IP_125630|TX=9606 (Length: 60)
#   Matches at position 49 : RPHLLL
#   Found in: IP_131007|TX=9606 (Length: 70)
#   Matches at position 31 : RPFGLL
#   Found in: IP_131715|TX=9606 (Length: 47)
#   Matches at position 29 : VPFLLL
#   Matches at position 30 : PFLLL
#   Found in: IP_131997|TX=9606 (Length: 78)
#   Matches at position 40 : RPLLL
#   Found in: IP_132142|TX=9606 (Length: 47)
#   Matches at position 39 : CPFLLL
#   Matches at position 40 : PFLLL
#   Found in: IP_132650|TX=9606 (Length: 56)
#   Matches at position 26 : SPFLLL
#   Matches at position 27 : PFLLL
#   Found in: IP_133536|TX=9606 (Length: 57)
#   Matches at position 13 : RTFLLL
#   Found in: IP_137422|TX=9606 (Length: 29)
#   Matches at position 1 : RPLLLL
#   Found in: IP_137907|TX=9606 (Length: 66)
#   Matches at position 52 : RPFLRL
#   Found in: IP_139917|TX=9606 (Length: 43)
#   Matches at position 32 : RPRLLL
#   Found in: IP_140344|TX=9606 (Length: 50)
#   Matches at position 24 : RPFYLL
#   Found in: IP_141103|TX=9606 (Length: 55)
#   Matches at position 42 : IPFLLL
#   Matches at position 43 : PFLLL
#   Found in: IP_142513|TX=9606 (Length: 52)
#   Matches at position 20 : RPFILL
#   Found in: IP_143261|TX=9606 (Length: 30)
#   Matches at position 16 : RCFLLL
#   Found in: IP_144470|TX=9606 (Length: 54)
#   Matches at position 1 : RPCLLL
#   Found in: IP_144838|TX=9606 (Length: 49)
#   Matches at position 10 : SPFLLL
#   Matches at position 11 : PFLLL
#   Found in: IP_147390|TX=9606 (Length: 53)
#   Matches at position 9 : RPLLL
#   Found in: IP_147853|TX=9606 (Length: 51)
#   Matches at position 30 : RPPLLL
#   Found in: IP_148239|TX=9606 (Length: 34)
#   Matches at position 7 : RPVLLL
#   Found in: IP_148313|TX=9606 (Length: 40)
#   Matches at position 2 : RLFLLL
#   Found in: IP_153810|TX=9606 (Length: 47)
#   Matches at position 33 : RPLLL
#   Found in: IP_154338|TX=9606 (Length: 51)
#   Matches at position 29 : RRFLLL
#   Matches at position 30 : RFLLL
#   Found in: IP_154383|TX=9606 (Length: 29)
#   Matches at position 3 : RVFLLL
#   Found in: IP_154689|TX=9606 (Length: 62)
#   Matches at position 9 : RPLLL
#   Found in: IP_156224|TX=9606 (Length: 55)
#   Matches at position 9 : RFLLL
#   Found in: IP_156796|TX=9606 (Length: 96)
#   Matches at position 32 : RPLLLL
#   Found in: IP_157030|TX=9606 (Length: 35)
#   Matches at position 11 : RPLLL
#   Found in: IP_157373|TX=9606 (Length: 68)
#   Matches at position 21 : RCFLLL
#   Found in: IP_158399|TX=9606 (Length: 76)
#   Matches at position 56 : LPFLLL
#   Matches at position 57 : PFLLL
#   Found in: IP_159748|TX=9606 (Length: 76)
#   Matches at position 0 : MPFLLL
#   Matches at position 1 : PFLLL
#   Found in: IP_159913|TX=9606 (Length: 67)
#   Matches at position 28 : RIFLLL
#   Found in: IP_160217|TX=9606 (Length: 34)
#   Matches at position 26 : RTFLLL
#   Found in: IP_160830|TX=9606 (Length: 65)
#   Matches at position 27 : RPRLLL
#   Found in: IP_161344|TX=9606 (Length: 31)
#   Matches at position 24 : RPLLL
#   Found in: IP_162347|TX=9606 (Length: 60)
#   Matches at position 46 : RTPFLLL
#   Matches at position 47 : TPFLLL
#   Matches at position 48 : PFLLL
#   Found in: IP_163218|TX=9606 (Length: 75)
#   Matches at position 43 : RTFLLL
#   Found in: IP_166980|TX=9606 (Length: 59)
#   Matches at position 28 : RFLLL
#   Found in: IP_167319|TX=9606 (Length: 96)
#   Matches at position 28 : RPFLLE
#   Found in: IP_169093|TX=9606 (Length: 49)
#   Matches at position 34 : NPFLLL
#   Matches at position 35 : PFLLL
#   Found in: IP_169813|TX=9606 (Length: 34)
#   Matches at position 7 : TPFLLL
#   Matches at position 8 : PFLLL
#   Matches at position 13 : RPFLLE
#   Found in: IP_169839|TX=9606 (Length: 64)
#   Matches at position 23 : RPFLLV
#   Found in: IP_171037|TX=9606 (Length: 40)
#   Matches at position 9 : RPPLLL
# Protein: P01137_17 (Length: 6)
#   Found in: IP_058509|TX=9606 (Length: 58)
#   Matches at position 32 : PLLWLLV
#   Matches at position 33 : LLWLLV
#   Matches at position 34 : LWLLV
#   Found in: IP_058649|TX=9606 (Length: 50)
#   Matches at position 44 : VLWLLV
#   Matches at position 45 : LWLLV
#   Found in: IP_059252|TX=9606 (Length: 33)
#   Matches at position 24 : LLLLLV
#   Matches at position 25 : LLLLV
#   Found in: IP_062489|TX=9606 (Length: 84)
#   Matches at position 44 : LLWLAV
#   Found in: IP_064367|TX=9606 (Length: 33)
#   Matches at position 26 : LLLLV
#   Found in: IP_064652|TX=9606 (Length: 59)
#   Matches at position 2 : LLLLV
#   Found in: IP_065659|TX=9606 (Length: 36)
#   Matches at position 28 : LLFLLV
#   Found in: IP_067832|TX=9606 (Length: 34)
#   Matches at position 20 : LAWLLV
#   Found in: IP_070046|TX=9606 (Length: 82)
#   Matches at position 42 : LLWLLL
#   Found in: IP_072008|TX=9606 (Length: 51)
#   Matches at position 42 : LLCLLV
#   Found in: IP_072357|TX=9606 (Length: 72)
#   Matches at position 50 : RLWLLV
#   Matches at position 51 : LWLLV
#   Found in: IP_073198|TX=9606 (Length: 86)
#   Matches at position 8 : LLSLLV
#   Found in: IP_073512|TX=9606 (Length: 30)
#   Matches at position 1 : LLLLV
#   Found in: IP_074171|TX=9606 (Length: 46)
#   Matches at position 34 : LLWLLP
#   Found in: IP_074218|TX=9606 (Length: 65)
#   Matches at position 46 : LLLLV
#   Found in: IP_075079|TX=9606 (Length: 43)
#   Matches at position 3 : LLWLV
#   Found in: IP_075094|TX=9606 (Length: 60)
#   Matches at position 54 : LLQLLV
#   Found in: IP_077003|TX=9606 (Length: 46)
#   Matches at position 7 : LLLLLV
#   Matches at position 8 : LLLLV
#   Found in: IP_077075|TX=9606 (Length: 35)
#   Matches at position 3 : LLWLLC
#   Found in: IP_077615|TX=9606 (Length: 45)
#   Matches at position 15 : LLWPLV
#   Found in: IP_078229|TX=9606 (Length: 44)
#   Matches at position 12 : LLWFLV
#   Found in: IP_080043|TX=9606 (Length: 67)
#   Matches at position 19 : LLLLV
#   Found in: IP_080051|TX=9606 (Length: 67)
#   Matches at position 19 : LLLLV
#   Found in: IP_080516|TX=9606 (Length: 67)
#   Matches at position 29 : LLLLV
#   Found in: IP_080705|TX=9606 (Length: 65)
#   Matches at position 24 : LLWDLV
#   Found in: IP_085693|TX=9606 (Length: 41)
#   Matches at position 10 : LLWLLL
#   Found in: IP_085932|TX=9606 (Length: 31)
#   Matches at position 22 : LLLLV
#   Found in: IP_086267|TX=9606 (Length: 46)
#   Matches at position 19 : LLMLLV
#   Found in: IP_087303|TX=9606 (Length: 75)
#   Matches at position 23 : LLMLLV
#   Found in: IP_089802|TX=9606 (Length: 80)
#   Matches at position 46 : LLILLV
#   Found in: IP_090984|TX=9606 (Length: 29)
#   Matches at position 12 : LLLLV
#   Found in: IP_094936|TX=9606 (Length: 46)
#   Matches at position 30 : LLWLLP
#   Found in: IP_096243|TX=9606 (Length: 76)
#   Matches at position 44 : LLLLLV
#   Matches at position 45 : LLLLV
#   Found in: IP_096713|TX=9606 (Length: 31)
#   Matches at position 22 : LAWLLV
#   Found in: IP_096817|TX=9606 (Length: 68)
#   Matches at position 57 : LQWLLV
#   Found in: IP_097250|TX=9606 (Length: 48)
#   Matches at position 26 : QLWLLV
#   Matches at position 27 : LWLLV
#   Found in: IP_097993|TX=9606 (Length: 85)
#   Matches at position 19 : LLLLV
#   Found in: IP_100333|TX=9606 (Length: 96)
#   Matches at position 51 : LLLLLV
#   Matches at position 52 : LLLLV
#   Found in: IP_100356|TX=9606 (Length: 77)
#   Matches at position 51 : LLLLLV
#   Matches at position 52 : LLLLV
#   Found in: IP_101909|TX=9606 (Length: 73)
#   Matches at position 48 : LLWLV
#   Found in: IP_102121|TX=9606 (Length: 36)
#   Matches at position 6 : LLMLLV
#   Found in: IP_102683|TX=9606 (Length: 31)
#   Matches at position 12 : DLWLLV
#   Matches at position 13 : LWLLV
#   Found in: IP_103304|TX=9606 (Length: 85)
#   Matches at position 60 : LGWLLV
#   Found in: IP_104754|TX=9606 (Length: 61)
#   Matches at position 11 : WLWLLV
#   Matches at position 12 : LWLLV
#   Found in: IP_104760|TX=9606 (Length: 58)
#   Matches at position 11 : WLWLLV
#   Matches at position 12 : LWLLV
#   Found in: IP_104914|TX=9606 (Length: 44)
#   Matches at position 14 : LLLLV
#   Found in: IP_106559|TX=9606 (Length: 55)
#   Matches at position 41 : LLWLLS
#   Found in: IP_106670|TX=9606 (Length: 36)
#   Matches at position 13 : LLLLV
#   Found in: IP_108847|TX=9606 (Length: 67)
#   Matches at position 15 : LAWLLV
#   Found in: IP_110585|TX=9606 (Length: 36)
#   Matches at position 14 : LLELLV
#   Found in: II_110660|TX=9606 (Length: 48)
#   Matches at position 3 : LLLLLV
#   Matches at position 4 : LLLLV
#   Found in: IP_111000|TX=9606 (Length: 74)
#   Matches at position 56 : LLWLV
#   Found in: IP_113492|TX=9606 (Length: 42)
#   Matches at position 4 : LLLLV
#   Found in: IP_113825|TX=9606 (Length: 61)
#   Matches at position 8 : LLFLLV
#   Found in: IP_114531|TX=9606 (Length: 50)
#   Matches at position 30 : LLWLLY
#   Found in: IP_116744|TX=9606 (Length: 31)
#   Matches at position 19 : LLLLV
#   Found in: IP_116845|TX=9606 (Length: 44)
#   Matches at position 23 : LLWLV
#   Found in: IP_117699|TX=9606 (Length: 34)
#   Matches at position 8 : LLLLLV
#   Matches at position 9 : LLLLV
#   Found in: IP_117720|TX=9606 (Length: 46)
#   Matches at position 32 : LLLLV
#   Found in: IP_118126|TX=9606 (Length: 52)
#   Matches at position 20 : QLWLLV
#   Matches at position 21 : LWLLV
#   Found in: IP_118128|TX=9606 (Length: 51)
#   Matches at position 29 : LLLLLV
#   Matches at position 30 : LLLLV
#   Found in: IP_119533|TX=9606 (Length: 33)
#   Matches at position 15 : LSWLLV
#   Found in: IP_120255|TX=9606 (Length: 44)
#   Matches at position 11 : LLNLLV
#   Found in: IP_121629|TX=9606 (Length: 29)
#   Matches at position 2 : LLMLLV
#   Found in: IP_121981|TX=9606 (Length: 72)
#   Matches at position 10 : LLLLV
#   Found in: IP_123329|TX=9606 (Length: 72)
#   Matches at position 48 : LLWLEV
#   Found in: II_123429|TX=9606 (Length: 51)
#   Matches at position 17 : LLLLV
#   Found in: IP_124382|TX=9606 (Length: 58)
#   Matches at position 18 : LLLLV
#   Found in: IP_124416|TX=9606 (Length: 38)
#   Matches at position 26 : LLWALLV
#   Found in: IP_124481|TX=9606 (Length: 31)
#   Matches at position 2 : FLWLLV
#   Matches at position 3 : LWLLV
#   Found in: IP_125670|TX=9606 (Length: 64)
#   Matches at position 43 : LLLLV
#   Found in: IP_125875|TX=9606 (Length: 34)
#   Matches at position 1 : LLLLV
#   Found in: IP_127639|TX=9606 (Length: 36)
#   Matches at position 19 : LLHLLV
#   Found in: IP_128341|TX=9606 (Length: 59)
#   Matches at position 27 : LLLLLV
#   Matches at position 28 : LLLLV
#   Found in: IP_129258|TX=9606 (Length: 85)
#   Matches at position 66 : LLWLEV
#   Found in: IP_129890|TX=9606 (Length: 96)
#   Matches at position 64 : LLLLV
#   Found in: IP_129894|TX=9606 (Length: 39)
#   Matches at position 7 : LLLLV
#   Found in: IP_130375|TX=9606 (Length: 32)
#   Matches at position 25 : LLLLV
#   Found in: IP_131490|TX=9606 (Length: 33)
#   Matches at position 11 : LLWLAV
#   Found in: IP_131830|TX=9606 (Length: 67)
#   Matches at position 2 : LLWLYV
#   Found in: IP_132339|TX=9606 (Length: 83)
#   Matches at position 58 : LLVLLV
#   Found in: IP_132345|TX=9606 (Length: 34)
#   Matches at position 9 : LLVLLV
#   Found in: IP_133783|TX=9606 (Length: 47)
#   Matches at position 8 : LLWLV
#   Found in: IP_134546|TX=9606 (Length: 36)
#   Matches at position 16 : LLLLV
#   Found in: IP_136012|TX=9606 (Length: 80)
#   Matches at position 25 : LLLLV
#   Found in: IP_136277|TX=9606 (Length: 54)
#   Matches at position 48 : LLTLLV
#   Found in: II_137798|TX=9606 (Length: 32)
#   Matches at position 10 : LLLLV
#   Found in: IP_138247|TX=9606 (Length: 74)
#   Matches at position 46 : LLWLLR
#   Found in: IP_139387|TX=9606 (Length: 87)
#   Matches at position 17 : LLPLLV
#   Found in: IP_139400|TX=9606 (Length: 84)
#   Matches at position 52 : LLWLLM
#   Found in: IP_139750|TX=9606 (Length: 57)
#   Matches at position 52 : LLWLL
#   Found in: IP_139917|TX=9606 (Length: 43)
#   Matches at position 35 : LLLLV
#   Found in: IP_140277|TX=9606 (Length: 42)
#   Matches at position 2 : LLLLV
#   Found in: IP_140786|TX=9606 (Length: 58)
#   Matches at position 37 : LLWLLL
#   Found in: IP_142093|TX=9606 (Length: 29)
#   Matches at position 8 : LLLLV
#   Found in: IP_142130|TX=9606 (Length: 91)
#   Matches at position 56 : LLILLV
#   Found in: IP_142484|TX=9606 (Length: 66)
#   Matches at position 15 : LLLLV
#   Found in: IP_143640|TX=9606 (Length: 93)
#   Matches at position 75 : LLWLLE
#   Found in: IP_145014|TX=9606 (Length: 93)
#   Matches at position 75 : LLWILV
#   Found in: IP_145825|TX=9606 (Length: 32)
#   Matches at position 9 : LLILLV
#   Found in: L8E8A8|TX=9606 (Length: 45)
#   Matches at position 9 : LLWLLE
#   Found in: IP_146808|TX=9606 (Length: 45)
#   Matches at position 11 : LLWLV
#   Found in: IP_147429|TX=9606 (Length: 48)
#   Matches at position 1 : LLFLLV
#   Found in: IP_147634|TX=9606 (Length: 30)
#   Matches at position 10 : LLLLV
#   Found in: IP_149005|TX=9606 (Length: 41)
#   Matches at position 33 : LLLLV
#   Found in: IP_149007|TX=9606 (Length: 38)
#   Matches at position 22 : LLNLLV
#   Found in: IP_149439|TX=9606 (Length: 89)
#   Matches at position 40 : LLWLGLV
#   Found in: IP_151255|TX=9606 (Length: 30)
#   Matches at position 19 : LLLLV
#   Found in: IP_151666|TX=9606 (Length: 43)
#   Matches at position 31 : LLTLLV
#   Found in: IP_152564|TX=9606 (Length: 39)
#   Matches at position 6 : LLLLV
#   Found in: II_152740|TX=9606 (Length: 70)
#   Matches at position 29 : LLSLLV
#   Found in: IP_154014|TX=9606 (Length: 31)
#   Matches at position 24 : LLWLLY
#   Found in: IP_154419|TX=9606 (Length: 62)
#   Matches at position 2 : LLVLLV
#   Matches at position 5 : LLVLLV
#   Found in: IP_154421|TX=9606 (Length: 95)
#   Matches at position 56 : LLVLLV
#   Matches at position 59 : LLVLLV
#   Found in: IP_155778|TX=9606 (Length: 52)
#   Matches at position 18 : LLLLLV
#   Matches at position 19 : LLLLV
#   Found in: IP_156867|TX=9606 (Length: 44)
#   Matches at position 8 : LLLLV
# ...
#   Found in: IP_159865|TX=9606 (Length: 54)
#   Matches at position 34 : SSYGIL
#   Found in: IP_162050|TX=9606 (Length: 70)
#   Matches at position 61 : SSLGSL
#   Found in: IP_167134|TX=9606 (Length: 50)
#   Matches at position 27 : SSGSL
#   Found in: IP_168433|TX=9606 (Length: 63)
#   Matches at position 53 : SSGSL
#   Found in: IP_169091|TX=9606 (Length: 69)
#   Matches at position 44 : SSGSL
#   Found in: IP_169170|TX=9606 (Length: 95)
#   Matches at position 9 : SSGSL
#   Found in: IP_170062|TX=9606 (Length: 29)
#   Matches at position 10 : SSSGSL
#   Matches at position 11 : SSGSL
#   Found in: IP_172586|TX=9606 (Length: 55)
#   Matches at position 23 : SSGSL
#   Found in: IP_172878|TX=9606 (Length: 65)
#   Matches at position 46 : SSSGSL
#   Matches at position 47 : SSGSL
#   Found in: IP_173133|TX=9606 (Length: 38)
#   Matches at position 7 : SSRGSL
# Protein: Q9UHK0_247 (Length: 6)
#   Found in: IP_059445|TX=9606 (Length: 29)
#   Matches at position 7 : KNPTL
#   Found in: IP_059451|TX=9606 (Length: 29)
#   Matches at position 7 : KNPTL
#   Found in: IP_065296|TX=9606 (Length: 43)
#   Matches at position 14 : KYPTL
#   Found in: IP_077707|TX=9606 (Length: 43)
#   Matches at position 37 : KNYLTL
#   Found in: IP_078324|TX=9606 (Length: 44)
#   Matches at position 17 : KNYPL
#   Found in: IP_083106|TX=9606 (Length: 51)
#   Matches at position 17 : KNYFTL
#   Found in: IP_095362|TX=9606 (Length: 72)
#   Matches at position 21 : KQYPTL
#   Found in: IP_101860|TX=9606 (Length: 84)
#   Matches at position 21 : KNYSTL
#   Found in: IP_107616|TX=9606 (Length: 98)
#   Matches at position 74 : KNQPTL
#   Found in: L8EC73|TX=9606 (Length: 55)
#   Matches at position 35 : KNPTL
#   Found in: IP_119166|TX=9606 (Length: 36)
#   Matches at position 21 : KNYTL
#   Found in: IP_143147|TX=9606 (Length: 38)
#   Matches at position 14 : KVYPTL
#   Found in: IP_143714|TX=9606 (Length: 29)
#   Matches at position 15 : VNYPTL
#   Matches at position 16 : NYPTL
#   Found in: IP_146127|TX=9606 (Length: 57)
#   Matches at position 43 : KNYPL
#   Found in: IP_149292|TX=9606 (Length: 43)
#   Matches at position 24 : KNYPPL
#   Found in: IP_169591|TX=9606 (Length: 62)
#   Matches at position 38 : KNYTL
# Protein: Q9UHK0_40 (Length: 6)
#   Found in: IP_091008|TX=9606 (Length: 50)
#   Matches at position 0 : MCWAML
# Protein: Q9ULG6_14 (Length: 6)
#   Found in: IP_061120|TX=9606 (Length: 52)
#   Matches at position 35 : RCGWTVI
#   Matches at position 36 : CGWTVI
#   Matches at position 37 : GWTVI
#   Found in: II_065332|TX=9606 (Length: 56)
#   Matches at position 29 : CGWTI
#   Found in: IP_105386|TX=9606 (Length: 44)
#   Matches at position 1 : CWTVI
#   Found in: IP_116165|TX=9606 (Length: 29)
#   Matches at position 6 : CGKTVI
#   Found in: IP_156586|TX=9606 (Length: 41)
#   Matches at position 18 : CWTVI
# Protein: Q9UQF2_336 (Length: 6)
#   Found in: IP_077190|TX=9606 (Length: 43)
#   Matches at position 13 : EGRDCL
#   Found in: IP_079901|TX=9606 (Length: 44)
#   Matches at position 7 : EGFSCL
#   Found in: IP_088837|TX=9606 (Length: 95)
#   Matches at position 71 : EGFCL
#   Found in: IP_089745|TX=9606 (Length: 72)
#   Matches at position 42 : EGDCL
#   Found in: IP_117448|TX=9606 (Length: 37)
#   Matches at position 12 : DGFDCL
#   Matches at position 13 : GFDCL
#   Found in: IP_119875|TX=9606 (Length: 52)
#   Matches at position 45 : EFDCL
#   Found in: IP_120711|TX=9606 (Length: 49)
#   Matches at position 14 : EGFCL
#   Found in: IP_124677|TX=9606 (Length: 30)
#   Matches at position 12 : EGDCL
#   Found in: IP_158040|TX=9606 (Length: 76)
#   Matches at position 57 : EGFCL
#   Found in: IP_159787|TX=9606 (Length: 54)
#   Matches at position 44 : EGDCL
#   Found in: IP_163281|TX=9606 (Length: 29)
#   Matches at position 19 : EGFDLL
# Protein: Q9Y4G2_635 (Length: 6)
#   Found in: IP_066344|TX=9606 (Length: 47)
#   Matches at position 34 : DEWVVV
# Protein: Q9Y4K3_406 (Length: 6)
#   Found in: IP_058208|TX=9606 (Length: 76)
#   Matches at position 24 : ANYSL
#   Found in: IP_072404|TX=9606 (Length: 29)
#   Matches at position 19 : ANYIL
#   Found in: IP_091145|TX=9606 (Length: 50)
#   Matches at position 45 : AYISL
#   Found in: IP_092021|TX=9606 (Length: 35)
#   Matches at position 19 : ANEISL
#   Found in: IP_096748|TX=9606 (Length: 34)
#   Matches at position 6 : ANYSSL
#   Found in: IP_102242|TX=9606 (Length: 61)
#   Matches at position 4 : ANYIL
#   Found in: IP_118906|TX=9606 (Length: 57)
#   Matches at position 25 : AEYISL
#   Found in: IP_123710|TX=9606 (Length: 56)
#   Matches at position 11 : AVYISL
#   Found in: IP_130025|TX=9606 (Length: 71)
#   Matches at position 44 : AYISL
#   Found in: L0R6M0|TX=9606 (Length: 57)
#   Matches at position 8 : ANAISL
#   Found in: IP_132475|TX=9606 (Length: 35)
#   Matches at position 18 : AFYISL
#   Found in: IP_134790|TX=9606 (Length: 31)
#   Matches at position 18 : AGYISL
#   Found in: IP_136635|TX=9606 (Length: 32)
#   Matches at position 24 : ANYSL
#   Found in: IP_140133|TX=9606 (Length: 34)
#   Matches at position 19 : ANYSL
#   Found in: IP_141920|TX=9606 (Length: 36)
#   Matches at position 19 : ANYIL
#   Found in: IP_152425|TX=9606 (Length: 74)
#   Matches at position 14 : YNYISL
#   Matches at position 15 : NYISL
#   Found in: IP_157798|TX=9606 (Length: 43)
#   Matches at position 15 : ANISL
#   Found in: IP_158085|TX=9606 (Length: 44)
#   Matches at position 9 : ENYISL
#   Matches at position 10 : NYISL
#   Found in: II_165874|TX=9606 (Length: 65)
#   Matches at position 29 : PNYISL
#   Matches at position 30 : NYISL
#   Found in: IP_170046|TX=9606 (Length: 64)
#   Matches at position 28 : AYISL
# Protein: Q9Y4P1_388 (Length: 6)
#   Found in: IP_067873|TX=9606 (Length: 55)
#   Matches at position 24 : EAFEIL
#   Found in: IP_093016|TX=9606 (Length: 49)
#   Matches at position 14 : EDFWIL
#   Found in: II_097771|TX=9606 (Length: 32)
#   Matches at position 23 : DEDFEIL
#   Matches at position 24 : EDFEIL
#   Matches at position 25 : DFEIL
#   Found in: IP_104083|TX=9606 (Length: 94)
#   Matches at position 51 : EDFKIL
#   Found in: IP_104464|TX=9606 (Length: 75)
#   Matches at position 29 : EFEIL
#   Found in: IP_112441|TX=9606 (Length: 34)
#   Matches at position 14 : EDFSIL
#   Found in: IP_113688|TX=9606 (Length: 31)
#   Matches at position 12 : EKFEIL
#   Found in: IP_119066|TX=9606 (Length: 46)
#   Matches at position 38 : EDFSIL
#   Found in: IP_119662|TX=9606 (Length: 93)
#   Matches at position 35 : EDFRIL
#   Found in: IP_131610|TX=9606 (Length: 33)
#   Matches at position 17 : ECFEIL
#   Found in: IP_142590|TX=9606 (Length: 51)
#   Matches at position 26 : EDWEIL
#   Found in: IP_146153|TX=9606 (Length: 29)
#   Matches at position 1 : EDFFIL
#   Found in: IP_148719|TX=9606 (Length: 33)
#   Matches at position 6 : ELFEIL
#   Found in: IP_151123|TX=9606 (Length: 38)
#   Matches at position 23 : KDFEIL
#   Matches at position 24 : DFEIL
#   Found in: IP_155988|TX=9606 (Length: 54)
#   Matches at position 37 : EDFEIW
#   Found in: IP_160347|TX=9606 (Length: 54)
#   Matches at position 38 : EDFVIL
#   Found in: IP_165861|TX=9606 (Length: 40)
#   Matches at position 1 : EDFSIL
#   Found in: IP_166216|TX=9606 (Length: 33)
#   Matches at position 18 : EDFIL
# Protein: Q9Y4P1_349 (Length: 6)
#   Found in: IP_120486|TX=9606 (Length: 37)
#   Matches at position 7 : PMELV
#   Found in: IP_131319|TX=9606 (Length: 89)
#   Matches at position 83 : PMFLLV
#   Found in: IP_167237|TX=9606 (Length: 78)
#   Matches at position 39 : PMELV
# Protein: Q9Y4P1_8 (Length: 6)
#   Found in: IP_066609|TX=9606 (Length: 55)
#   Matches at position 13 : LTYTL
#   Found in: IP_096148|TX=9606 (Length: 61)
#   Matches at position 27 : LTTDTL
#   Found in: IP_130013|TX=9606 (Length: 40)
#   Matches at position 34 : LTYDKL
#   Found in: IP_131186|TX=9606 (Length: 49)
#   Matches at position 25 : LTYDTS
#   Found in: II_132380|TX=9606 (Length: 66)
#   Matches at position 7 : LTQDTL
#   Found in: IP_150589|TX=9606 (Length: 41)
#   Matches at position 26 : LYDTL
#   Found in: IP_151785|TX=9606 (Length: 72)
#   Matches at position 50 : LTYDL
#   Found in: IP_161342|TX=9606 (Length: 55)
#   Matches at position 10 : LTYDL
#   Found in: IP_166158|TX=9606 (Length: 44)
#   Matches at position 29 : LTDTL
#   Found in: IP_167314|TX=9606 (Length: 37)
#   Matches at position 16 : LTYMTL
# Protein: Q9Y6I9_273 (Length: 6)
#   Found in: IP_059331|TX=9606 (Length: 37)
#   Matches at position 24 : SSQEEL
#   Found in: IP_061064|TX=9606 (Length: 42)
#   Matches at position 34 : SAFEEL
#   Found in: IP_061078|TX=9606 (Length: 84)
#   Matches at position 36 : SSFERL
#   Found in: IP_061337|TX=9606 (Length: 63)
#   Matches at position 33 : SSFSEL
#   Found in: IP_062515|TX=9606 (Length: 40)
#   Matches at position 25 : SSFIEL
#   Found in: IP_062783|TX=9606 (Length: 34)
#   Matches at position 11 : SSFPEL
#   Found in: IP_078091|TX=9606 (Length: 56)
#   Matches at position 18 : SCFEEL
#   Found in: II_078889|TX=9606 (Length: 51)
#   Matches at position 30 : SDFEEL
#   Found in: IP_086642|TX=9606 (Length: 30)
#   Matches at position 9 : SSFEL
#   Found in: IP_088297|TX=9606 (Length: 71)
#   Matches at position 54 : SSLEEL
#   Found in: IP_089155|TX=9606 (Length: 39)
#   Matches at position 21 : SSFEL
#   Found in: IP_097641|TX=9606 (Length: 34)
#   Matches at position 4 : SSEEL
#   Found in: IP_099506|TX=9606 (Length: 32)
#   Matches at position 19 : NSFEEL
#   Matches at position 20 : SFEEL
#   Found in: IP_100570|TX=9606 (Length: 54)
#   Matches at position 47 : SSFEER
#   Found in: IP_115454|TX=9606 (Length: 98)
#   Matches at position 90 : SSFHEL
#   Found in: IP_116183|TX=9606 (Length: 59)
#   Matches at position 47 : SSFLEL
#   Found in: IP_120883|TX=9606 (Length: 50)
#   Matches at position 31 : SSGEEL
#   Found in: IP_127292|TX=9606 (Length: 39)
#   Matches at position 16 : SSFEL
#   Found in: IP_132339|TX=9606 (Length: 83)
#   Matches at position 71 : SSFQEL
#   Found in: IP_132345|TX=9606 (Length: 34)
#   Matches at position 22 : SSFQEL
#   Found in: IP_133570|TX=9606 (Length: 63)
#   Matches at position 1 : SSFKEL
#   Found in: IP_135534|TX=9606 (Length: 34)
#   Matches at position 24 : SSFPEL
#   Found in: IP_140280|TX=9606 (Length: 79)
#   Matches at position 33 : SSEEL
#   Found in: IP_140786|TX=9606 (Length: 58)
#   Matches at position 16 : SSFEKL
#   Found in: IP_151106|TX=9606 (Length: 47)
#   Matches at position 24 : SSFELL
#   Found in: IP_158697|TX=9606 (Length: 85)
#   Matches at position 51 : SSFEL
#   Found in: IP_162816|TX=9606 (Length: 44)
#   Matches at position 11 : SSFLEEL
#   Found in: IP_164107|TX=9606 (Length: 48)
#   Matches at position 17 : SSFELL
#   Found in: IP_166445|TX=9606 (Length: 56)
#   Matches at position 27 : SSFEEK
#   Found in: IP_169533|TX=9606 (Length: 34)
#   Matches at position 2 : SGSFEEL
#   Matches at position 3 : GSFEEL
#   Matches at position 4 : SFEEL
#   Found in: IP_172727|TX=9606 (Length: 90)
#   Matches at position 69 : SSFEWL
# Protein: Q9Y6I9_27 (Length: 6)
#   Found in: IP_058943|TX=9606 (Length: 73)
#   Matches at position 7 : AGSGL
#   Found in: IP_061289|TX=9606 (Length: 55)
#   Matches at position 5 : AGGSGL
#   Found in: IP_063339|TX=9606 (Length: 79)
#   Matches at position 71 : AGLSGL
#   Found in: IP_063511|TX=9606 (Length: 35)
#   Matches at position 26 : AGPSGL
#   Found in: IP_064194|TX=9606 (Length: 33)
#   Matches at position 4 : AGRSGL
#   Found in: IP_069903|TX=9606 (Length: 40)
#   Matches at position 1 : AGYSL
#   Found in: IP_075883|TX=9606 (Length: 61)
#   Matches at position 22 : AGSGL
#   Found in: IP_078267|TX=9606 (Length: 29)
#   Matches at position 6 : AGSGL
#   Found in: IP_080009|TX=9606 (Length: 39)
#   Matches at position 14 : AQYSGL
#   Found in: IP_080311|TX=9606 (Length: 80)
#   Matches at position 6 : AGASGL
#   Found in: IP_085744|TX=9606 (Length: 57)
#   Matches at position 32 : AGSGL
#   Found in: IP_086270|TX=9606 (Length: 40)
#   Matches at position 20 : AGYSYL
#   Found in: IP_093073|TX=9606 (Length: 51)
#   Matches at position 30 : AGSGL
#   Found in: IP_093806|TX=9606 (Length: 40)
#   Matches at position 30 : AGYSL
#   Found in: IP_093825|TX=9606 (Length: 48)
#   Matches at position 41 : AGSGL
#   Found in: IP_095819|TX=9606 (Length: 49)
#   Matches at position 44 : AGSGL
#   Found in: IP_097319|TX=9606 (Length: 55)
#   Matches at position 10 : AGSSGL
#   Found in: IP_098695|TX=9606 (Length: 73)
#   Matches at position 62 : AGRSGL
#   Found in: IP_102448|TX=9606 (Length: 48)
#   Matches at position 17 : AGSGL
#   Found in: IP_110085|TX=9606 (Length: 38)
#   Matches at position 24 : AGSSGL
#   Found in: IP_111146|TX=9606 (Length: 46)
#   Matches at position 33 : AGSGL
#   Found in: IP_112913|TX=9606 (Length: 32)
#   Matches at position 21 : AGLSGL
#   Found in: IP_115258|TX=9606 (Length: 33)
#   Matches at position 10 : AGSGL
#   Found in: IP_115753|TX=9606 (Length: 37)
#   Matches at position 29 : AGYSGS
#   Found in: IP_116400|TX=9606 (Length: 86)
#   Matches at position 27 : AGSGL
#   Found in: IP_127771|TX=9606 (Length: 35)
#   Matches at position 26 : AGYSWL
#   Found in: IP_127956|TX=9606 (Length: 55)
#   Matches at position 4 : AGCSGL
#   Found in: IP_128241|TX=9606 (Length: 48)
#   Matches at position 30 : AGDSGL
#   Found in: IP_128744|TX=9606 (Length: 34)
#   Matches at position 6 : AGASGL
#   Found in: IP_129996|TX=9606 (Length: 40)
#   Matches at position 31 : AGSGL
#   Found in: IP_130273|TX=9606 (Length: 62)
#   Matches at position 11 : AYSGL
#   Found in: IP_132961|TX=9606 (Length: 53)
#   Matches at position 1 : AGSGL
#   Found in: IP_135438|TX=9606 (Length: 44)
#   Matches at position 18 : AGPSGL
#   Found in: IP_139682|TX=9606 (Length: 33)
#   Matches at position 7 : AGSSGL
#   Found in: IP_141072|TX=9606 (Length: 49)
#   Matches at position 15 : AGFSGL
#   Found in: IP_141741|TX=9606 (Length: 94)
#   Matches at position 5 : AGYGL
#   Found in: IP_143012|TX=9606 (Length: 36)
#   Matches at position 7 : AGSGL
#   Found in: IP_143018|TX=9606 (Length: 63)
#   Matches at position 34 : AGSGL
#   Found in: IP_145621|TX=9606 (Length: 47)
#   Matches at position 41 : AAYSGL
#   Matches at position 42 : AYSGL
#   Found in: IP_146809|TX=9606 (Length: 72)
#   Matches at position 56 : AGGSGL
#   Found in: II_147823|TX=9606 (Length: 31)
#   Matches at position 15 : AGSGL
#   Found in: IP_149775|TX=9606 (Length: 96)
#   Matches at position 12 : AGYSL
#   Found in: IP_157629|TX=9606 (Length: 61)
#   Matches at position 25 : AGSGL
#   Found in: IP_158652|TX=9606 (Length: 68)
#   Matches at position 50 : AGSGL
#   Found in: IP_160220|TX=9606 (Length: 69)
#   Matches at position 61 : AGYSEL
#   Found in: IP_160839|TX=9606 (Length: 39)
#   Matches at position 32 : AGYSGP
#   Found in: II_161469|TX=9606 (Length: 92)
#   Matches at position 23 : AGPSGL
#   Found in: IP_169280|TX=9606 (Length: 43)
#   Matches at position 18 : AGRSGL
#   Found in: IP_171494|TX=9606 (Length: 73)
#   Matches at position 48 : AYSGL
# Protein: Q9Y6K9_340 (Length: 6)
#   Found in: IP_086078|TX=9606 (Length: 31)
#   Matches at position 6 : REYSHL
#   Found in: L8E7R5|TX=9606 (Length: 69)
#   Matches at position 34 : REYSL
#   Found in: IP_089923|TX=9606 (Length: 45)
#   Matches at position 21 : REMSKL
#   Found in: IP_105617|TX=9606 (Length: 72)
#   Matches at position 40 : RYSKL
#   Found in: IP_114592|TX=9606 (Length: 59)
#   Matches at position 20 : RERSKL
#   Found in: IP_121220|TX=9606 (Length: 30)
#   Matches at position 24 : REYSKS
#   Found in: IP_121680|TX=9606 (Length: 53)
#   Matches at position 43 : RESKL
#   Found in: IP_123701|TX=9606 (Length: 37)
#   Matches at position 3 : REYSL
#   Found in: II_130190|TX=9606 (Length: 34)
#   Matches at position 19 : RESKL
#   Found in: IP_137500|TX=9606 (Length: 38)
#   Matches at position 22 : REYSFL
#   Found in: IP_143461|TX=9606 (Length: 38)
#   Matches at position 23 : REMSKL
#   Found in: II_162238|TX=9606 (Length: 51)
#   Matches at position 25 : REYGKL
#   Found in: IP_162411|TX=9606 (Length: 40)
#   Matches at position 11 : RPYSKL
#   Found in: IP_166298|TX=9606 (Length: 36)
#   Matches at position 13 : RESKL
#   Found in: II_172526|TX=9606 (Length: 29)
#   Matches at position 1 : RYSKL
#   Found in: IP_172612|TX=9606 (Length: 43)
#   Matches at position 23 : REYKL
# Protein: Q9Y6K9_234 (Length: 6)
#   Found in: IP_074651|TX=9606 (Length: 68)
#   Matches at position 27 : VARHQL
#   Found in: IP_082741|TX=9606 (Length: 40)
#   Matches at position 24 : VAYQL
#   Found in: IP_115703|TX=9606 (Length: 97)
#   Matches at position 71 : VARHQL
#   Found in: IP_115714|TX=9606 (Length: 95)
#   Matches at position 71 : VARHQL
#   Found in: IP_127813|TX=9606 (Length: 29)
#   Matches at position 6 : VFYHQL
#   Found in: IP_159849|TX=9606 (Length: 60)
#   Matches at position 2 : VAYHSL

# %%
'''LOAD INPUT DATASET'''

#Read motif data from CSV file
set1 = read_csv_file("LIRcentral.csv")
#Read small human peptides sequence from FASTA file
set2 = read_fasta_file("Smallhumanpeptides.fasta")

'''VALIDATE INPUT DATA'''

#Check if either input set is empty and stop the execution
if not set1 or not set2:
    print("Error: One or both sets are empty.")
else:
  #Find where motifs matched peptides sequence
  matches= find_protein_matches(set1,set2)

  #Table creation to store results from output
  table_info =[]
  #Set to store peptide's IDs that contain identical matches to motifs
  identical_with_LIRmotifs = set()

  #Loop through each motif from the CSV
  for uniqueID, match_list in matches.items():
      motif_length = len(set1[uniqueID]["motif"]) #Length of the current motif

      #Loop through each peptide that matched this motif
      for match in match_list:
        protein_id= match["protein_id"]
        protein_length = match["protein_length"]
        experimentally_verified = match["experimentally_verified"]


        #Loop through each individual match found in this peptide
        for position, sequence,sequence_length in match["matches"]:

          #Check if the matched sequence is identical to the motif
          if sequence == set1[uniqueID]["motif"] :
            identical= "YES"
            identical_with_LIRmotifs.add(protein_id) #Store the identical matches
          else:
            identical = "NO"

          #Append all relevant data to the result table
          table_info.append([uniqueID, motif_length,experimentally_verified,protein_id, protein_length, position,sequence,sequence_length, identical])

  headers = ["Motif ID", "Motif Length" , "Experimentally Verified" , "Matched in Protein" , "Protein Length" , "Matched Position" , "Matched Sequence","Matched Sequence Length", "Identical Sequence"]
  #print(tabulate(table_info, headers=headers, tablefmt= "grid"))

  #Write the results to a txt file in tab-separated format
  with open("output.txt", "w") as out:
    #out.write(tabulate(table_info, headers=headers, tablefmt= "grid"))
    for match_lir in table_info:
      #out.write(str(match_lir)+"\n")
      out.write('\t'.join(map(str,match_lir)) + '\n')

# %%
'''RESYLTS ANALYSIS'''


# File paths for input and output files
csv_file = "LIRcentral.csv"
output_file = "output.txt"
information_file = "analysis_results.txt"


#Initialize sets to store unique human LIRmotifs data

Homo_sapiens_unique_name_motifs = set() #Unique motif entries with Uniprot ID and position
Homo_sapiens_motifs = set() #Unique Uniprot IDs with LIR motifs

# Dictionaries to store analysis results
lir_motif_counts = defaultdict(int)  # Total number of matches per LIR motif
lir_motif_proteins = defaultdict(set)  # Peptides matched per LIR motif
lir_motif_all_proteins = set() # All peptides with at least one motif match
lir_motif_deletions = defaultdict(int)  # Counts deletions, motif matches <6 amino acids long
lir_motif_insertions = defaultdict(int)  # Counts insertions, motif matches >6 amino acids long
lir_motif_substitutions = defaultdict(int)  # Counts substitutions , motif matches exactly 6 amino acids long but not identical
lir_motif_identical = defaultdict(int) # Matched sequences identical with the LIRmotifs

# Counter objects
total_matches = 0
deletions = 0
insertions = 0
substitutions = 0
identicalseq = 0


'''READ MOTIF ENTRIES FROM THE ORIGINAL CSV FILE
AND COLLECT HUMAN LIR MOTIF IDENTIFIERS'''

with open(csv_file , "r" , newline="") as file :
  reader = csv.reader(file)
  header= next(reader) # Skip CSV header

  for row in reader:
        if row[0].strip() == "Homo sapiens":
            uniprot_id = row[1].strip()
            start_position = row[8].strip()
            uniqueID = f"{uniprot_id}_{start_position}"
            Homo_sapiens_unique_name_motifs.add(uniqueID)
            Homo_sapiens_motifs.add(uniprot_id)


# Read the matches from output.txt file
with open(output_file, "r") as file:
    for line in file:
        cols = line.strip().split("\t")
        if len(cols) < 9:
            continue  # Skip incomplete rows

        lir_motif = cols[0]  # LIR motif ID
        protein_id = cols[3]  # Protein ID where the motif matched
        match_length = int(cols[7])  # Length of the matched sequence to classify mismatch type

        # Count matches with <= 1 mismatch (each row represents one)
        total_matches += 1

        # Count different motifs and their associated peptides
        lir_motif_counts[lir_motif] += 1
        lir_motif_proteins[lir_motif].add(protein_id)
        lir_motif_all_proteins.add(protein_id)

        # Classify type of match
        if cols[8]=="NO": #Not an identical match
          if match_length < 6:
            lir_motif_deletions[lir_motif] += 1
            deletions += 1
          elif match_length > 6:
            lir_motif_insertions[lir_motif] += 1
            insertions += 1
          else:  # match_length == 6
            lir_motif_substitutions[lir_motif] += 1
            substitutions += 1
        else : #Identical match
          lir_motif_identical[lir_motif] += 1
          identicalseq += 1

# Find the LIR motif with the highest number of matches
most_common_motif = max(lir_motif_counts, key=lir_motif_counts.get, default=None)
most_common_motif_count = lir_motif_counts.get(most_common_motif, 0)
#Count how many different peptides matched this motif
unique_proteins_for_motif = len(lir_motif_proteins.get(most_common_motif, set()))

# Find LIR motifs that appear at least 1 time
frequent_motifs = {
    motif: {
        "count": lir_motif_counts[motif],
        "unique_proteins": len(lir_motif_proteins[motif]),
        "deletions": lir_motif_deletions[motif],
        "insertions": lir_motif_insertions[motif],
        "substitutions": lir_motif_substitutions[motif],
        "identical" : lir_motif_identical[motif]
    }
    for motif in lir_motif_counts if lir_motif_counts[motif] >= 1
}

# Write all summary results to a TXT file
with open(information_file, "w") as file:
    file.write(f"1. Homo sapiens LIR motifs: {len(Homo_sapiens_unique_name_motifs)}\n")
    file.write(f"2. Different human proteins with LIR motifs: {len(Homo_sapiens_motifs)}\n")
    file.write(f"3. Total LIRmotifs-small human proteins mismatches: {total_matches}\n")
    file.write(f"4. Identified different LIR motifs: {len(lir_motif_counts)}\n")
    file.write(f"6. Mismatches in different proteins:{len(lir_motif_all_proteins)}\n")
    file.write(f"5. Deletions (<6): {deletions}\n")
    file.write(f"7. Insertions (>6): {insertions}\n")
    file.write(f"8. Substitutions (=6): {substitutions}\n")
    file.write(f"9. Identical : {identicalseq}\n")
    file.write(f"10. Most frequent LIR motif: {most_common_motif} ({most_common_motif_count} times)\n")
    file.write(f"11. Number of different proteins matched: {unique_proteins_for_motif}\n\n")
    file.write("LIR motifs matching x times:\n")
    for motif, details in frequent_motifs.items():
        file.write(f"   - {motif}: {details['count']} times\n")
        file.write(f"     Different proteins matched: {details['unique_proteins']}\n")
        file.write(f"     Deletions: {details['deletions']}, Insertions: {details['insertions']}, Substitutions: {details['substitutions']}, Identical:{details['identical']}\n\n")

# %%
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq
from collections import defaultdict

# === Step 1: Parse output.txt for all match details ===
protein_matches = defaultdict(list)  # protein_id -> list of (motif_id, position, match_type)

with open("output.txt", "r") as file:
    next(file)  # Skip header
    for line in file:
        cols = line.strip().split("\t")
        if len(cols) < 9:
            continue
        motif_id = cols[0].strip()
        protein_id = cols[3].strip()
        position = cols[5].strip()
        identical = cols[8].strip()

        # Classify match type
        match_len = int(cols[7])
        if identical == "YES":
            match_type = "Identical"
        elif match_len < 6:
            match_type = "Deletion"
        elif match_len > 6:
            match_type = "Insertion"
        else:
            match_type = "Substitution"

        protein_matches[protein_id].append((motif_id, position, match_type))

# === Step 2: Load full sequences from FASTA ===
all_proteins = {}
with open("Smallhumanpeptides.fasta", "r") as fasta_file:
    for record in SeqIO.parse(fasta_file, "fasta"):
        all_proteins[record.id] = str(record.seq)

# === Step 3: Build FASTA records with descriptive headers ===
fasta_records = []

for protein_id, match_list in protein_matches.items():
    if protein_id not in all_proteins:
        print(f"Warning: {protein_id} not found in FASTA.")
        continue

    seq = all_proteins[protein_id]
    # Join all match annotations into one description line
    details = [f"{motif}@{pos}({typ})" for motif, pos, typ in match_list]
    description = "Matches: " + "; ".join(details)

    record = SeqRecord(
        Seq(seq),
        id=protein_id,
        description=description
    )
    fasta_records.append(record)

# === Step 4: Write to FASTA ===
with open("matched_proteins_with_details.fasta", "w") as out_fasta:
    SeqIO.write(fasta_records, out_fasta, "fasta")

print(f"Saved {len(fasta_records)} matched protein records with match types and positions to 'matched_proteins_with_details.fasta'")
# Out:
# Saved 2138 matched protein records with match types and positions to 'matched_proteins_with_details.fasta'
