# %% [markdown]
# <a href="https://colab.research.google.com/github/viktoriapatouna/Thesis-work-2025/blob/main/levenshtein_distance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !touch human1.fasta arabidopsis1.fasta

# %% [markdown]
# ARABIDOPSIS
#
#
#
# >gene1
# AYYYYHHHGG
# >gene1.1
# AYYYYHHHGG
# >prot2
# GGHYPLSKYYY
# >prot3
# LLLYY
# >prot3.1
# LLLYK
# YKKK
# >gene67
# PPLLYYH
# >gene67.1
# PPLLYYH

# %% [markdown]
# HUMAN
#
#
#
# >gene1
# AYYYYHHHGG
# >prot2
# GGHYPLSKYYY
# >prot3
# LLLYY
# YKKK
# >gene67
# PPLLYYH

# %%
import numpy as np

def parse_fasta(species_proteins_list):
    sequences = {}
    with open(species_proteins_list, "r") as file:
        entry_name = None
        sequence = []
        for line in file:
            line = line.strip()
            if line.startswith(">"):
                if entry_name:
                    sequences[entry_name] = "".join(sequence)
                entry_name = line[1:]
                sequence = []
            else:
                sequence.append(line)
        if entry_name:
            sequences[entry_name] = "".join(sequence)
    return sequences

def levenshtein(q, t, lowercase=True):
    """Calculate Levenshtein distance between two strings."""
    if not isinstance(q, str):
        raise TypeError("First argument is not a string!")
    if not isinstance(t, str):
        raise TypeError("Second argument is not a string!")

    if lowercase:
        q = q.lower()
        t = t.lower()

    n = len(q)
    m = len(t)
    lev = np.zeros((n + 1, m + 1))


    for i in range(n + 1):
        lev[i, 0] = i
    for j in range(m + 1):
        lev[0, j] = j


    for i in range(1, n + 1):
        for j in range(1, m + 1):
            insertion = lev[i - 1, j] + 1
            deletion = lev[i, j - 1] + 1
            substitution = lev[i - 1, j - 1] + (1 if q[i - 1] != t[j - 1] else 0)
            lev[i, j] = min(insertion, deletion, substitution)

    return int(lev[n, m])

def find_identical_sequences(species_proteins_list):
    """Find identical sequences across multiple FASTA files."""
    parsed_data = {file: parse_fasta(file) for file in species_proteins_list}

    # Compare sequences between all pairs of species
    for i in range(len(species_proteins_list)):
        query_species = species_proteins_list[i]
        query_proteins = parsed_data[query_species]
        for j in range(i, len(species_proteins_list)):
            target_species = species_proteins_list[j]
            target_proteins = parsed_data[target_species]

            qnames = list(query_proteins.keys())
            tnames = list(target_proteins.keys())

            print(f"Comparing {query_species} with {target_species}:")
            for q_idx in range(len(qnames)):
                for t_idx in range(len(tnames)):
                    # Avoid self-comparisons
                    if i == j and q_idx == t_idx:
                        continue

                    qname = qnames[q_idx]
                    tname = tnames[t_idx]
                    distance = levenshtein(query_proteins[qname], target_proteins[tname])
                    print(f"  {qname} vs {tname}: Distance = {distance}")


species_proteins_list = ["arabidopsis1.fasta", "human1.fasta"]
find_identical_sequences(species_proteins_list)
# Out:
# Comparing arabidopsis1.fasta with arabidopsis1.fasta:
#   gene1 vs gene1.1: Distance = 0
#   gene1 vs prot2: Distance = 10
#   gene1 vs prot3: Distance = 8
#   gene1 vs prot3.1: Distance = 9
#   gene1 vs gene67: Distance = 8
#   gene1 vs gene67.1: Distance = 8
#   gene1.1 vs gene1: Distance = 0
#   gene1.1 vs prot2: Distance = 10
#   gene1.1 vs prot3: Distance = 8
#   gene1.1 vs prot3.1: Distance = 9
#   gene1.1 vs gene67: Distance = 8
#   gene1.1 vs gene67.1: Distance = 8
#   prot2 vs gene1: Distance = 10
#   prot2 vs gene1.1: Distance = 10
#   prot2 vs prot3: Distance = 8
#   prot2 vs prot3.1: Distance = 9
#   prot2 vs gene67: Distance = 7
#   prot2 vs gene67.1: Distance = 7
#   prot3 vs gene1: Distance = 8
#   prot3 vs gene1.1: Distance = 8
#   prot3 vs prot2: Distance = 8
#   prot3 vs prot3.1: Distance = 4
#   prot3 vs gene67: Distance = 3
#   prot3 vs gene67.1: Distance = 3
#   prot3.1 vs gene1: Distance = 9
#   prot3.1 vs gene1.1: Distance = 9
#   prot3.1 vs prot2: Distance = 9
#   prot3.1 vs prot3: Distance = 4
#   prot3.1 vs gene67: Distance = 6
#   prot3.1 vs gene67.1: Distance = 6
#   gene67 vs gene1: Distance = 8
#   gene67 vs gene1.1: Distance = 8
#   gene67 vs prot2: Distance = 7
#   gene67 vs prot3: Distance = 3
#   gene67 vs prot3.1: Distance = 6
#   gene67 vs gene67.1: Distance = 0
#   gene67.1 vs gene1: Distance = 8
#   gene67.1 vs gene1.1: Distance = 8
#   gene67.1 vs prot2: Distance = 7
#   gene67.1 vs prot3: Distance = 3
#   gene67.1 vs prot3.1: Distance = 6
#   gene67.1 vs gene67: Distance = 0
# Comparing arabidopsis1.fasta with human1.fasta:
#   gene1 vs gene1: Distance = 0
#   gene1 vs prot2: Distance = 10
#   gene1 vs prot3: Distance = 8
#   gene1 vs gene67: Distance = 8
#   gene1.1 vs gene1: Distance = 0
#   gene1.1 vs prot2: Distance = 10
#   gene1.1 vs prot3: Distance = 8
#   gene1.1 vs gene67: Distance = 8
#   prot2 vs gene1: Distance = 10
#   prot2 vs prot2: Distance = 0
#   prot2 vs prot3: Distance = 9
#   prot2 vs gene67: Distance = 7
#   prot3 vs gene1: Distance = 8
#   prot3 vs prot2: Distance = 8
#   prot3 vs prot3: Distance = 4
#   prot3 vs gene67: Distance = 3
#   prot3.1 vs gene1: Distance = 9
#   prot3.1 vs prot2: Distance = 9
#   prot3.1 vs prot3: Distance = 1
#   prot3.1 vs gene67: Distance = 6
#   gene67 vs gene1: Distance = 8
#   gene67 vs prot2: Distance = 7
#   gene67 vs prot3: Distance = 6
#   gene67 vs gene67: Distance = 0
#   gene67.1 vs gene1: Distance = 8
#   gene67.1 vs prot2: Distance = 7
#   gene67.1 vs prot3: Distance = 6
#   gene67.1 vs gene67: Distance = 0
# Comparing human1.fasta with human1.fasta:
#   gene1 vs prot2: Distance = 10
#   gene1 vs prot3: Distance = 8
#   gene1 vs gene67: Distance = 8
#   prot2 vs gene1: Distance = 10
#   prot2 vs prot3: Distance = 9
#   prot2 vs gene67: Distance = 7
#   prot3 vs gene1: Distance = 8
#   prot3 vs prot2: Distance = 9
#   prot3 vs gene67: Distance = 6
#   gene67 vs gene1: Distance = 8
#   gene67 vs prot2: Distance = 7
#   gene67 vs prot3: Distance = 6

# %%
import numpy as np

def parse_fasta(species_proteins_list):
    """Parse a FASTA file into a dictionary."""
    sequences = {}
    with open(species_proteins_list, "r") as file:
        entry_name = None
        sequence = []
        for line in file:
            line = line.strip()
            if line.startswith(">"):
                if entry_name:
                    sequences[entry_name] = "".join(sequence)
                entry_name = line[1:]
                sequence = []
            else:
                sequence.append(line)
        if entry_name:
            sequences[entry_name] = "".join(sequence)
    return sequences

def levenshtein(q, t, lowercase=True):
    """Calculate Levenshtein distance between two strings."""
    if not isinstance(q, str):
        raise TypeError("First argument is not a string!")
    if not isinstance(t, str):
        raise TypeError("Second argument is not a string!")

    if lowercase:
        q = q.lower()
        t = t.lower()

    n = len(q)
    m = len(t)
    lev = np.zeros((n + 1, m + 1))


    for i in range(n + 1):
        lev[i, 0] = i
    for j in range(m + 1):
        lev[0, j] = j


    for i in range(1, n + 1):
        for j in range(1, m + 1):
            insertion = lev[i - 1, j] + 1
            deletion = lev[i, j - 1] + 1
            substitution = lev[i - 1, j - 1] + (1 if q[i - 1] != t[j - 1] else 0)
            lev[i, j] = min(insertion, deletion, substitution)

    return int(lev[n, m])

def find_identical_sequences(species_proteins_list):
    """Find identical sequences across multiple FASTA files."""
    parsed_data = {file: parse_fasta(file) for file in species_proteins_list}

    # Compare sequences between all pairs of species
    for i in range(len(species_proteins_list)):
        query_species = species_proteins_list[i]
        query_proteins = parsed_data[query_species]
        for j in range(i, len(species_proteins_list)):
            target_species = species_proteins_list[j]
            target_proteins = parsed_data[target_species]

            qnames = list(query_proteins.keys())
            tnames = list(target_proteins.keys())

            print(f"Comparing {query_species} with {target_species}:")
            for q_idx in range(len(qnames)):
                for t_idx in range(len(tnames)):
                    # Avoid self-comparisons
                    if i == j and q_idx == t_idx:
                        continue

                    qname = qnames[q_idx]
                    tname = tnames[t_idx]
                    distance = levenshtein(query_proteins[qname], target_proteins[tname])
                    print(f"  {qname} vs {tname}: Distance = {distance}")


species_proteins_list = ["Human", "arabidopsis.fasta", "c.elegans.fasta", "drosophila.fasta", "mouse.fasta", "s.cerevisiae.fasta"]
find_identical_sequences(species_proteins_list)
# Out:
# Streaming output truncated to the last 5000 lines.
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4F0|DF266_ARATH Defensin-like protein 266 OS=Arabidopsis thaliana OX=3702 GN=At1g65352 PE=2 SV=1: Distance = 74
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4F3|DEF35_ARATH Defensin-like protein 35 OS=Arabidopsis thaliana OX=3702 GN=At1g64195 PE=2 SV=2: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4F4|DF269_ARATH Defensin-like protein 269 OS=Arabidopsis thaliana OX=3702 GN=At1g64107 PE=3 SV=1: Distance = 76
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4F6|DF279_ARATH Putative defensin-like protein 279 OS=Arabidopsis thaliana OX=3702 GN=At1g63535 PE=3 SV=1: Distance = 64
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4F7|DF278_ARATH Defensin-like protein 278 OS=Arabidopsis thaliana OX=3702 GN=At1g63522 PE=3 SV=1: Distance = 66
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4G1|DEF63_ARATH Putative defensin-like protein 63 OS=Arabidopsis thaliana OX=3702 GN=At1g59833 PE=3 SV=1: Distance = 69
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4G3|DF117_ARATH Defensin-like protein 117 OS=Arabidopsis thaliana OX=3702 GN=At1g58055 PE=3 SV=1: Distance = 66
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4G5|DF199_ARATH Defensin-like protein 199 OS=Arabidopsis thaliana OX=3702 GN=At1g56553 PE=3 SV=1: Distance = 72
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4G6|DEF81_ARATH Defensin-like protein 81 OS=Arabidopsis thaliana OX=3702 GN=At1g56233 PE=3 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4G9|DEF90_ARATH Defensin-like protein 90 OS=Arabidopsis thaliana OX=3702 GN=At1g54445 PE=2 SV=1: Distance = 70
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4H7|DF175_ARATH Defensin-like protein 175 OS=Arabidopsis thaliana OX=3702 GN=At1g49715 PE=3 SV=1: Distance = 74
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4I8|DEF32_ARATH Defensin-like protein 32 OS=Arabidopsis thaliana OX=3702 GN=At1g35537 PE=1 SV=1: Distance = 70
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4I9|DF275_ARATH Defensin-like protein 275 OS=Arabidopsis thaliana OX=3702 GN=At1g35435 PE=2 SV=1: Distance = 72
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4J2|DEF26_ARATH Putative defensin-like protein 26 OS=Arabidopsis thaliana OX=3702 GN=At1g33607 PE=5 SV=1: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4J5|DEF43_ARATH Defensin-like protein 43 OS=Arabidopsis thaliana OX=3702 GN=At1g32763 PE=3 SV=1: Distance = 71
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4J8|DF316_ARATH Defensin-like protein 316 OS=Arabidopsis thaliana OX=3702 GN=At1g31772 PE=5 SV=1: Distance = 81
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4L5|DEF68_ARATH Defensin-like protein 68 OS=Arabidopsis thaliana OX=3702 GN=At1g24062 PE=3 SV=1: Distance = 82
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4N0|DF110_ARATH Putative defensin-like protein 110 OS=Arabidopsis thaliana OX=3702 GN=At1g15757 PE=3 SV=1: Distance = 74
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4N2|DF201_ARATH Defensin-like protein 201 OS=Arabidopsis thaliana OX=3702 GN=At1g14755 PE=3 SV=1: Distance = 68
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4N4|DF287_ARATH Defensin-like protein 287 OS=Arabidopsis thaliana OX=3702 GN=At1g13609 PE=3 SV=1: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q2V4N5|DF288_ARATH Putative defensin-like protein 288 OS=Arabidopsis thaliana OX=3702 GN=At1g13608 PE=5 SV=1: Distance = 66
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q38803|MT1B_ARATH Putative metallothionein-like protein 1B OS=Arabidopsis thaliana OX=3702 GN=MT1B PE=5 SV=1: Distance = 68
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q38804|MT1C_ARATH Metallothionein-like protein 1C OS=Arabidopsis thaliana OX=3702 GN=MT1C PE=2 SV=1: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q38805|MT2B_ARATH Metallothionein-like protein 2B OS=Arabidopsis thaliana OX=3702 GN=MT2B PE=2 SV=1: Distance = 70
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3E6U0|DF100_ARATH Defensin-like protein 100 OS=Arabidopsis thaliana OX=3702 GN=At4g22217 PE=3 SV=1: Distance = 74
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3E715|DF301_ARATH Defensin-like protein 301 OS=Arabidopsis thaliana OX=3702 GN=At5g04045 PE=3 SV=1: Distance = 80
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3E7C7|DEF47_ARATH Defensin-like protein 47 OS=Arabidopsis thaliana OX=3702 GN=At3g16895 PE=3 SV=1: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3E7S1|DEF87_ARATH Defensin-like protein 87 OS=Arabidopsis thaliana OX=3702 GN=At2g24693 PE=5 SV=1: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3E8B0|DEF41_ARATH Defensin-like protein 41 OS=Arabidopsis thaliana OX=3702 GN=At5g55565 PE=5 SV=1: Distance = 65
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3E8I8|DF116_ARATH Defensin-like protein 116 OS=Arabidopsis thaliana OX=3702 GN=At5g42235 PE=3 SV=1: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3E8K0|DF313_ARATH Defensin-like protein 313 OS=Arabidopsis thaliana OX=3702 GN=At5g40155 PE=3 SV=2: Distance = 70
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3E8R5|DF207_ARATH Defensin-like protein 207 OS=Arabidopsis thaliana OX=3702 GN=At5g33355 PE=2 SV=1: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3EBU2|DEF67_ARATH Putative defensin-like protein 67 OS=Arabidopsis thaliana OX=3702 GN=At2g25305 PE=3 SV=1: Distance = 72
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3ECL0|RLF9_ARATH Protein RALF-like 9 OS=Arabidopsis thaliana OX=3702 GN=RALFL9 PE=3 SV=1: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3ED99|PUP9_ARATH Putative purine permease 9 OS=Arabidopsis thaliana OX=3702 GN=PUP9 PE=5 SV=1: Distance = 63
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q41220|SAU15_ARATH Auxin-responsive protein SAUR15 OS=Arabidopsis thaliana OX=3702 GN=SAUR15 PE=1 SV=1: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q42330|DF192_ARATH Defensin-like protein 192 OS=Arabidopsis thaliana OX=3702 GN=ATTI7 PE=3 SV=2: Distance = 81
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q42337|S1FA2_ARATH DNA-binding protein S1FA2 OS=Arabidopsis thaliana OX=3702 GN=S1FA2 PE=3 SV=2: Distance = 66
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q4VNZ8|DEF59_ARATH Defensin-like protein 59 OS=Arabidopsis thaliana OX=3702 GN=At2g03933 PE=3 SV=2: Distance = 66
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q4VNZ9|DEF58_ARATH Defensin-like protein 58 OS=Arabidopsis thaliana OX=3702 GN=At2g03937 PE=3 SV=2: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q4VP04|DF308_ARATH Defensin-like protein 308 OS=Arabidopsis thaliana OX=3702 GN=At5g46871 PE=3 SV=2: Distance = 70
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q4VP07|LUR16_ARATH Protein LURE 1.6 OS=Arabidopsis thaliana OX=3702 GN=LURE1.6 PE=3 SV=2: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q56XB0|DF204_ARATH Defensin-like protein 204 OS=Arabidopsis thaliana OX=3702 GN=At3g05727 PE=1 SV=1: Distance = 72
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6DUW6|IDL4_ARATH Protein IDA-LIKE 4 OS=Arabidopsis thaliana OX=3702 GN=IDL4 PE=2 SV=1: Distance = 78
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6DUW9|IDL2_ARATH Protein IDA-LIKE 2 OS=Arabidopsis thaliana OX=3702 GN=IDL2 PE=1 SV=1: Distance = 80
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6IM80|DVL21_ARATH Small polypeptide DEVIL 21 OS=Arabidopsis thaliana OX=3702 GN=DVL21 PE=3 SV=1: Distance = 62
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6IM82|DVL19_ARATH Small polypeptide DEVIL 19 OS=Arabidopsis thaliana OX=3702 GN=DVL19 PE=3 SV=1: Distance = 65
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6IM84|DVL17_ARATH Small polypeptide DEVIL 17 OS=Arabidopsis thaliana OX=3702 GN=DVL17 PE=3 SV=1: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6IM87|DVL14_ARATH Small polypeptide DEVIL 14 OS=Arabidopsis thaliana OX=3702 GN=DVL14 PE=3 SV=1: Distance = 65
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6IM89|DVL12_ARATH Small polypeptide DEVIL 12 OS=Arabidopsis thaliana OX=3702 GN=DVL12 PE=3 SV=1: Distance = 66
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6IM91|DVL10_ARATH Small polypeptide DEVIL 10 OS=Arabidopsis thaliana OX=3702 GN=DVL10 PE=3 SV=1: Distance = 64
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6IM93|DVL8_ARATH Small polypeptide DEVIL 8 OS=Arabidopsis thaliana OX=3702 GN=DVL8 PE=3 SV=1: Distance = 69
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6IM94|DVL7_ARATH Small polypeptide DEVIL 7 OS=Arabidopsis thaliana OX=3702 GN=DVL7 PE=3 SV=1: Distance = 66
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6IM95|DVL6_ARATH Small polypeptide DEVIL 6 OS=Arabidopsis thaliana OX=3702 GN=DVL6 PE=3 SV=1: Distance = 63
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6NMS3|DEF95_ARATH Defensin-like protein 95 OS=Arabidopsis thaliana OX=3702 GN=At4g22235 PE=3 SV=1: Distance = 79
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6NNM0|TFB5_ARATH General transcription and DNA repair factor IIH subunit TFB5 OS=Arabidopsis thaliana OX=3702 GN=TFB5 PE=3 SV=1: Distance = 68
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q6NNN0|RADL3_ARATH Protein RADIALIS-like 3 OS=Arabidopsis thaliana OX=3702 GN=RL3 PE=2 SV=1: Distance = 71
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q84WM0|RL292_ARATH Large ribosomal subunit protein eL29y OS=Arabidopsis thaliana OX=3702 GN=RPL29B PE=3 SV=2: Distance = 68
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8GW75|RADL5_ARATH Protein RADIALIS-like 5 OS=Arabidopsis thaliana OX=3702 GN=RL5 PE=3 SV=1: Distance = 82
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8GWU7|SKI34_ARATH Protein SKIP34 OS=Arabidopsis thaliana OX=3702 GN=SKIP34 PE=1 SV=1: Distance = 76
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8GXR4|DF103_ARATH Defensin-like protein 103 OS=Arabidopsis thaliana OX=3702 GN=At2g20465 PE=3 SV=1: Distance = 74
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8GXV6|DEF85_ARATH Defensin-like protein 85 OS=Arabidopsis thaliana OX=3702 GN=At5g55132 PE=3 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8GY39|DEF54_ARATH Defensin-like protein 54 OS=Arabidopsis thaliana OX=3702 GN=At2g42885 PE=3 SV=1: Distance = 69
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8L7G7|DEF96_ARATH Defensin-like protein 96 OS=Arabidopsis thaliana OX=3702 GN=At4g22230 PE=3 SV=1: Distance = 79
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8L8W6|RL392_ARATH Large ribosomal subunit protein eL39y OS=Arabidopsis thaliana OX=3702 GN=RPL39B PE=3 SV=1: Distance = 65
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8L986|OST4B_ARATH Dolichyl-diphosphooligosaccharide--protein glycosyltransferase subunit 4B OS=Arabidopsis thaliana OX=3702 GN=OST4B PE=3 SV=1: Distance = 63
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8LAJ9|MIC10_ARATH MICOS complex subunit MIC10 OS=Arabidopsis thaliana OX=3702 GN=MIC10 PE=1 SV=1: Distance = 78
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8LAX3|PEP3_ARATH Elicitor peptide 3 OS=Arabidopsis thaliana OX=3702 GN=PEP3 PE=3 SV=2: Distance = 79
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8LD63|PEP5_ARATH Elicitor peptide 5 OS=Arabidopsis thaliana OX=3702 GN=PEP5 PE=3 SV=1: Distance = 77
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8LDK3|NDUB2_ARATH NADH dehydrogenase [ubiquinone] 1 beta subcomplex subunit 2 OS=Arabidopsis thaliana OX=3702 GN=At1g76200 PE=1 SV=1: Distance = 64
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8LDN4|CLE46_ARATH CLAVATA3/ESR (CLE)-related protein 46 OS=Arabidopsis thaliana OX=3702 GN=CLE46 PE=3 SV=1: Distance = 70
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8LFM0|DF163_ARATH Defensin-like protein 163 OS=Arabidopsis thaliana OX=3702 GN=LCR24 PE=3 SV=2: Distance = 69
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8LGD1|SP1L5_ARATH Protein SPIRAL1-like 5 OS=Arabidopsis thaliana OX=3702 GN=SP1L5 PE=2 SV=1: Distance = 81
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8RXU5|R37A2_ARATH Large ribosomal subunit protein eL43y OS=Arabidopsis thaliana OX=3702 GN=RPL37AC PE=3 SV=1: Distance = 77
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8S8H3|DF149_ARATH Defensin-like protein 149 OS=Arabidopsis thaliana OX=3702 GN=LCR5 PE=3 SV=1: Distance = 72
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8S8H9|DF144_ARATH Defensin-like protein 144 OS=Arabidopsis thaliana OX=3702 GN=LCR10 PE=3 SV=1: Distance = 74
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8S8P7|PSY3_ARATH Protein PSY3 OS=Arabidopsis thaliana OX=3702 GN=PSY3 PE=3 SV=1: Distance = 65
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8S8S3|DVL11_ARATH Small polypeptide DEVIL 11 OS=Arabidopsis thaliana OX=3702 GN=DVL11 PE=3 SV=1: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q93VI0|S1FA3_ARATH DNA-binding protein S1FA3 OS=Arabidopsis thaliana OX=3702 GN=S1FA3 PE=3 SV=1: Distance = 65
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q944J0|SPCS1_ARATH Signal peptidase complex subunit 1 OS=Arabidopsis thaliana OX=3702 GN=At2g22425 PE=3 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q94AZ8|DEF98_ARATH Defensin-like protein 98 OS=Arabidopsis thaliana OX=3702 GN=At4g22212 PE=3 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q94FT1|CX172_ARATH Cytochrome c oxidase copper chaperone 2 OS=Arabidopsis thaliana OX=3702 GN=COX17-2 PE=3 SV=1: Distance = 64
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q94JR6|DF206_ARATH Defensin-like protein 206 OS=Arabidopsis thaliana OX=3702 GN=At3g59930 PE=3 SV=1: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9C8M4|RPBCL_ARATH DNA-directed RNA polymerase subunit 12-like protein OS=Arabidopsis thaliana OX=3702 GN=NRPB12L PE=3 SV=1: Distance = 66
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9CA23|UFM1_ARATH Ubiquitin-fold modifier 1 OS=Arabidopsis thaliana OX=3702 GN=At1g77710 PE=1 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FGZ9|UBL5_ARATH Ubiquitin-like protein 5 OS=Arabidopsis thaliana OX=3702 GN=UBL5 PE=3 SV=1: Distance = 68
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FHX8|MDA3_ARATH Mediator-associated protein 3 OS=Arabidopsis thaliana OX=3702 GN=At5g42060 PE=1 SV=1: Distance = 77
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FIA9|PEP4_ARATH Elicitor peptide 4 OS=Arabidopsis thaliana OX=3702 GN=PEP4 PE=3 SV=1: Distance = 72
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FIJ2|NDUA2_ARATH NADH dehydrogenase [ubiquinone] 1 alpha subcomplex subunit 2 OS=Arabidopsis thaliana OX=3702 GN=At5g47890 PE=1 SV=1: Distance = 71
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FJF6|SAU23_ARATH Auxin-responsive protein SAUR23 OS=Arabidopsis thaliana OX=3702 GN=SAUR23 PE=2 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FJF7|SAU22_ARATH Auxin-responsive protein SAUR22 OS=Arabidopsis thaliana OX=3702 GN=SAUR22 PE=2 SV=1: Distance = 76
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FJF9|SAU21_ARATH Auxin-responsive protein SAUR21 OS=Arabidopsis thaliana OX=3702 GN=SAUR21 PE=2 SV=1: Distance = 74
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FJG0|SAU20_ARATH Auxin-responsive protein SAUR20 OS=Arabidopsis thaliana OX=3702 GN=SAUR20 PE=1 SV=1: Distance = 77
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FK62|SAU24_ARATH Auxin-responsive protein SAUR24 OS=Arabidopsis thaliana OX=3702 GN=SAUR24 PE=2 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FL73|DEF69_ARATH Defensin-like protein 69 OS=Arabidopsis thaliana OX=3702 GN=At5g54220 PE=3 SV=1: Distance = 83
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FLK2|CX5C3_ARATH Probable cytochrome c oxidase subunit 5C-3 OS=Arabidopsis thaliana OX=3702 GN=At5g61310 PE=3 SV=1: Distance = 63
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FNE0|CX5C4_ARATH Putative cytochrome c oxidase subunit 5C-4 OS=Arabidopsis thaliana OX=3702 GN=At5g40382 PE=3 SV=1: Distance = 64
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9LF54|CML29_ARATH Probable calcium-binding protein CML29 OS=Arabidopsis thaliana OX=3702 GN=CML29 PE=3 SV=1: Distance = 72
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9LHK3|OST4A_ARATH Dolichyl-diphosphooligosaccharide--protein glycosyltransferase subunit 4A OS=Arabidopsis thaliana OX=3702 GN=OST4A PE=3 SV=1: Distance = 62
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9LRQ1|Y3974_ARATH Putative BTB/POZ domain-containing protein At3g29740 OS=Arabidopsis thaliana OX=3702 GN=At3g29740 PE=3 SV=1: Distance = 71
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9LSG0|RLF25_ARATH Protein RALF-like 25 OS=Arabidopsis thaliana OX=3702 GN=RALFL25 PE=3 SV=1: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9LV55|DF259_ARATH Defensin-like protein 259 OS=Arabidopsis thaliana OX=3702 GN=At3g24510 PE=3 SV=1: Distance = 72
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9LVX6|SMR7_ARATH Cyclin-dependent protein kinase inhibitor SMR7 OS=Arabidopsis thaliana OX=3702 GN=SMR7 PE=2 SV=1: Distance = 80
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9LZQ0|CX5C2_ARATH Cytochrome c oxidase subunit 5C-2 OS=Arabidopsis thaliana OX=3702 GN=At3g62400 PE=3 SV=1: Distance = 63
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9M095|RC23_ARATH UPF0057 membrane protein At4g30650 OS=Arabidopsis thaliana OX=3702 GN=At4g30650 PE=3 SV=1: Distance = 65
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9M0F1|DF161_ARATH Defensin-like protein 161 OS=Arabidopsis thaliana OX=3702 GN=LCR27 PE=3 SV=2: Distance = 70
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9M0F2|DF160_ARATH Putative defensin-like protein 160 OS=Arabidopsis thaliana OX=3702 GN=LCR26 PE=3 SV=2: Distance = 69
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9M0F3|DF157_ARATH Putative defensin-like protein 157 OS=Arabidopsis thaliana OX=3702 GN=LCR22 PE=3 SV=1: Distance = 69
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9M1V4|DEF11_ARATH Defensin-like protein 11 OS=Arabidopsis thaliana OX=3702 GN=At3g63360 PE=3 SV=1: Distance = 72
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9M7X7|RL291_ARATH Large ribosomal subunit protein eL29z OS=Arabidopsis thaliana OX=3702 GN=RPL29A PE=1 SV=1: Distance = 68
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9M833|DEF44_ARATH Defensin-like protein 44 OS=Arabidopsis thaliana OX=3702 GN=At3g04540 PE=2 SV=2: Distance = 69
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9M9M3|DF205_ARATH Defensin-like protein 205 OS=Arabidopsis thaliana OX=3702 GN=At3g05730 PE=3 SV=1: Distance = 76
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SCK1|LSU1_ARATH Protein RESPONSE TO LOW SULFUR 1 OS=Arabidopsis thaliana OX=3702 GN=LSU1 PE=1 SV=1: Distance = 77
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SD25|SOT2_ARATH Putative cytosolic sulfotransferase 2 OS=Arabidopsis thaliana OX=3702 GN=SOT2 PE=5 SV=1: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SF57|OST4C_ARATH Dolichyl-diphosphooligosaccharide--protein glycosyltransferase subunit 4C OS=Arabidopsis thaliana OX=3702 GN=OST4C PE=3 SV=1: Distance = 62
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SGX9|ESFL1_ARATH EMBRYO SURROUNDING FACTOR 1-like protein 1 OS=Arabidopsis thaliana OX=3702 GN=ESFL1 PE=2 SV=2: Distance = 69
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SJU8|RT31_ARATH Small ribosomal subunit protein bTHXm OS=Arabidopsis thaliana OX=3702 GN=At2g21290 PE=1 SV=1: Distance = 81
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SK39|SBP3_ARATH Probable steroid-binding protein 3 OS=Arabidopsis thaliana OX=3702 GN=MP3 PE=1 SV=1: Distance = 82
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SKE0|SDH8_ARATH Succinate dehydrogenase subunit 8, mitochondrial OS=Arabidopsis thaliana OX=3702 GN=SDH8 PE=1 SV=1: Distance = 66
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SL74|DEF78_ARATH Defensin-like protein 78 OS=Arabidopsis thaliana OX=3702 GN=At2g20070 PE=3 SV=1: Distance = 76
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SMP2|S61G3_ARATH Protein transport protein Sec61 subunit gamma-3 OS=Arabidopsis thaliana OX=3702 GN=SEC61G3 PE=1 SV=1: Distance = 65
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SMZ9|Y4331_ARATH Uncharacterized protein At4g33100 OS=Arabidopsis thaliana OX=3702 GN=At4g33100 PE=3 SV=1: Distance = 77
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SRK6|R37A1_ARATH Large ribosomal subunit protein eL43z OS=Arabidopsis thaliana OX=3702 GN=RPL37AB PE=3 SV=1: Distance = 77
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SRP7|CML28_ARATH Probable calcium-binding protein CML28 OS=Arabidopsis thaliana OX=3702 GN=CML28 PE=3 SV=1: Distance = 71
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SSS5|CX5BL_ARATH Putative cytochrome c oxidase subunit 5b-like OS=Arabidopsis thaliana OX=3702 GN=At1g52710 PE=3 SV=2: Distance = 74
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SUM2|RUXF_ARATH Probable small nuclear ribonucleoprotein F OS=Arabidopsis thaliana OX=3702 GN=At4g30220 PE=3 SV=1: Distance = 71
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9T0E3|DF151_ARATH Defensin-like protein 151 OS=Arabidopsis thaliana OX=3702 GN=LCR17 PE=3 SV=1: Distance = 79
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9ZNQ7|RCI2A_ARATH Hydrophobic protein RCI2A OS=Arabidopsis thaliana OX=3702 GN=RCI2A PE=2 SV=1: Distance = 65
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9ZNS6|RCI2B_ARATH Hydrophobic protein RCI2B OS=Arabidopsis thaliana OX=3702 GN=RCI2B PE=2 SV=1: Distance = 65
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|O64818|Y2309_ARATH Uncharacterized protein At2g23090 OS=Arabidopsis thaliana OX=3702 GN=At2g23090 PE=1 SV=1: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|O82232|RC22_ARATH UPF0057 membrane protein At2g24040 OS=Arabidopsis thaliana OX=3702 GN=At2g24040 PE=3 SV=1: Distance = 68
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P58728|SF3BB_ARATH Uncharacterized protein At4g14342 OS=Arabidopsis thaliana OX=3702 GN=At4g14342 PE=3 SV=1: Distance = 74
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80828|CWP04_ARATH 54 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 71
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80833|CWP11_ARATH 96 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80834|CWP12_ARATH 52 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80835|CWP13_ARATH 44 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80836|CWP14_ARATH 36 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80838|CWP17_ARATH 23 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 71
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80840|CWP19_ARATH 17 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80842|CWP21_ARATH 36 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80843|CWP22_ARATH 68 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80844|CWP23_ARATH 64 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80845|CWP24_ARATH 36 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 71
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80848|CWP28_ARATH 48 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80850|CWP30_ARATH 33 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 72
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80851|CWP31_ARATH 27 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 71
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80852|CWP32_ARATH 31 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P80853|CWP09_ARATH 30 kDa cell wall protein (Fragment) OS=Arabidopsis thaliana OX=3702 PE=1 SV=1: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P92515|M740_ARATH Uncharacterized mitochondrial protein AtMg00740 OS=Arabidopsis thaliana OX=3702 GN=AtMg00740 PE=4 SV=1: Distance = 76
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P92518|M770_ARATH Uncharacterized mitochondrial protein AtMg00770 OS=Arabidopsis thaliana OX=3702 GN=AtMg00770 PE=4 SV=1: Distance = 80
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|P92554|M1240_ARATH Uncharacterized mitochondrial protein AtMg01240 OS=Arabidopsis thaliana OX=3702 GN=AtMg01240 PE=4 SV=1: Distance = 80
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q1G3M2|LYRM9_ARATH LYR motif-containing protein At3g19508 OS=Arabidopsis thaliana OX=3702 GN=At3g19508 PE=3 SV=1: Distance = 70
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3E6X9|FB47_ARATH Putative F-box protein At1g47915 OS=Arabidopsis thaliana OX=3702 GN=At1g47915 PE=4 SV=1: Distance = 64
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3E7S2|FB312_ARATH F-box protein At1g19070 OS=Arabidopsis thaliana OX=3702 GN=At1g19070 PE=2 SV=1: Distance = 67
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3E9H1|FB259_ARATH Putative F-box protein At5g16285 OS=Arabidopsis thaliana OX=3702 GN=At5g16285 PE=4 SV=1: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3EBP0|FB125_ARATH Putative F-box protein At2g33705 OS=Arabidopsis thaliana OX=3702 GN=At2g33705 PE=4 SV=1: Distance = 62
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q3ECU8|C3H13_ARATH Zinc finger CCCH domain-containing protein 13 OS=Arabidopsis thaliana OX=3702 GN=At1g48195 PE=4 SV=1: Distance = 71
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q8LBN7|COSA_ARATH Costars family protein At4g33640 OS=Arabidopsis thaliana OX=3702 GN=At4g33640 PE=1 SV=1: Distance = 75
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FE70|RC21_ARATH UPF0057 membrane protein At1g57550 OS=Arabidopsis thaliana OX=3702 GN=At1g57550 PE=3 SV=1: Distance = 63
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9FZE7|FB41_ARATH Putative F-box protein At1g47702 OS=Arabidopsis thaliana OX=3702 GN=At1g47702 PE=4 SV=1: Distance = 63
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9LW64|SF3BA_ARATH Uncharacterized protein At3g23325 OS=Arabidopsis thaliana OX=3702 GN=At3g23325 PE=3 SV=1: Distance = 73
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SCK2|LSU3_ARATH Protein RESPONSE TO LOW SULFUR 3 OS=Arabidopsis thaliana OX=3702 GN=LSU3 PE=4 SV=1: Distance = 78
#   sp|Q4LDR2|CTXN3_HUMAN Cortexin-3 OS=Homo sapiens OX=9606 GN=CTXN3 PE=1 SV=1 vs sp|Q9SUI0|RC24_ARATH UPF0057 membrane protein At4g30660 OS=Arabidopsis thaliana OX=3702 GN=At4g30660 PE=3 SV=1: Distance = 68
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|A0A178WF56|CSTM3_ARATH Protein CYSTEINE-RICH TRANSMEMBRANE MODULE 3 OS=Arabidopsis thaliana OX=3702 GN=CYSTM3 PE=1 SV=1: Distance = 78
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|A0A1P8AQ95|STMP4_ARATH Secreted transmembrane peptide 4 OS=Arabidopsis thaliana OX=3702 GN=STMP4 PE=2 SV=1: Distance = 79
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|A0JQ18|SOP14_ARATH Serine rich endogenous peptide 14 OS=Arabidopsis thaliana OX=3702 GN=PROSCOOP14 PE=2 SV=1: Distance = 69
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|A8MQA5|ESF13_ARATH EMBRYO SURROUNDING FACTOR 1.3 OS=Arabidopsis thaliana OX=3702 GN=ESF1.3 PE=1 SV=1: Distance = 77
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|B3H4Y2|STMP3_ARATH Secreted transmembrane peptide 3 OS=Arabidopsis thaliana OX=3702 GN=STMP3 PE=2 SV=1: Distance = 76
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|B3H5J1|GLV10_ARATH Protein GOLVEN 10 OS=Arabidopsis thaliana OX=3702 GN=GLV10 PE=1 SV=1: Distance = 80
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|B3H7I1|SOP12_ARATH Serine rich endogenous peptide 12 OS=Arabidopsis thaliana OX=3702 GN=PROSCOOP12 PE=1 SV=1: Distance = 77
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|F4JCN9|PRE4_ARATH Transcription factor PRE4 OS=Arabidopsis thaliana OX=3702 GN=PRE4 PE=1 SV=1: Distance = 81
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|F4KCH3|SOP15_ARATH Serine rich endogenous peptide 15 OS=Arabidopsis thaliana OX=3702 GN=PROSCOOP15 PE=2 SV=1: Distance = 76
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|O04468|STMP6_ARATH Secreted transmembrane peptide 6 OS=Arabidopsis thaliana OX=3702 GN=STMP6 PE=2 SV=1: Distance = 78
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|O22059|CPC_ARATH Transcription factor CPC OS=Arabidopsis thaliana OX=3702 GN=CPC PE=1 SV=1: Distance = 83
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|O49519|CLE2_ARATH CLAVATA3/ESR (CLE)-related protein 2 OS=Arabidopsis thaliana OX=3702 GN=CLE2 PE=1 SV=1: Distance = 72
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|O80460|PCEP3_ARATH Precursor of CEP3 OS=Arabidopsis thaliana OX=3702 GN=CEP3 PE=1 SV=1: Distance = 75
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|P55852|SUMO1_ARATH Small ubiquitin-related modifier 1 OS=Arabidopsis thaliana OX=3702 GN=SUMO1 PE=1 SV=2: Distance = 86
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|P56780|PSBH_ARATH Photosystem II reaction center protein H OS=Arabidopsis thaliana OX=3702 GN=psbH PE=1 SV=2: Distance = 76
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|P57752|ACBP6_ARATH Acyl-CoA-binding domain-containing protein 6 OS=Arabidopsis thaliana OX=3702 GN=ACBP6 PE=1 SV=1: Distance = 81
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|P62090|PSAC_ARATH Photosystem I iron-sulfur center OS=Arabidopsis thaliana OX=3702 GN=psaC PE=1 SV=2: Distance = 81
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q1H595|LSM2_ARATH Sm-like protein LSM2 OS=Arabidopsis thaliana OX=3702 GN=LSM2 PE=1 SV=1: Distance = 81
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q2V4E2|CLE8_ARATH CLAVATA3/ESR (CLE)-related protein 8 OS=Arabidopsis thaliana OX=3702 GN=CLE8 PE=1 SV=1: Distance = 77
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q3EBM6|PCEP4_ARATH Precursor of CEP4 OS=Arabidopsis thaliana OX=3702 GN=CEP4 PE=2 SV=1: Distance = 81
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q3ECJ5|CLE14_ARATH CLAVATA3/ESR (CLE)-related protein 14 OS=Arabidopsis thaliana OX=3702 GN=CLE14 PE=1 SV=1: Distance = 78
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q3ECR7|CSTM2_ARATH Protein CYSTEINE-RICH TRANSMEMBRANE MODULE 2 OS=Arabidopsis thaliana OX=3702 GN=CYSTM2 PE=1 SV=1: Distance = 77
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q4VP08|LUR12_ARATH Protein LURE 1.2 OS=Arabidopsis thaliana OX=3702 GN=LURE1.2 PE=1 SV=2: Distance = 78
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q570K8|SCOP4_ARATH Serine rich endogenous peptide 4 OS=Arabidopsis thaliana OX=3702 GN=PROSCOOP4 PE=2 SV=1: Distance = 74
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q6NNL9|NOXY2_ARATH Protein NONRESPONDING TO OXYLIPINS 2, mitochondrial OS=Arabidopsis thaliana OX=3702 GN=NOXY2 PE=1 SV=2: Distance = 78
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q7XXN8|DVL16_ARATH Small polypeptide DEVIL 16 OS=Arabidopsis thaliana OX=3702 GN=DVL16 PE=2 SV=1: Distance = 76
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q84J95|GASA5_ARATH Gibberellin-regulated protein 5 OS=Arabidopsis thaliana OX=3702 GN=GASA5 PE=2 SV=1: Distance = 82
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q84W98|CLE41_ARATH CLAVATA3/ESR (CLE)-related protein 41 OS=Arabidopsis thaliana OX=3702 GN=CLE41 PE=1 SV=1: Distance = 79
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q8GW48|HSBP_ARATH Heat shock factor-binding protein OS=Arabidopsis thaliana OX=3702 GN=HSBP PE=1 SV=1: Distance = 80
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q8L8Y3|PCEP1_ARATH Precursor of CEP1 OS=Arabidopsis thaliana OX=3702 GN=CEP1 PE=1 SV=1: Distance = 78
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q8LAD7|IDA_ARATH Protein IDA OS=Arabidopsis thaliana OX=3702 GN=IDA PE=1 SV=1: Distance = 75
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q8LE06|SOP13_ARATH Serine rich endogenous peptide 13 OS=Arabidopsis thaliana OX=3702 GN=PROSCOOP13 PE=2 SV=1: Distance = 74
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q8LLV8|PLS_ARATH Peptide POLARIS OS=Arabidopsis thaliana OX=3702 GN=PLS PE=2 SV=1: Distance = 79
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q8RWS1|ORS1_ARATH Protein ORGAN SIZE RELATED 1 OS=Arabidopsis thaliana OX=3702 GN=OSR1 PE=2 SV=1: Distance = 81
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q8VY77|TGD5_ARATH Protein TRIGALACTOSYLDIACYLGLYCEROL 5, chloroplastic OS=Arabidopsis thaliana OX=3702 GN=TGD5 PE=1 SV=1: Distance = 83
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q8VYI0|LSM8_ARATH Sm-like protein LSM8 OS=Arabidopsis thaliana OX=3702 GN=LSM8 PE=1 SV=1: Distance = 84
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q93V47|GG2_ARATH Guanine nucleotide-binding protein subunit gamma 2 OS=Arabidopsis thaliana OX=3702 GN=GG2 PE=1 SV=1: Distance = 84
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q93VK8|GLV1_ARATH Protein GOLVEN 1 OS=Arabidopsis thaliana OX=3702 GN=GLV1 PE=1 SV=1: Distance = 81
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q93WF6|SAG21_ARATH Protein SENESCENCE-ASSOCIATED GENE 21, mitochondrial OS=Arabidopsis thaliana OX=3702 GN=SAG21 PE=2 SV=1: Distance = 82
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q941C7|PSY1_ARATH Protein PSY1 OS=Arabidopsis thaliana OX=3702 GN=PSY1 PE=1 SV=1: Distance = 78
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q94C26|PCC1_ARATH Cysteine-rich and transmembrane domain-containing protein PCC1 OS=Arabidopsis thaliana OX=3702 GN=PCC1 PE=1 SV=1: Distance = 76
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q94JY4|BRK1_ARATH Protein BRICK 1 OS=Arabidopsis thaliana OX=3702 GN=BRK1 PE=1 SV=1: Distance = 79
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9C9T3|MZT1A_ARATH Mitotic-spindle organizing protein 1A OS=Arabidopsis thaliana OX=3702 GN=GIP2 PE=1 SV=1: Distance = 76
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9CA64|PRE3_ARATH Transcription factor PRE3 OS=Arabidopsis thaliana OX=3702 GN=PRE3 PE=1 SV=1: Distance = 85
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9FDX9|GG1_ARATH Guanine nucleotide-binding protein subunit gamma 1 OS=Arabidopsis thaliana OX=3702 GN=GG1 PE=1 SV=1: Distance = 85
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9FGF6|GLV2_ARATH Protein GOLVEN 2 OS=Arabidopsis thaliana OX=3702 GN=GLV2 PE=1 SV=1: Distance = 75
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9FI23|DEF16_ARATH Defensin-like protein 16 OS=Arabidopsis thaliana OX=3702 GN=PDF1.2A PE=1 SV=1: Distance = 79
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9FIC3|BOLA2_ARATH Protein BOLA2 OS=Arabidopsis thaliana OX=3702 GN=BOLA2 PE=1 SV=1: Distance = 81
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9FIR9|LSU2_ARATH Protein RESPONSE TO LOW SULFUR 2 OS=Arabidopsis thaliana OX=3702 GN=LSU2 PE=1 SV=1: Distance = 79
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9FIW0|ACIN1_ARATH Peptide ARACIN 1 OS=Arabidopsis thaliana OX=3702 GN=ARACIN1 PE=2 SV=1: Distance = 75
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9FIW1|STMP9_ARATH Secreted transmembrane peptide 9 OS=Arabidopsis thaliana OX=3702 GN=STMP9 PE=2 SV=1: Distance = 77
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9FJW3|WIH1_ARATH Protein CYSTEINE-RICH TRANSMEMBRANE MODULE 13 OS=Arabidopsis thaliana OX=3702 GN=WIH1 PE=1 SV=1: Distance = 83
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9FKB0|LSM5_ARATH Sm-like protein LSM5 OS=Arabidopsis thaliana OX=3702 GN=LSM5 PE=1 SV=1: Distance = 78
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9FLE9|PRE1_ARATH Transcription factor PRE1 OS=Arabidopsis thaliana OX=3702 GN=PRE1 PE=1 SV=1: Distance = 79
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9LV87|PEP1_ARATH Precursor of elicitor peptide 1 OS=Arabidopsis thaliana OX=3702 GN=PROPEP1 PE=1 SV=1: Distance = 78
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9LVC0|AGP14_ARATH Arabinogalactan protein 14 OS=Arabidopsis thaliana OX=3702 GN=AGP14 PE=1 SV=1: Distance = 77
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9LXG5|PRE2_ARATH Transcription factor PRE2 OS=Arabidopsis thaliana OX=3702 GN=PRE2 PE=1 SV=1: Distance = 81
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9LXI8|ZPR3_ARATH Protein LITTLE ZIPPER 3 OS=Arabidopsis thaliana OX=3702 GN=ZPR3 PE=1 SV=1: Distance = 80
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9M0N8|MZT1B_ARATH Mitotic-spindle organizing protein 1B OS=Arabidopsis thaliana OX=3702 GN=GIP1 PE=1 SV=1: Distance = 77
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9SLJ2|HRD11_ARATH Dehydrin HIRD11 OS=Arabidopsis thaliana OX=3702 GN=HIRD11 PE=1 SV=1: Distance = 83
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|Q9XF04|CLV3_ARATH Protein CLAVATA 3 OS=Arabidopsis thaliana OX=3702 GN=CLV3 PE=1 SV=2: Distance = 81
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|A0A1P8BDL3|SCOP2_ARATH Serine rich endogenous peptide 2 OS=Arabidopsis thaliana OX=3702 GN=PROSCOOP2 PE=2 SV=1: Distance = 75
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|A8MQX3|ESF12_ARATH EMBRYO SURROUNDING FACTOR 1.2 OS=Arabidopsis thaliana OX=3702 GN=ESF1.2 PE=2 SV=1: Distance = 78
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|A8MSA6|ESF11_ARATH EMBRYO SURROUNDING FACTOR 1.1 OS=Arabidopsis thaliana OX=3702 GN=ESF1.1 PE=2 SV=1: Distance = 76
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|B3H4X8|TCL2_ARATH MYB-like transcription factor TCL2 OS=Arabidopsis thaliana OX=3702 GN=TCL2 PE=1 SV=1: Distance = 82
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|D3GKW6|TCL1_ARATH MYB-like transcription factor TCL1 OS=Arabidopsis thaliana OX=3702 GN=TCL1 PE=2 SV=1: Distance = 81
#   sp|Q56P42|PYDC2_HUMAN Pyrin domain-containing protein 2 OS=Homo sapiens OX=9606 GN=PYDC2 PE=1 SV=1 vs sp|F4IIS6|PCA22_ARATH Protein PROLINE CONTENT ALTERNATIVE 22 OS=Arabidopsis thaliana OX=3702 GN=PCA22 PE=2 SV=1: Distance = 86
# ...
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V328|DF276_ARATH Defensin-like protein 276 OS=Arabidopsis thaliana OX=3702 GN=At5g37474 PE=2 SV=1: Distance = 77
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V329|DF277_ARATH Putative defensin-like protein 277 OS=Arabidopsis thaliana OX=3702 GN=At5g37473 PE=3 SV=1: Distance = 78
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V334|DEF82_ARATH Defensin-like protein 82 OS=Arabidopsis thaliana OX=3702 GN=At5g32619 PE=3 SV=1: Distance = 83
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V337|DF101_ARATH Putative defensin-like protein 101 OS=Arabidopsis thaliana OX=3702 GN=At5g28288 PE=3 SV=1: Distance = 81
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V342|DF113_ARATH Defensin-like protein 113 OS=Arabidopsis thaliana OX=3702 GN=At5g27495 PE=5 SV=1: Distance = 83
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V352|DF271_ARATH Putative defensin-like protein 271 OS=Arabidopsis thaliana OX=3702 GN=At5g23212 PE=3 SV=1: Distance = 81
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V354|DF267_ARATH Defensin-like protein 267 OS=Arabidopsis thaliana OX=3702 GN=At5g23035 PE=2 SV=1: Distance = 87
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V364|DEF23_ARATH Putative defensin-like protein 23 OS=Arabidopsis thaliana OX=3702 GN=At5g19315 PE=3 SV=1: Distance = 81
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V365|DEF48_ARATH Putative defensin-like protein 48 OS=Arabidopsis thaliana OX=3702 GN=At5g19175 PE=3 SV=1: Distance = 86
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V366|DEF49_ARATH Defensin-like protein 49 OS=Arabidopsis thaliana OX=3702 GN=At5g19172 PE=3 SV=1: Distance = 87
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V369|DF223_ARATH Defensin-like protein 223 OS=Arabidopsis thaliana OX=3702 GN=At5g18407 PE=2 SV=3: Distance = 80
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V370|DF218_ARATH Defensin-like protein 218 OS=Arabidopsis thaliana OX=3702 GN=At5g18403 PE=2 SV=1: Distance = 82
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V371|DEF24_ARATH Defensin-like protein 24 OS=Arabidopsis thaliana OX=3702 GN=At5g16453 PE=3 SV=1: Distance = 79
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V390|DF109_ARATH Defensin-like protein 109 OS=Arabidopsis thaliana OX=3702 GN=At5g08505 PE=2 SV=1: Distance = 81
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V391|DEF22_ARATH Defensin-like protein 22 OS=Arabidopsis thaliana OX=3702 GN=At5g08315 PE=2 SV=1: Distance = 82
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V392|DEF25_ARATH Putative defensin-like protein 25 OS=Arabidopsis thaliana OX=3702 GN=At5g08055 PE=3 SV=1: Distance = 81
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3D7|DEF31_ARATH Putative defensin-like protein 31 OS=Arabidopsis thaliana OX=3702 GN=At4g29033 PE=3 SV=1: Distance = 84
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3H6|DF306_ARATH Defensin-like protein 306 OS=Arabidopsis thaliana OX=3702 GN=At4g17713 PE=2 SV=1: Distance = 88
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3J0|DEF89_ARATH Putative defensin-like protein 89 OS=Arabidopsis thaliana OX=3702 GN=At4g13968 PE=3 SV=1: Distance = 80
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3J1|DEF88_ARATH Putative defensin-like protein 88 OS=Arabidopsis thaliana OX=3702 GN=At4g13955 PE=5 SV=1: Distance = 80
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3J6|DF202_ARATH Putative defensin-like protein 202 OS=Arabidopsis thaliana OX=3702 GN=At4g11393 PE=3 SV=1: Distance = 81
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3K0|DF169_ARATH Putative defensin-like protein 169 OS=Arabidopsis thaliana OX=3702 GN=At4g10603 PE=3 SV=1: Distance = 84
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3K1|DF135_ARATH Putative defensin-like protein 135 OS=Arabidopsis thaliana OX=3702 GN=At4g09647 PE=3 SV=1: Distance = 80
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3K2|DF209_ARATH Defensin-like protein 209 OS=Arabidopsis thaliana OX=3702 GN=At4g08875 PE=2 SV=1: Distance = 87
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3K4|DF210_ARATH Defensin-like protein 210 OS=Arabidopsis thaliana OX=3702 GN=At4g08869 PE=2 SV=1: Distance = 86
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3K7|DF211_ARATH Putative defensin-like protein 211 OS=Arabidopsis thaliana OX=3702 GN=At4g08485 PE=3 SV=1: Distance = 85
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3K9|DF312_ARATH Putative defensin-like protein 312 OS=Arabidopsis thaliana OX=3702 GN=At4g08039 PE=5 SV=1: Distance = 82
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3L0|DF102_ARATH Putative defensin-like protein 102 OS=Arabidopsis thaliana OX=3702 GN=At4g08028 PE=3 SV=1: Distance = 82
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3Q1|DF168_ARATH Putative defensin-like protein 168 OS=Arabidopsis thaliana OX=3702 GN=At3g50925 PE=3 SV=1: Distance = 85
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3Q8|DF255_ARATH Defensin-like protein 255 OS=Arabidopsis thaliana OX=3702 GN=At3g45093 PE=5 SV=1: Distance = 83
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3R5|DF315_ARATH Putative defensin-like protein 315 OS=Arabidopsis thaliana OX=3702 GN=At3g33187 PE=5 SV=1: Distance = 82
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3R9|DEF29_ARATH Putative defensin-like protein 29 OS=Arabidopsis thaliana OX=3702 GN=At3g27835 PE=3 SV=1: Distance = 82
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3S0|DEF30_ARATH Putative defensin-like protein 30 OS=Arabidopsis thaliana OX=3702 GN=At3g27831 PE=3 SV=1: Distance = 80
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3S7|DF258_ARATH Putative defensin-like protein 258 OS=Arabidopsis thaliana OX=3702 GN=At3g24513 PE=3 SV=1: Distance = 82
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3S8|DF257_ARATH Putative defensin-like protein 257 OS=Arabidopsis thaliana OX=3702 GN=At3g24508 PE=3 SV=1: Distance = 83
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3V1|DEF46_ARATH Defensin-like protein 46 OS=Arabidopsis thaliana OX=3702 GN=At3g17155 PE=3 SV=1: Distance = 82
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3W5|DF302_ARATH Defensin-like protein 302 OS=Arabidopsis thaliana OX=3702 GN=At3g13403 PE=5 SV=1: Distance = 83
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3X3|DF311_ARATH Defensin-like protein 311 OS=Arabidopsis thaliana OX=3702 GN=At3g10195 PE=2 SV=1: Distance = 84
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3Y5|DF317_ARATH Putative defensin-like protein 317 OS=Arabidopsis thaliana OX=3702 GN=At3g04903 PE=3 SV=1: Distance = 82
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V3Y8|DEF45_ARATH Defensin-like protein 45 OS=Arabidopsis thaliana OX=3702 GN=At3g04545 PE=2 SV=1: Distance = 81
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V413|DF107_ARATH Defensin-like protein 107 OS=Arabidopsis thaliana OX=3702 GN=At2g40995 PE=2 SV=1: Distance = 81
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V424|DF203_ARATH Putative defensin-like protein 203 OS=Arabidopsis thaliana OX=3702 GN=At2g36255 PE=3 SV=1: Distance = 82
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V433|DEF52_ARATH Putative defensin-like protein 52 OS=Arabidopsis thaliana OX=3702 GN=At2g34123 PE=5 SV=1: Distance = 83
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V460|DEF39_ARATH Putative defensin-like protein 39 OS=Arabidopsis thaliana OX=3702 GN=At2g24625 PE=3 SV=1: Distance = 83
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V462|DEF38_ARATH Putative defensin-like protein 38 OS=Arabidopsis thaliana OX=3702 GN=At2g24615 PE=3 SV=1: Distance = 84
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V466|DF191_ARATH Putative defensin-like protein 191 OS=Arabidopsis thaliana OX=3702 GN=At2g22941 PE=3 SV=1: Distance = 80
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V467|DF190_ARATH Putative defensin-like protein 190 OS=Arabidopsis thaliana OX=3702 GN=At2g22807 PE=3 SV=1: Distance = 90
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V468|DF189_ARATH Putative defensin-like protein 189 OS=Arabidopsis thaliana OX=3702 GN=At2g22805 PE=3 SV=1: Distance = 83
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V470|DEF79_ARATH Putative defensin-like protein 79 OS=Arabidopsis thaliana OX=3702 GN=At2g21725 PE=3 SV=1: Distance = 81
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V472|DF291_ARATH Defensin-like protein 291 OS=Arabidopsis thaliana OX=3702 GN=At2g21465 PE=2 SV=1: Distance = 81
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V476|DF104_ARATH Putative defensin-like protein 104 OS=Arabidopsis thaliana OX=3702 GN=At2g20463 PE=3 SV=1: Distance = 86
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V477|DEF12_ARATH Putative defensin-like protein 12 OS=Arabidopsis thaliana OX=3702 GN=At2g19893 PE=3 SV=1: Distance = 79
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V483|DF256_ARATH Putative defensin-like protein 256 OS=Arabidopsis thaliana OX=3702 GN=At2g17723 PE=3 SV=1: Distance = 85
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V485|DEF62_ARATH Putative defensin-like protein 62 OS=Arabidopsis thaliana OX=3702 GN=At2g13542 PE=3 SV=1: Distance = 85
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V488|DF112_ARATH Defensin-like protein 112 OS=Arabidopsis thaliana OX=3702 GN=At2g12475 PE=2 SV=1: Distance = 85
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4A3|DF293_ARATH Defensin-like protein 293 OS=Arabidopsis thaliana OX=3702 GN=At2g04925 PE=3 SV=1: Distance = 78
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4A4|DF294_ARATH Defensin-like protein 294 OS=Arabidopsis thaliana OX=3702 GN=At2g04034 PE=2 SV=1: Distance = 81
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4A5|DEF60_ARATH Putative defensin-like protein 60 OS=Arabidopsis thaliana OX=3702 GN=At2g03955 PE=3 SV=1: Distance = 82
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4A6|DEF56_ARATH Putative defensin-like protein 56 OS=Arabidopsis thaliana OX=3702 GN=At2g03936 PE=3 SV=1: Distance = 82
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4A7|DEF64_ARATH Putative defensin-like protein 64 OS=Arabidopsis thaliana OX=3702 GN=At2g03932 PE=5 SV=1: Distance = 86
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4A8|DEF57_ARATH Putative defensin-like protein 57 OS=Arabidopsis thaliana OX=3702 GN=At2g03913 PE=3 SV=1: Distance = 81
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4C3|DF281_ARATH Defensin-like protein 281 OS=Arabidopsis thaliana OX=3702 GN=At1g77093 PE=2 SV=1: Distance = 80
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4C4|DF280_ARATH Putative defensin-like protein 280 OS=Arabidopsis thaliana OX=3702 GN=At1g76954 PE=3 SV=1: Distance = 84
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4D5|DEF36_ARATH Putative defensin-like protein 36 OS=Arabidopsis thaliana OX=3702 GN=At1g69828 PE=3 SV=1: Distance = 78
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4D6|DEF33_ARATH Putative defensin-like protein 33 OS=Arabidopsis thaliana OX=3702 GN=At1g69825 PE=3 SV=1: Distance = 85
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4D7|DEF34_ARATH Defensin-like protein 34 OS=Arabidopsis thaliana OX=3702 GN=At1g69818 PE=2 SV=1: Distance = 83
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4D9|DF263_ARATH Putative defensin-like protein 263 OS=Arabidopsis thaliana OX=3702 GN=At1g68907 PE=3 SV=1: Distance = 87
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4E0|DF262_ARATH Putative defensin-like protein 262 OS=Arabidopsis thaliana OX=3702 GN=At1g68905 PE=3 SV=1: Distance = 84
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4F0|DF266_ARATH Defensin-like protein 266 OS=Arabidopsis thaliana OX=3702 GN=At1g65352 PE=2 SV=1: Distance = 85
#   sp|Q5TA78|LCE4A_HUMAN Late cornified envelope protein 4A OS=Homo sapiens OX=9606 GN=LCE4A PE=1 SV=1 vs sp|Q2V4F3|DEF35_ARATH Defensin-like protein 35 OS=Arabidopsis thaliana OX=3702 GN=At1g64195 PE=2 SV=2: Distance = 77
